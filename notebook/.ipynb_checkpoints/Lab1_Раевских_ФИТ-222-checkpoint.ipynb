# %% [markdown]
# # Этап 1. Обзор данных <a id='data_review'></a>
# <br>
# Чтобы выявить гипотезы для выполнения заданий стоит сначала узнать из чего состоит данная таблица

# %%
import pandas as pd
import os

# %%
os.chdir('../data')
df = pd.read_csv('Dataset1.csv')

# %% [markdown]
# Проанализируем датафрейм с помощью нескольких команд

# %%
df.head (10)
# Out:
#     color      Director_Name  num_Critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1  Colour     Gore Verbinski                   302.0     169.0
# 2  Colour         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 4     NaN        Doug Walker                     NaN       NaN
# 5  Colour     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8  Colour        Joss Whedon                   635.0     141.0
# 9  Colour        David Yates                   375.0     153.0
#
#    director_Facebook_likes  actor_3_Facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# 3                  22000.0                 23000.0     Christian Bale
# 4                    131.0                     NaN         Rob Walker
# 5                    475.0                   530.0    Samantha Morton
# 6                      0.0                  4000.0       James Franco
# 7                     15.0                   284.0       Donna Murphy
# 8                      0.0                 19000.0  Robert Downey Jr.
# 9                    282.0                 10000.0   Daniel Radcliffe
#
#    Actor_1_Facebook_likes        gross  \
# 0                  1000.0  760505847.0
# 1                 40000.0  309404152.0
# 2                 11000.0  200074175.0
# 3                 27000.0  448130642.0
# 4                   131.0          NaN
# 5                   640.0   73058679.0
# 6                 24000.0  336530303.0
# 7                   799.0  200807262.0
# 8                 26000.0  458991599.0
# 9                 25000.0  301956980.0
#
#                                               genres  ...  \
# 0                    Action|Adventure|Fantasy|Sci-Fi  ...
# 1                           Action|Adventure|Fantasy  ...
# 2                          Action|Adventure|Thriller  ...
# 3                                    Action|Thriller  ...
# 4                                        Documentary  ...
# 5                            Action|Adventure|Sci-Fi  ...
# 6                           Action|Adventure|Romance  ...
# 7  Adventure|Animation|Comedy|Family|Fantasy|Musi...  ...
# 8                            Action|Adventure|Sci-Fi  ...
# 9                   Adventure|Family|Fantasy|Mystery  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
# 5                738.0  English      USA           PG-13  263700000.0
# 6               1902.0  English      USA           PG-13  258000000.0
# 7                387.0  English      USA              PG  260000000.0
# 8               1117.0  English      USA           PG-13  250000000.0
# 9                973.0  English       UK              PG  250000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
# 5      2012.0                  632.0        6.6          2.35
# 6      2007.0                11000.0        6.2          2.35
# 7      2010.0                  553.0        7.8          1.85
# 8      2015.0                21000.0        7.5          2.35
# 9      2009.0                11000.0        7.5          2.35
#
#   movie_facebook_likes;
# 0                33000;
# 1                    0;
# 2                85000;
# 3               164000;
# 4                    0;
# 5                24000;
# 6                    0;
# 7                29000;
# 8               118000;
# 9                10000;
#
# [10 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   color                       5025 non-null   object
#  1   Director_Name               4872 non-null   object
#  2   num_Critic_for_reviews      4927 non-null   float64
#  3   duration                    4959 non-null   float64
#  4   director_Facebook_likes     4872 non-null   float64
#  5   actor_3_Facebook_likes      4953 non-null   float64
#  6   actor_2_name                4963 non-null   object
#  7   Actor_1_Facebook_likes      4968 non-null   float64
#  8   gross                       4104 non-null   float64
#  9   genres                      4974 non-null   object
#  10  actor_1_name                4968 non-null   object
#  11  movie_Title                 4974 non-null   object
#  12  num_voted_users             4974 non-null   float64
#  13   cast_total_facebook_likes  4974 non-null   float64
#  14  actor_3_name                4953 non-null   object
#  15  facenumber_in_poster        4961 non-null   float64
#  16  plot_keywords               4827 non-null   object
#  17  movie_imdb_link             4974 non-null   object
#  18  num_user_for_reviews        4956 non-null   float64
#  19  language                    4961 non-null   object
#  20  country                     4971 non-null   object
#  21  content_rating              4677 non-null   object
#  22  budget                      4494 non-null   float64
#  23  title_year                  4869 non-null   float64
#  24  actor_2_facebook_likes      4963 non-null   float64
#  25  imdb_score                  4974 non-null   float64
#  26  aspect_ratio                4654 non-null   float64
#  27  movie_facebook_likes;       4974 non-null   object
# dtypes: float64(15), object(13)
# memory usage: 1.1+ MB

# %% [markdown]
# Итак в ДатаФрейме присутствуют пустые значения, пробелы в названии столбцов и написание с большой буквы.
# Это все следует исправить.

# %% [markdown]
# # Этап 2. Предварительная обработка данных <a id='data_review'></a>
# <br>
# Чтобы начать работу с ДатаФреймом следует ее подправить.

# %% [markdown]
# ### Стили заголовков <a id='header_style'></a>

# %%
df.columns
# Out:
# Index(['color', 'Director_Name', 'num_Critic_for_reviews', 'duration',
#        'director_Facebook_likes', 'actor_3_Facebook_likes', 'actor_2_name',
#        'Actor_1_Facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_Title', 'num_voted_users', ' cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes;'],
#       dtype='object')

# %% [markdown]
# Изменим названия столбцов.

# %%
df = df.rename (
    columns = {
        'Director_Name' : 'director_name',
        'num_Critic_for_reviews': 'num_critic_for_reviews',
        'director_Facebook_likes': 'director_facebook_likes',
        'actor_3_Facebook_likes': 'actor_3_facebook_likes',
        'Actor_1_Facebook_likes': 'actor_1_facebook_likes',
        ' cast_total_facebook_likes': 'cast_total_facebook_likes',
        'movie_facebook_likes;': 'movie_facebook_likes',
        'movie_Title': 'movie_title'
    }
)

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ### Пропущенные значения <a id='missing_values'></a>
# <br>
# Восполним в ДатаФрейме все пропущенные значения.
# Сначала узнаем сколько их.

# %%
df.isna().sum()
# Out:
# color                         18
# director_name                171
# num_critic_for_reviews       116
# duration                      84
# director_facebook_likes      171
# actor_3_facebook_likes        90
# actor_2_name                  80
# actor_1_facebook_likes        75
# gross                        939
# genres                        69
# actor_1_name                  75
# movie_title                   69
# num_voted_users               69
# cast_total_facebook_likes     69
# actor_3_name                  90
# facenumber_in_poster          82
# plot_keywords                216
# movie_imdb_link               69
# num_user_for_reviews          87
# language                      82
# country                       72
# content_rating               366
# budget                       549
# title_year                   174
# actor_2_facebook_likes        80
# imdb_score                    69
# aspect_ratio                 389
# movie_facebook_likes          69
# dtype: int64

# %%
columns_to_replace =['color', 'director_name', 'actor_2_name',
       'genres', 'actor_1_name',
       'movie_title',
       'actor_3_name', 'plot_keywords',
       'movie_imdb_link', 'language', 'country',
       ]

for row in columns_to_replace:
    df[row] = df[row].fillna('unknown')

# %%
columns_to_replace =['num_critic_for_reviews', 'duration',
       'director_facebook_likes', 'actor_3_facebook_likes',
       'actor_1_facebook_likes', 'gross', 'num_voted_users', 'cast_total_facebook_likes', 'facenumber_in_poster', 'num_user_for_reviews',
       'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
       'imdb_score', 'aspect_ratio', 'movie_facebook_likes']

for row in columns_to_replace:
    df[row] = df[row].fillna(-1)

# %%
df.isna().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %% [markdown]
# Все пропущенные значения в дата фрейме были заполнены на "unknown", а цифровые значения на -1.

# %% [markdown]
# ### Сортировка столбцов <a id='sort_tabel'></a>
# <br>
# Мне очень тяжело смотреть на таблицу где за Имя_актера_2 следует Имя_актера_1, поэтому отсортируем столбцы

# %%
cols = sorted(list(df.columns.values))
df = df[cols]

# %%
df.columns
# Out:
# Index(['actor_1_facebook_likes', 'actor_1_name', 'actor_2_facebook_likes',
#        'actor_2_name', 'actor_3_facebook_likes', 'actor_3_name',
#        'aspect_ratio', 'budget', 'cast_total_facebook_likes', 'color',
#        'content_rating', 'country', 'director_facebook_likes', 'director_name',
#        'duration', 'facenumber_in_poster', 'genres', 'gross', 'imdb_score',
#        'language', 'movie_facebook_likes', 'movie_imdb_link', 'movie_title',
#        'num_critic_for_reviews', 'num_user_for_reviews', 'num_voted_users',
#        'plot_keywords', 'title_year'],
#       dtype='object')

# %% [markdown]
# Теперь таблица выглядит приятнее глазу.

# %% [markdown]
# ### Дупликаты <a id='duplicates'></a>
# <br>
# Заметно, что в столбце "color" присутствуют дубликаты Color и Colour
# Заменим их на американский Color, а так же посмотрим на наличие дубликатов в других столбцах.

# %%
sorted (df['genres'].unique())
# Out:
# ['Action',
#  'Action|Adventure',
#  'Action|Adventure|Animation|Comedy|Crime|Family|Fantasy',
#  'Action|Adventure|Animation|Comedy|Drama|Family|Fantasy|Thriller',
#  'Action|Adventure|Animation|Comedy|Drama|Family|Sci-Fi',
#  'Action|Adventure|Animation|Comedy|Family',
#  'Action|Adventure|Animation|Comedy|Family|Fantasy',
#  'Action|Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi',
#  'Action|Adventure|Animation|Comedy|Family|Sci-Fi',
#  'Action|Adventure|Animation|Comedy|Fantasy',
#  'Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi',
#  'Action|Adventure|Animation|Comedy|Sci-Fi',
#  'Action|Adventure|Animation|Drama|Fantasy|Sci-Fi',
#  'Action|Adventure|Animation|Drama|Mystery|Sci-Fi|Thriller',
#  'Action|Adventure|Animation|Family',
#  'Action|Adventure|Animation|Family|Fantasy',
#  'Action|Adventure|Animation|Family|Fantasy|Sci-Fi',
#  'Action|Adventure|Animation|Family|Sci-Fi',
#  'Action|Adventure|Animation|Family|Sci-Fi|Thriller',
#  'Action|Adventure|Animation|Fantasy',
#  'Action|Adventure|Animation|Fantasy|Romance|Sci-Fi',
#  'Action|Adventure|Biography|Drama|History',
#  'Action|Adventure|Biography|Drama|History|Romance|War',
#  'Action|Adventure|Biography|Drama|History|Thriller',
#  'Action|Adventure|Comedy',
#  'Action|Adventure|Comedy|Crime',
#  'Action|Adventure|Comedy|Crime|Family|Romance|Thriller',
#  'Action|Adventure|Comedy|Crime|Music|Mystery',
#  'Action|Adventure|Comedy|Crime|Mystery|Thriller',
#  'Action|Adventure|Comedy|Crime|Thriller',
#  'Action|Adventure|Comedy|Drama|Music|Sci-Fi',
#  'Action|Adventure|Comedy|Drama|Thriller',
#  'Action|Adventure|Comedy|Drama|War',
#  'Action|Adventure|Comedy|Family',
#  'Action|Adventure|Comedy|Family|Fantasy',
#  'Action|Adventure|Comedy|Family|Fantasy|Mystery|Sci-Fi',
#  'Action|Adventure|Comedy|Family|Fantasy|Sci-Fi',
#  'Action|Adventure|Comedy|Family|Mystery',
#  'Action|Adventure|Comedy|Family|Romance',
#  'Action|Adventure|Comedy|Family|Romance|Sci-Fi',
#  'Action|Adventure|Comedy|Family|Sci-Fi',
#  'Action|Adventure|Comedy|Fantasy',
#  'Action|Adventure|Comedy|Fantasy|Mystery',
#  'Action|Adventure|Comedy|Fantasy|Romance',
#  'Action|Adventure|Comedy|Fantasy|Sci-Fi',
#  'Action|Adventure|Comedy|Fantasy|Thriller',
#  'Action|Adventure|Comedy|Musical',
#  'Action|Adventure|Comedy|Music|Thriller',
#  'Action|Adventure|Comedy|Romance',
#  'Action|Adventure|Comedy|Romance|Sci-Fi',
#  'Action|Adventure|Comedy|Romance|Thriller',
#  'Action|Adventure|Comedy|Romance|Thriller|Western',
#  'Action|Adventure|Comedy|Sci-Fi',
#  'Action|Adventure|Comedy|Sci-Fi|Thriller',
#  'Action|Adventure|Comedy|Thriller',
#  'Action|Adventure|Comedy|Western',
#  'Action|Adventure|Crime',
#  'Action|Adventure|Crime|Drama',
#  'Action|Adventure|Crime|Drama|Family|Fantasy|Romance|Thriller',
#  'Action|Adventure|Crime|Drama|Mystery|Thriller',
#  'Action|Adventure|Crime|Drama|Romance',
#  'Action|Adventure|Crime|Drama|Sci-Fi|Thriller',
#  'Action|Adventure|Crime|Drama|Thriller',
#  'Action|Adventure|Crime|Fantasy|Mystery|Thriller',
#  'Action|Adventure|Crime|Mystery|Thriller',
#  'Action|Adventure|Crime|Thriller',
#  'Action|Adventure|Drama',
#  'Action|Adventure|Drama|Family',
#  'Action|Adventure|Drama|Fantasy',
#  'Action|Adventure|Drama|Fantasy|Sci-Fi',
#  'Action|Adventure|Drama|Fantasy|War',
#  'Action|Adventure|Drama|History',
#  'Action|Adventure|Drama|History|Romance',
#  'Action|Adventure|Drama|History|Romance|War',
#  'Action|Adventure|Drama|History|Thriller|War',
#  'Action|Adventure|Drama|History|War',
#  'Action|Adventure|Drama|Horror|Sci-Fi',
#  'Action|Adventure|Drama|Mystery',
#  'Action|Adventure|Drama|Romance',
#  'Action|Adventure|Drama|Romance|Sci-Fi',
#  'Action|Adventure|Drama|Romance|Thriller',
#  'Action|Adventure|Drama|Romance|War',
#  'Action|Adventure|Drama|Romance|Western',
#  'Action|Adventure|Drama|Sci-Fi',
#  'Action|Adventure|Drama|Sci-Fi|Thriller',
#  'Action|Adventure|Drama|Thriller',
#  'Action|Adventure|Drama|Thriller|War',
#  'Action|Adventure|Drama|Thriller|Western',
#  'Action|Adventure|Drama|War',
#  'Action|Adventure|Drama|Western',
#  'Action|Adventure|Family|Fantasy',
#  'Action|Adventure|Family|Fantasy|Romance',
#  'Action|Adventure|Family|Fantasy|Sci-Fi',
#  'Action|Adventure|Family|Fantasy|Sci-Fi|Thriller',
#  'Action|Adventure|Family|Fantasy|Thriller',
#  'Action|Adventure|Family|Mystery',
#  'Action|Adventure|Family|Mystery|Sci-Fi',
#  'Action|Adventure|Family|Sci-Fi',
#  'Action|Adventure|Family|Sci-Fi|Thriller',
#  'Action|Adventure|Family|Thriller',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Fantasy|Horror',
#  'Action|Adventure|Fantasy|Horror|Sci-Fi',
#  'Action|Adventure|Fantasy|Horror|Sci-Fi|Thriller',
#  'Action|Adventure|Fantasy|Horror|Thriller',
#  'Action|Adventure|Fantasy|Romance',
#  'Action|Adventure|Fantasy|Sci-Fi',
#  'Action|Adventure|Fantasy|Sci-Fi|Thriller',
#  'Action|Adventure|Fantasy|Thriller',
#  'Action|Adventure|Fantasy|War',
#  'Action|Adventure|History',
#  'Action|Adventure|History|Romance',
#  'Action|Adventure|History|Western',
#  'Action|Adventure|Horror|Sci-Fi',
#  'Action|Adventure|Horror|Sci-Fi|Thriller',
#  'Action|Adventure|Horror|Thriller',
#  'Action|Adventure|Mystery|Romance|Thriller',
#  'Action|Adventure|Mystery|Sci-Fi',
#  'Action|Adventure|Mystery|Sci-Fi|Thriller',
#  'Action|Adventure|Romance',
#  'Action|Adventure|Romance|Sci-Fi',
#  'Action|Adventure|Romance|Sci-Fi|Thriller',
#  'Action|Adventure|Romance|Thriller',
#  'Action|Adventure|Romance|War',
#  'Action|Adventure|Romance|Western',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Sci-Fi|Thriller',
#  'Action|Adventure|Thriller',
#  'Action|Adventure|Thriller|War',
#  'Action|Adventure|Western',
#  'Action|Animation|Comedy|Crime|Family',
#  'Action|Animation|Comedy|Family',
#  'Action|Animation|Comedy|Family|Fantasy',
#  'Action|Animation|Comedy|Family|Fantasy|Sci-Fi',
#  'Action|Animation|Comedy|Family|Sci-Fi',
#  'Action|Animation|Comedy|Sci-Fi',
#  'Action|Animation|Sci-Fi',
#  'Action|Animation|Sci-Fi|Thriller',
#  'Action|Biography|Crime|Drama',
#  'Action|Biography|Crime|Drama|Family|Fantasy',
#  'Action|Biography|Crime|Drama|Thriller',
#  'Action|Biography|Documentary|Sport',
#  'Action|Biography|Drama',
#  'Action|Biography|Drama|History',
#  'Action|Biography|Drama|History|Romance|War',
#  'Action|Biography|Drama|History|Romance|Western',
#  'Action|Biography|Drama|History|Thriller|War',
#  'Action|Biography|Drama|History|War',
#  'Action|Biography|Drama|Sport',
#  'Action|Biography|Drama|Thriller|War',
#  'Action|Comedy',
#  'Action|Comedy|Crime',
#  'Action|Comedy|Crime|Drama',
#  'Action|Comedy|Crime|Drama|Romance|Thriller',
#  'Action|Comedy|Crime|Drama|Thriller',
#  'Action|Comedy|Crime|Family',
#  'Action|Comedy|Crime|Fantasy',
#  'Action|Comedy|Crime|Fantasy|Horror|Mystery|Sci-Fi|Thriller',
#  'Action|Comedy|Crime|Music',
#  'Action|Comedy|Crime|Music|Romance|Thriller',
#  'Action|Comedy|Crime|Romance',
#  'Action|Comedy|Crime|Romance|Thriller',
#  'Action|Comedy|Crime|Sci-Fi|Thriller',
#  'Action|Comedy|Crime|Thriller',
#  'Action|Comedy|Crime|Western',
#  'Action|Comedy|Documentary',
#  'Action|Comedy|Drama',
#  'Action|Comedy|Drama|Family|Thriller',
#  'Action|Comedy|Drama|Music',
#  'Action|Comedy|Drama|Sci-Fi',
#  'Action|Comedy|Drama|Thriller',
#  'Action|Comedy|Drama|War',
#  'Action|Comedy|Drama|Western',
#  'Action|Comedy|Family',
#  'Action|Comedy|Family|Fantasy',
#  'Action|Comedy|Fantasy',
#  'Action|Comedy|Fantasy|Horror',
#  'Action|Comedy|Fantasy|Romance',
#  'Action|Comedy|Fantasy|Sci-Fi',
#  'Action|Comedy|Horror',
#  'Action|Comedy|Horror|Sci-Fi',
#  'Action|Comedy|Horror|Thriller',
#  'Action|Comedy|Music',
#  'Action|Comedy|Mystery',
#  'Action|Comedy|Mystery|Romance',
#  'Action|Comedy|Romance',
#  'Action|Comedy|Romance|Thriller',
#  'Action|Comedy|Sci-Fi',
#  'Action|Comedy|Sci-Fi|Sport',
#  'Action|Comedy|Sci-Fi|Thriller',
#  'Action|Comedy|Sci-Fi|Western',
#  'Action|Comedy|Sport',
#  'Action|Comedy|Thriller',
#  'Action|Comedy|War',
#  'Action|Crime',
#  'Action|Crime|Drama',
#  'Action|Crime|Drama|History|Western',
#  'Action|Crime|Drama|Mystery',
#  'Action|Crime|Drama|Mystery|Sci-Fi|Thriller',
#  'Action|Crime|Drama|Mystery|Thriller',
#  'Action|Crime|Drama|Romance|Thriller',
#  'Action|Crime|Drama|Sci-Fi|Thriller',
#  'Action|Crime|Drama|Sport',
#  'Action|Crime|Drama|Thriller',
#  'Action|Crime|Drama|Thriller|War',
#  'Action|Crime|Drama|Thriller|Western',
#  'Action|Crime|Drama|Western',
#  'Action|Crime|Fantasy|Romance|Thriller',
#  'Action|Crime|Fantasy|Thriller',
#  'Action|Crime|Horror|Sci-Fi|Thriller',
#  'Action|Crime|Horror|Thriller',
#  'Action|Crime|Mystery|Romance|Thriller',
#  'Action|Crime|Mystery|Sci-Fi|Thriller',
#  'Action|Crime|Mystery|Thriller',
#  'Action|Crime|Romance|Thriller',
#  'Action|Crime|Sci-Fi',
#  'Action|Crime|Sci-Fi|Thriller',
#  'Action|Crime|Sport|Thriller',
#  'Action|Crime|Thriller',
#  'Action|Drama',
#  'Action|Drama|Family|Sport',
#  'Action|Drama|Fantasy',
#  'Action|Drama|Fantasy|Horror|Thriller',
#  'Action|Drama|Fantasy|Horror|War',
#  'Action|Drama|Fantasy|Mystery|Sci-Fi|Thriller',
#  'Action|Drama|Fantasy|Mystery|Thriller',
#  'Action|Drama|Fantasy|Romance',
#  'Action|Drama|Fantasy|Sci-Fi',
#  'Action|Drama|Fantasy|Thriller|Western',
#  'Action|Drama|Fantasy|War',
#  'Action|Drama|History',
#  'Action|Drama|History|Romance|War',
#  'Action|Drama|History|Romance|War|Western',
#  'Action|Drama|History|Thriller',
#  'Action|Drama|History|Thriller|War',
#  'Action|Drama|History|War',
#  'Action|Drama|Horror|Thriller',
#  'Action|Drama|Music|Romance',
#  'Action|Drama|Mystery|Sci-Fi',
#  'Action|Drama|Mystery|Thriller',
#  'Action|Drama|Mystery|Thriller|War',
#  'Action|Drama|Romance',
#  'Action|Drama|Romance|Sci-Fi|Thriller',
#  'Action|Drama|Romance|Sport',
#  'Action|Drama|Romance|Thriller',
#  'Action|Drama|Romance|War',
#  'Action|Drama|Sci-Fi',
#  'Action|Drama|Sci-Fi|Sport',
#  'Action|Drama|Sci-Fi|Thriller',
#  'Action|Drama|Sport',
#  'Action|Drama|Sport|Thriller',
#  'Action|Drama|Thriller',
#  'Action|Drama|Thriller|War',
#  'Action|Drama|War',
#  'Action|Drama|Western',
#  'Action|Family|Fantasy|Musical',
#  'Action|Family|Sport',
#  'Action|Fantasy',
#  'Action|Fantasy|Horror',
#  'Action|Fantasy|Horror|Mystery',
#  'Action|Fantasy|Horror|Mystery|Thriller',
#  'Action|Fantasy|Horror|Sci-Fi',
#  'Action|Fantasy|Horror|Sci-Fi|Thriller',
#  'Action|Fantasy|Horror|Thriller',
#  'Action|Fantasy|Romance|Sci-Fi',
#  'Action|Fantasy|Thriller',
#  'Action|Fantasy|Western',
#  'Action|Horror',
#  'Action|Horror|Mystery|Sci-Fi|Thriller',
#  'Action|Horror|Mystery|Thriller',
#  'Action|Horror|Romance',
#  'Action|Horror|Romance|Sci-Fi|Thriller',
#  'Action|Horror|Sci-Fi',
#  'Action|Horror|Sci-Fi|Thriller',
#  'Action|Horror|Thriller',
#  'Action|Mystery|Sci-Fi|Thriller',
#  'Action|Mystery|Thriller',
#  'Action|Romance|Sport',
#  'Action|Romance|Thriller',
#  'Action|Sci-Fi',
#  'Action|Sci-Fi|Sport',
#  'Action|Sci-Fi|Thriller',
#  'Action|Sci-Fi|War',
#  'Action|Sport',
#  'Action|Thriller',
#  'Action|Thriller|Western',
#  'Action|War',
#  'Action|Western',
#  'Adventure',
#  'Adventure|Animation',
#  'Adventure|Animation|Biography|Drama|Family|Fantasy|Musical',
#  'Adventure|Animation|Comedy',
#  'Adventure|Animation|Comedy|Crime',
#  'Adventure|Animation|Comedy|Crime|Family',
#  'Adventure|Animation|Comedy|Drama|Family',
#  'Adventure|Animation|Comedy|Drama|Family|Fantasy',
#  'Adventure|Animation|Comedy|Drama|Family|Fantasy|Musical',
#  'Adventure|Animation|Comedy|Drama|Family|Fantasy|Romance',
#  'Adventure|Animation|Comedy|Drama|Family|Fantasy|Sci-Fi',
#  'Adventure|Animation|Comedy|Drama|Family|Musical',
#  'Adventure|Animation|Comedy|Family',
#  'Adventure|Animation|Comedy|Family|Fantasy',
#  'Adventure|Animation|Comedy|Family|Fantasy|Music',
#  'Adventure|Animation|Comedy|Family|Fantasy|Musical',
#  'Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance',
#  'Adventure|Animation|Comedy|Family|Fantasy|Romance',
#  'Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi',
#  'Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi|Sport',
#  'Adventure|Animation|Comedy|Family|Musical',
#  'Adventure|Animation|Comedy|Family|Romance',
#  'Adventure|Animation|Comedy|Family|Sci-Fi',
#  'Adventure|Animation|Comedy|Family|Sport',
#  'Adventure|Animation|Comedy|Family|War',
#  'Adventure|Animation|Comedy|Family|Western',
#  'Adventure|Animation|Comedy|Fantasy',
#  'Adventure|Animation|Comedy|Fantasy|Music|Romance',
#  'Adventure|Animation|Comedy|Fantasy|Romance',
#  'Adventure|Animation|Drama|Family|Fantasy',
#  'Adventure|Animation|Drama|Family|Fantasy|Musical|Mystery|Romance',
#  'Adventure|Animation|Drama|Family|History|Musical|Romance',
#  'Adventure|Animation|Drama|Family|Musical',
#  'Adventure|Animation|Family',
#  'Adventure|Animation|Family|Fantasy',
#  'Adventure|Animation|Family|Fantasy|Musical',
#  'Adventure|Animation|Family|Fantasy|Musical|War',
#  'Adventure|Animation|Family|Musical',
#  'Adventure|Animation|Family|Sci-Fi',
#  'Adventure|Animation|Family|Sport',
#  'Adventure|Animation|Family|Thriller',
#  'Adventure|Animation|Family|Western',
#  'Adventure|Animation|Fantasy',
#  'Adventure|Animation|Fantasy|Horror|Sci-Fi',
#  'Adventure|Animation|Sci-Fi',
#  'Adventure|Biography',
#  'Adventure|Biography|Crime|Drama|Western',
#  'Adventure|Biography|Documentary|Drama',
#  'Adventure|Biography|Drama',
#  'Adventure|Biography|Drama|History',
#  'Adventure|Biography|Drama|History|Sport|Thriller',
#  'Adventure|Biography|Drama|History|War',
#  'Adventure|Biography|Drama|Horror|Thriller',
#  'Adventure|Biography|Drama|Romance',
#  'Adventure|Biography|Drama|Thriller',
#  'Adventure|Biography|Drama|War',
#  'Adventure|Comedy',
#  'Adventure|Comedy|Crime',
#  'Adventure|Comedy|Crime|Drama',
#  'Adventure|Comedy|Crime|Drama|Family',
#  'Adventure|Comedy|Crime|Family|Musical',
#  'Adventure|Comedy|Crime|Family|Mystery',
#  'Adventure|Comedy|Crime|Romance',
#  'Adventure|Comedy|Drama',
#  'Adventure|Comedy|Drama|Family',
#  'Adventure|Comedy|Drama|Family|Fantasy',
#  'Adventure|Comedy|Drama|Family|Mystery',
#  'Adventure|Comedy|Drama|Family|Romance',
#  'Adventure|Comedy|Drama|Family|Sport',
#  'Adventure|Comedy|Drama|Fantasy',
#  'Adventure|Comedy|Drama|Fantasy|Musical',
#  'Adventure|Comedy|Drama|Fantasy|Romance',
#  'Adventure|Comedy|Drama|Music',
#  'Adventure|Comedy|Drama|Romance',
#  'Adventure|Comedy|Drama|Romance|Sci-Fi',
#  'Adventure|Comedy|Drama|Romance|Thriller|War',
#  'Adventure|Comedy|Family',
#  'Adventure|Comedy|Family|Fantasy',
#  'Adventure|Comedy|Family|Fantasy|Horror',
#  'Adventure|Comedy|Family|Fantasy|Horror|Mystery',
#  'Adventure|Comedy|Family|Fantasy|Musical',
#  'Adventure|Comedy|Family|Fantasy|Music|Sci-Fi',
#  'Adventure|Comedy|Family|Fantasy|Romance|Sport',
#  'Adventure|Comedy|Family|Fantasy|Sci-Fi',
#  'Adventure|Comedy|Family|Musical',
#  'Adventure|Comedy|Family|Music|Romance',
#  'Adventure|Comedy|Family|Mystery|Sci-Fi',
#  'Adventure|Comedy|Family|Romance',
#  'Adventure|Comedy|Family|Romance|Sci-Fi',
#  'Adventure|Comedy|Family|Sci-Fi',
#  'Adventure|Comedy|Family|Sport',
#  'Adventure|Comedy|Fantasy',
#  'Adventure|Comedy|Fantasy|Music|Sci-Fi',
#  'Adventure|Comedy|Fantasy|Sci-Fi',
#  'Adventure|Comedy|History',
#  'Adventure|Comedy|History|Romance',
#  'Adventure|Comedy|Horror',
#  'Adventure|Comedy|Horror|Sci-Fi',
#  'Adventure|Comedy|Musical|Romance',
#  'Adventure|Comedy|Music|Sci-Fi',
#  'Adventure|Comedy|Mystery',
#  'Adventure|Comedy|Romance',
#  'Adventure|Comedy|Romance|Sci-Fi',
#  'Adventure|Comedy|Sci-Fi',
#  'Adventure|Comedy|Sci-Fi|Western',
#  'Adventure|Comedy|Sport',
#  'Adventure|Comedy|Western',
#  'Adventure|Crime|Drama',
#  'Adventure|Crime|Drama|Mystery|Thriller',
#  'Adventure|Crime|Drama|Mystery|Western',
#  'Adventure|Crime|Drama|Romance',
#  'Adventure|Crime|Drama|Thriller',
#  'Adventure|Crime|Drama|Western',
#  'Adventure|Crime|Mystery|Sci-Fi|Thriller',
#  'Adventure|Crime|Thriller',
#  'Adventure|Documentary',
#  'Adventure|Documentary|Drama|Sport',
#  'Adventure|Documentary|Short',
#  'Adventure|Drama',
#  'Adventure|Drama|Family',
#  'Adventure|Drama|Family|Fantasy',
#  'Adventure|Drama|Family|Mystery',
#  'Adventure|Drama|Family|Romance|Western',
#  'Adventure|Drama|Fantasy',
#  'Adventure|Drama|Fantasy|Mystery',
#  'Adventure|Drama|Fantasy|Mystery|Thriller',
#  'Adventure|Drama|Fantasy|Romance',
#  'Adventure|Drama|Fantasy|Thriller|Western',
#  'Adventure|Drama|History',
#  'Adventure|Drama|History|Romance',
#  'Adventure|Drama|History|Romance|Thriller|War',
#  'Adventure|Drama|History|Romance|War',
#  'Adventure|Drama|History|Thriller|War',
#  'Adventure|Drama|History|War',
#  'Adventure|Drama|Horror|Mystery|Thriller',
#  'Adventure|Drama|Horror|Thriller',
#  'Adventure|Drama|Mystery',
#  'Adventure|Drama|Mystery|Sci-Fi|Thriller',
#  'Adventure|Drama|Romance',
#  'Adventure|Drama|Romance|War',
#  'Adventure|Drama|Romance|Western',
#  'Adventure|Drama|Sci-Fi',
#  'Adventure|Drama|Sci-Fi|Thriller',
#  'Adventure|Drama|Thriller',
#  'Adventure|Drama|Thriller|War',
#  'Adventure|Drama|Thriller|Western',
#  'Adventure|Drama|War',
#  'Adventure|Drama|Western',
#  'Adventure|Family',
#  'Adventure|Family|Fantasy',
#  'Adventure|Family|Fantasy|Horror|Mystery',
#  'Adventure|Family|Fantasy|Musical',
#  'Adventure|Family|Fantasy|Music|Musical',
#  'Adventure|Family|Fantasy|Mystery',
#  'Adventure|Family|Fantasy|Romance',
#  'Adventure|Family|Fantasy|Sci-Fi',
#  'Adventure|Family|Romance',
#  'Adventure|Family|Sci-Fi',
#  'Adventure|Family|Sport',
#  'Adventure|Fantasy',
#  'Adventure|Fantasy|Horror|Mystery|Thriller',
#  'Adventure|Fantasy|Mystery',
#  'Adventure|Fantasy|Mystery|Thriller',
#  'Adventure|Fantasy|Thriller',
#  'Adventure|Horror',
#  'Adventure|Horror|Mystery',
#  'Adventure|Horror|Thriller',
#  'Adventure|Mystery|Sci-Fi',
#  'Adventure|Mystery|Thriller',
#  'Adventure|Sci-Fi',
#  'Adventure|Sci-Fi|Thriller',
#  'Adventure|War|Western',
#  'Animation',
#  'Animation|Biography|Documentary|Drama|History|War',
#  'Animation|Biography|Drama|War',
#  'Animation|Comedy',
#  'Animation|Comedy|Crime|Drama|Family',
#  'Animation|Comedy|Drama',
#  'Animation|Comedy|Drama|Family|Musical',
#  'Animation|Comedy|Drama|Fantasy|Sci-Fi',
#  'Animation|Comedy|Drama|Romance',
#  'Animation|Comedy|Family',
#  'Animation|Comedy|Family|Fantasy',
#  'Animation|Comedy|Family|Fantasy|Music',
#  'Animation|Comedy|Family|Fantasy|Musical',
#  'Animation|Comedy|Family|Fantasy|Musical|Romance',
#  'Animation|Comedy|Family|Fantasy|Mystery',
#  'Animation|Comedy|Family|Fantasy|Sci-Fi',
#  'Animation|Comedy|Family|Horror|Sci-Fi',
#  'Animation|Comedy|Family|Musical',
#  'Animation|Comedy|Family|Music|Romance',
#  'Animation|Comedy|Family|Music|Western',
#  'Animation|Comedy|Family|Mystery|Sci-Fi',
#  'Animation|Comedy|Family|Romance',
#  'Animation|Comedy|Family|Sci-Fi',
#  'Animation|Comedy|Family|Sport',
#  'Animation|Comedy|Fantasy',
#  'Animation|Comedy|Fantasy|Musical',
#  'Animation|Drama',
#  'Animation|Drama|Family',
#  'Animation|Drama|Family|Fantasy',
#  'Animation|Drama|Family|Fantasy|Musical|Romance',
#  'Animation|Drama|Family|Musical|Romance',
#  'Animation|Drama|Mystery|Sci-Fi|Thriller',
#  'Animation|Family',
#  'Animation|Family|Fantasy',
#  'Animation|Family|Fantasy|Music',
#  'Animation|Family|Fantasy|Musical',
#  'Animation|Family|Fantasy|Musical|Romance',
#  'Animation|Family|Fantasy|Mystery',
#  'Biography',
#  'Biography|Comedy|Crime|Drama',
#  'Biography|Comedy|Crime|Drama|Romance',
#  'Biography|Comedy|Crime|Drama|Romance|Thriller',
#  'Biography|Comedy|Documentary',
#  'Biography|Comedy|Drama',
#  'Biography|Comedy|Drama|Family|Romance',
#  'Biography|Comedy|Drama|Family|Sport',
#  'Biography|Comedy|Drama|History',
#  'Biography|Comedy|Drama|History|Music',
#  'Biography|Comedy|Drama|History|Music|Musical',
#  'Biography|Comedy|Drama|Music',
#  'Biography|Comedy|Drama|Music|Romance',
#  'Biography|Comedy|Drama|Romance',
#  'Biography|Comedy|Drama|Sport',
#  'Biography|Comedy|Musical',
#  'Biography|Comedy|Musical|Romance|Western',
#  'Biography|Comedy|Romance',
#  'Biography|Crime|Documentary|History',
#  'Biography|Crime|Documentary|History|Thriller',
#  'Biography|Crime|Drama',
#  'Biography|Crime|Drama|History',
#  'Biography|Crime|Drama|History|Music',
#  'Biography|Crime|Drama|History|Romance',
#  'Biography|Crime|Drama|History|Thriller',
#  'Biography|Crime|Drama|History|Western',
#  'Biography|Crime|Drama|Music',
#  'Biography|Crime|Drama|Mystery|Thriller',
#  'Biography|Crime|Drama|Romance',
#  'Biography|Crime|Drama|Romance|Thriller',
#  'Biography|Crime|Drama|Thriller',
#  'Biography|Crime|Drama|War',
#  'Biography|Crime|Drama|Western',
#  'Biography|Documentary',
#  'Biography|Documentary|Drama',
#  'Biography|Documentary|History',
#  'Biography|Documentary|Music',
#  'Biography|Documentary|Sport',
#  'Biography|Drama',
#  'Biography|Drama|Family',
#  'Biography|Drama|Family|History|Sport',
#  'Biography|Drama|Family|Musical|Romance',
#  'Biography|Drama|Family|Sport',
#  'Biography|Drama|Fantasy|History',
#  'Biography|Drama|History',
#  'Biography|Drama|History|Music',
#  'Biography|Drama|History|Musical',
#  'Biography|Drama|History|Romance',
#  'Biography|Drama|History|Sport',
#  'Biography|Drama|History|Thriller',
#  'Biography|Drama|History|Thriller|War',
#  'Biography|Drama|History|War',
#  'Biography|Drama|Music',
#  'Biography|Drama|Music|Musical',
#  'Biography|Drama|Music|Romance',
#  'Biography|Drama|Romance',
#  'Biography|Drama|Romance|Sport',
#  'Biography|Drama|Romance|War',
#  'Biography|Drama|Romance|Western',
#  'Biography|Drama|Sport',
#  'Biography|Drama|Sport|War',
#  'Biography|Drama|Thriller',
#  'Biography|Drama|Thriller|War',
#  'Biography|Drama|War',
#  'Comedy',
#  'Comedy|Crime',
#  'Comedy|Crime|Drama',
#  'Comedy|Crime|Drama|Horror|Mystery|Thriller',
#  'Comedy|Crime|Drama|Horror|Thriller',
#  'Comedy|Crime|Drama|Music|Romance',
#  'Comedy|Crime|Drama|Mystery',
#  'Comedy|Crime|Drama|Mystery|Romance',
#  'Comedy|Crime|Drama|Mystery|Thriller',
#  'Comedy|Crime|Drama|Romance',
#  'Comedy|Crime|Drama|Romance|Thriller',
#  'Comedy|Crime|Drama|Sci-Fi',
#  'Comedy|Crime|Drama|Thriller',
#  'Comedy|Crime|Drama|Thriller|War',
#  'Comedy|Crime|Family',
#  'Comedy|Crime|Family|Mystery|Romance|Thriller',
#  'Comedy|Crime|Family|Romance',
#  'Comedy|Crime|Family|Sci-Fi',
#  'Comedy|Crime|Horror',
#  'Comedy|Crime|Horror|Thriller',
#  'Comedy|Crime|Music',
#  'Comedy|Crime|Musical',
#  'Comedy|Crime|Musical|Mystery',
#  'Comedy|Crime|Musical|Romance',
#  'Comedy|Crime|Mystery',
#  'Comedy|Crime|Mystery|Romance',
#  'Comedy|Crime|Romance',
#  'Comedy|Crime|Romance|Thriller',
#  'Comedy|Crime|Sci-Fi|Thriller',
#  'Comedy|Crime|Sport',
#  'Comedy|Crime|Thriller',
#  'Comedy|Documentary',
#  'Comedy|Documentary|Drama',
#  'Comedy|Documentary|Drama|Fantasy|Mystery|Sci-Fi',
#  'Comedy|Documentary|Music',
#  'Comedy|Documentary|War',
#  'Comedy|Drama',
#  'Comedy|Drama|Family',
#  'Comedy|Drama|Family|Fantasy',
#  'Comedy|Drama|Family|Fantasy|Musical',
#  'Comedy|Drama|Family|Fantasy|Romance',
#  'Comedy|Drama|Family|Fantasy|Sci-Fi',
#  'Comedy|Drama|Family|Musical',
#  'Comedy|Drama|Family|Music|Musical|Romance',
#  'Comedy|Drama|Family|Music|Romance',
#  'Comedy|Drama|Family|Romance',
#  'Comedy|Drama|Family|Sport',
#  'Comedy|Drama|Fantasy',
#  'Comedy|Drama|Fantasy|Horror',
#  'Comedy|Drama|Fantasy|Music|Romance',
#  'Comedy|Drama|Fantasy|Romance',
#  'Comedy|Drama|History|Musical|Romance',
#  'Comedy|Drama|History|Romance',
#  'Comedy|Drama|Horror',
#  'Comedy|Drama|Horror|Romance',
#  'Comedy|Drama|Horror|Sci-Fi',
#  'Comedy|Drama|Horror|Sci-Fi|Thriller',
#  'Comedy|Drama|Music',
#  'Comedy|Drama|Musical',
#  'Comedy|Drama|Musical|Romance',
#  'Comedy|Drama|Musical|Romance|War',
#  'Comedy|Drama|Musical|Romance|Western',
#  'Comedy|Drama|Music|Musical',
#  'Comedy|Drama|Music|Musical|Romance',
#  'Comedy|Drama|Music|Romance',
#  'Comedy|Drama|Music|War',
#  'Comedy|Drama|Mystery|Romance|Thriller',
#  'Comedy|Drama|Mystery|Romance|Thriller|War',
#  'Comedy|Drama|Romance',
#  'Comedy|Drama|Romance|Sci-Fi',
#  'Comedy|Drama|Romance|Sport',
#  'Comedy|Drama|Romance|Thriller',
#  'Comedy|Drama|Romance|War',
#  'Comedy|Drama|Romance|Western',
#  'Comedy|Drama|Sci-Fi',
#  'Comedy|Drama|Sport',
#  'Comedy|Drama|Thriller',
#  'Comedy|Drama|War',
#  'Comedy|Family',
#  'Comedy|Family|Fantasy',
#  'Comedy|Family|Fantasy|Horror|Mystery',
#  'Comedy|Family|Fantasy|Musical',
#  'Comedy|Family|Fantasy|Music|Romance',
#  'Comedy|Family|Fantasy|Romance',
#  'Comedy|Family|Fantasy|Sci-Fi',
#  'Comedy|Family|Fantasy|Sport',
#  'Comedy|Family|Music',
#  'Comedy|Family|Musical|Romance',
#  'Comedy|Family|Musical|Romance|Short',
#  'Comedy|Family|Music|Musical',
#  'Comedy|Family|Music|Romance',
#  'Comedy|Family|Romance',
#  'Comedy|Family|Romance|Sci-Fi',
#  'Comedy|Family|Romance|Sport',
#  'Comedy|Family|Sci-Fi',
#  'Comedy|Family|Sport',
#  'Comedy|Fantasy',
#  'Comedy|Fantasy|Horror',
#  'Comedy|Fantasy|Horror|Musical',
#  'Comedy|Fantasy|Horror|Mystery',
#  'Comedy|Fantasy|Horror|Romance',
#  'Comedy|Fantasy|Horror|Thriller',
#  'Comedy|Fantasy|Musical|Sci-Fi',
#  'Comedy|Fantasy|Mystery',
#  'Comedy|Fantasy|Romance',
#  'Comedy|Fantasy|Sci-Fi',
#  'Comedy|Fantasy|Thriller',
#  'Comedy|History',
#  'Comedy|Horror',
#  'Comedy|Horror|Musical',
#  'Comedy|Horror|Musical|Sci-Fi',
#  'Comedy|Horror|Mystery',
#  'Comedy|Horror|Mystery|Thriller',
#  'Comedy|Horror|Romance',
#  'Comedy|Horror|Sci-Fi',
#  'Comedy|Horror|Sci-Fi|Thriller',
#  'Comedy|Horror|Thriller',
#  'Comedy|Music',
#  'Comedy|Musical',
#  'Comedy|Musical|Romance',
#  'Comedy|Music|Romance',
#  'Comedy|Music|Sci-Fi',
#  'Comedy|Mystery|Romance',
#  'Comedy|Mystery|Sci-Fi|Thriller',
#  'Comedy|Mystery|Thriller',
#  'Comedy|Romance',
#  'Comedy|Romance|Sci-Fi',
#  'Comedy|Romance|Sci-Fi|Thriller',
#  'Comedy|Romance|Sport',
#  'Comedy|Romance|Thriller',
#  'Comedy|Sci-Fi',
#  'Comedy|Sci-Fi|Thriller',
#  'Comedy|Short',
#  'Comedy|Sport',
#  'Comedy|Thriller',
#  'Comedy|War',
#  'Comedy|Western',
#  'Crime|Documentary',
#  'Crime|Documentary|Drama',
#  'Crime|Documentary|News',
#  'Crime|Documentary|War',
#  'Crime|Drama',
#  'Crime|Drama|Fantasy',
#  'Crime|Drama|Fantasy|Mystery',
#  'Crime|Drama|Fantasy|Romance',
#  'Crime|Drama|Film-Noir',
#  'Crime|Drama|Film-Noir|Mystery|Thriller',
#  'Crime|Drama|History',
#  'Crime|Drama|History|Mystery|Thriller',
#  'Crime|Drama|History|Romance',
#  'Crime|Drama|Horror',
#  'Crime|Drama|Horror|Mystery|Thriller',
#  'Crime|Drama|Horror|Thriller',
#  'Crime|Drama|Music',
#  'Crime|Drama|Musical',
#  'Crime|Drama|Musical|Romance',
#  'Crime|Drama|Musical|Romance|Thriller',
#  'Crime|Drama|Music|Mystery|Thriller',
#  'Crime|Drama|Music|Romance',
#  'Crime|Drama|Music|Thriller',
#  'Crime|Drama|Mystery',
#  'Crime|Drama|Mystery|Romance',
#  'Crime|Drama|Mystery|Romance|Thriller',
#  'Crime|Drama|Mystery|Sci-Fi|Thriller',
#  'Crime|Drama|Mystery|Thriller',
#  'Crime|Drama|Mystery|Thriller|Western',
#  'Crime|Drama|Romance',
#  'Crime|Drama|Romance|Thriller',
#  'Crime|Drama|Sci-Fi|Thriller',
#  'Crime|Drama|Sport',
#  'Crime|Drama|Thriller',
#  'Crime|Drama|Western',
#  'Crime|Fantasy|Horror',
#  'Crime|Film-Noir|Thriller',
#  'Crime|Horror',
#  'Crime|Horror|Music|Thriller',
#  'Crime|Horror|Mystery|Thriller',
#  'Crime|Horror|Thriller',
#  'Crime|Mystery|Thriller',
#  'Crime|Romance|Thriller',
#  'Crime|Thriller',
#  'Crime|Thriller|War',
#  'Documentary',
#  'Documentary|Drama',
#  'Documentary|Drama|History|News',
#  'Drama|Mystery|Romance|War',
#  'Drama|Mystery|Sci-Fi',
#  'Drama|Mystery|Sci-Fi|Thriller',
#  'Drama|Mystery|Thriller',
#  'Drama|Mystery|War',
#  'Drama|Romance',
#  'Drama|Romance|Sci-Fi',
#  'Drama|Romance|Sci-Fi|Thriller',
#  'Drama|Romance|Sport',
#  'Drama|Romance|Thriller',
#  'Drama|Romance|War',
#  'Drama|Romance|War|Western',
#  'Drama|Romance|Western',
#  'Drama|Sci-Fi',
#  'Drama|Sci-Fi|Thriller',
#  'Drama|Sport',
#  'Drama|Thriller',
#  'Drama|Thriller|War',
#  'Drama|War',
#  'Drama|War|Western',
#  'Drama|Western',
#  'Family',
#  'Family|Fantasy|Music',
#  'Family|Fantasy|Musical',
#  'Family|Musical',
#  'Family|Music|Romance',
#  'Family|Sci-Fi',
#  'Fantasy',
#  'Fantasy|Horror',
#  'Fantasy|Horror|Mystery',
#  'Fantasy|Horror|Mystery|Romance',
#  'Fantasy|Horror|Mystery|Thriller',
#  'Fantasy|Horror|Romance',
#  'Fantasy|Horror|Romance|Thriller',
#  'Fantasy|Horror|Sci-Fi',
#  'Fantasy|Horror|Thriller',
#  'Fantasy|Mystery|Romance|Sci-Fi|Thriller',
#  'Fantasy|Mystery|Thriller',
#  'Fantasy|Romance',
#  'Fantasy|Thriller',
#  'Film-Noir|Mystery|Romance|Thriller',
#  'Game-Show|Reality-TV|Romance',
#  'History',
#  'Horror',
#  'Horror|Musical',
#  'Horror|Musical|Sci-Fi',
#  'Horror|Mystery',
#  'Horror|Mystery|Sci-Fi',
#  'Horror|Mystery|Sci-Fi|Thriller',
#  'Horror|Mystery|Thriller',
#  'Horror|Romance|Sci-Fi',
#  'Horror|Romance|Thriller',
#  'Horror|Sci-Fi',
#  'Horror|Sci-Fi|Short|Thriller',
#  'Horror|Sci-Fi|Thriller',
#  'Horror|Thriller',
#  'Music',
#  'Musical',
#  'Musical|Romance',
#  'Mystery|Romance|Sci-Fi|Thriller',
#  'Mystery|Romance|Thriller',
#  'Mystery|Sci-Fi|Thriller',
#  'Mystery|Thriller',
#  'Mystery|Western',
#  'Romance',
#  'Romance|Sci-Fi|Thriller',
#  'Romance|Short',
#  'Sci-Fi',
#  'Sci-Fi|Thriller',
#  'Thriller',
#  'Thriller|War',
#  'Thriller|Western',
#  'Western',
#  'unknown']

# %% [markdown]
# Мне в таком списке трудно заметить различия, так что будем считать, что жарны верны

# %%
sorted (df['language'].unique())
# Out:
# ['Aboriginal',
#  'Arabic',
#  'Aramaic',
#  'Bosnian',
#  'Cantonese',
#  'Chinese',
#  'Czech',
#  'Danish',
#  'Dari',
#  'Dutch',
#  'Dzongkha',
#  'English',
#  'Filipino',
#  'French',
#  'German',
#  'Greek',
#  'Hebrew',
#  'Hindi',
#  'Hungarian',
#  'Icelandic',
#  'Indonesian',
#  'Italian',
#  'Japanese',
#  'Kannada',
#  'Kazakh',
#  'Korean',
#  'Mandarin',
#  'Maya',
#  'Mongolian',
#  'Norwegian',
#  'Panjabi',
#  'Persian',
#  'Polish',
#  'Portuguese',
#  'Romanian',
#  'Russian',
#  'Slovenian',
#  'Spanish',
#  'Swahili',
#  'Swedish',
#  'Tamil',
#  'Telugu',
#  'Thai',
#  'Urdu',
#  'Vietnamese',
#  'Zulu',
#  'unknown']

# %%
sorted (df['country'].unique())
# Out:
# ['Afghanistan',
#  'Argentina',
#  'Aruba',
#  'Australia',
#  'Bahamas',
#  'Belgium',
#  'Brazil',
#  'Bulgaria',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chile',
#  'China',
#  'Colombia',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Egypt',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Libya',
#  'Mexico',
#  'Netherlands',
#  'New Line',
#  'New Zealand',
#  'Nigeria',
#  'Norway',
#  'Official site',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Romania',
#  'Russia',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'South Korea',
#  'Soviet Union',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Thailand',
#  'Turkey',
#  'UK',
#  'USA',
#  'United Arab Emirates',
#  'West Germany',
#  'unknown']

# %% [markdown]
# Будем считать, что СССР и Россия это разные страны тк относятся они к разному периоду времени.
# А вот Западная Германия и Германия будут одной страной, тк в списке отсутствует Восточная.

# %%
sorted (df['color'].unique())
# Out:
# [' Black and White',
#  ' Black and White,Eugène Lourié,67,80,7,21,Cecil Kellaway,57,5000000,Adventure|Horror|Sci-Fi,Kenneth Tobey,"The Beast from 20,000 Fathoms\xa0",4812,205,Ross Elliott,0,arctic|beast|dinosaur|monster|rhedosaurus,http://www.imdb.com/title/tt0045546/?ref_=fn_tt_tt_1,88,English,USA,Approved,210000,1953,40,6.7,1.37,465;',
#  ' Black and White,George Clooney,351,93,0,566,Tate Donovan,21000,31501218,Biography|Drama|History,Robert Downey Jr.,"Good Night, and Good Luck.\xa0",84070,22745,Alex Borstein,0,cbs|expose|fear|paranoia|reporter,http://www.imdb.com/title/tt0433383/?ref_=fn_tt_tt_1,526,English,USA,PG,7500000,2005,650,7.5,1.85,0;',
#  ',Christopher Barnard,,22,0,,,5,,Comedy,Mathew Buck,"10,000 B.C.\xa0            ",6,5,,0,,http://www.imdb.com/title/tt1869849/?ref_=fn_tt_tt_1,,,,,,,,7.2,,0;',
#  'Color',
#  'Color,,,43,,211,Jenni \'Jwoww\' Farley,341,,Comedy|Drama|Reality-TV|Romance,Nicole \'Snooki\' Polizzi,"Gone, Baby, Gone\xa0            ",29,1462,Paul \'Pauly D\' DelVecchio,1,lifestyle,http://www.imdb.com/title/tt1697237/?ref_=fn_tt_tt_1,,English,,TV-14,,,230,6.6,1.33,0;',
#  'Color,,20,22,,271,Soleil Moon Frye,870,,Comedy|Family|Fantasy,Nate Richert,"Sabrina, the Teenage Witch\xa0            ",24420,2433,Caroline Rhea,1,female protagonist|hereditary gift of witchcraft|magic|supernatural|witch,http://www.imdb.com/title/tt0115341/?ref_=fn_tt_tt_1,94,English,USA,TV-G,3000000,,558,6.6,1.33,990;',
#  'Color,Adam Brooks,160,112,20,61,Sakina Jaffrey,16000,31973840,Comedy|Drama|Romance,Ryan Reynolds,"Definitely, Maybe\xa0",127760,16289,Paulina Gerzon,5,college|daughter|girl|sex|wisconsin,http://www.imdb.com/title/tt0832266/?ref_=fn_tt_tt_1,168,English,Germany,PG-13,,2008,109,7.2,2.35,0;',
#  'Color,Léa Pool,23,97,4,,,,24784,Documentary,,"Pink Ribbons, Inc.\xa0",591,0,,0,breast cancer|comma in title|period in title|punctuation in title|three word title,http://www.imdb.com/title/tt2035599/?ref_=fn_tt_tt_1,10,English,Canada,Not Rated,1200000,2011,,7.4,,5000;',
#  'Color,Malcolm D. Lee,76,114,92,436,Mike Epps,940,42168445,Comedy|Drama|Romance,Mo\'Nique,"Welcome Home, Roscoe Jenkins\xa0",10791,3565,Cedric the Entertainer,3,african american protagonist|comma in title|four word title|name in title|talk show host,http://www.imdb.com/title/tt0494652/?ref_=fn_tt_tt_1,39,English,USA,PG-13,35000000,2008,706,5.3,1.85,464;',
#  'Color,Mark Illsley,77,98,3,327,Illeana Douglas,349,1943649,Comedy|Crime|Romance,Ally Walker,"Happy, Texas\xa0",8697,2095,Jeremy Northam,3,banker|beauty pageant|escaped convict|gay|pageant,http://www.imdb.com/title/tt0162360/?ref_=fn_tt_tt_1,122,English,USA,PG-13,1700000,1999,347,6.3,1.85,374;',
#  'Color,Martin Scorsese,59,136,17000,213,Liza Minnelli,22000,,Drama|Music|Musical|Romance,Robert De Niro,"New York, New York\xa0",13548,23378,Mary Kay Place,0,love|musician|saxophonist|singer|songwriter,http://www.imdb.com/title/tt0076451/?ref_=fn_tt_tt_1,75,English,USA,PG,14000000,1977,740,6.7,1.66,932;',
#  'Color,Martyn Pick,19,76,4,151,Steven Waddington,722,,Action|Animation|Fantasy|Horror|Mystery|Sci-Fi|Thriller,Sean Pertwee,"Ultramarines: A Warhammer 40,000 Movie\xa0",4990,1254,Donald Sumpter,0,grimdark|mutilated corpse|space marine|ultramarines|warhammer 40k,http://www.imdb.com/title/tt1679332/?ref_=fn_tt_tt_1,64,English,UK,R,,2010,212,5.7,1.85,0;',
#  'Color,Melville Shavelson,8,111,5,559,Tom Bosley,6000,,Comedy|Family,Lucille Ball,"Yours, Mine and Ours\xa0",5888,7493,Tim Matheson,0,nurse|parent|sibling|widow|widower,http://www.imdb.com/title/tt0063829/?ref_=fn_tt_tt_1,61,English,USA,Unrated,2500000,1968,584,7.2,1.85,0;',
#  'Color,Miguel Arteta,119,81,44,3000,Steve Carell,35000,66950483,Comedy|Family,Bella Thorne,"Alexander and the Terrible, Horrible, No Good, Very Bad Day\xa0",29738,47677,Jennifer Garner,6,bad day|based on book|birthday|job interview|long title,http://www.imdb.com/title/tt1698641/?ref_=fn_tt_tt_1,85,English,USA,PG,28000000,2014,7000,6.2,2.39,12000;',
#  'Color,Neal Brennan,83,89,23,503,Noureen DeWulf,839,15102127,Comedy,Rob Riggle,"The Goods: Live Hard, Sell Hard\xa0",17790,3973,Charles Napier,5,fourth of july|looking at one\'s self in a mirror|mirror|sex toy|young version of character,http://www.imdb.com/title/tt1092633/?ref_=fn_tt_tt_1,59,English,USA,R,,2009,700,5.8,1.85,0;',
#  'Color,Stanley Kramer,61,197,176,760,Sid Caesar,924,46300000,Action|Adventure|Comedy|Crime,Jonathan Winters,"It\'s a Mad, Mad, Mad, Mad World\xa0",29323,4109,Spencer Tracy,0,california|desert|dying words|money|race,http://www.imdb.com/title/tt0057193/?ref_=fn_tt_tt_1,344,English,USA,Approved,9400000,1963,898,7.6,2.76,0;',
#  'Color,Stephen Langford,2,82,7,50,Gabriela Castillo,143,,Family,Kevin P. Farley,"Dude, Where\'s My Dog?!\xa0",73,417,Brandon Middleton,0,,http://www.imdb.com/title/tt3109200/?ref_=fn_tt_tt_1,4,English,USA,PG,20000,2014,134,3.2,1.85,178;',
#  'Color,Steven Soderbergh,58,100,0,65,Laura San Giacomo,828,24741700,Drama,Peter Gallagher,"Sex, Lies, and Videotape\xa0",37785,1431,Steven Brill,2,affair|interview|marriage|sex|videotape,http://www.imdb.com/title/tt0098724/?ref_=fn_tt_tt_1,95,English,USA,R,1200000,1989,531,7.2,1.85,2000;',
#  'Color,Stuart Beattie,308,92,72,568,Kevin Grevioux,623,19059018,Action|Fantasy|Sci-Fi|Thriller,Caitlin Stasey,"I, Frankenstein\xa0",65709,3165,Miranda Otto,0,army|creature|demon|frankenstein|gargoyle,http://www.imdb.com/title/tt1418377/?ref_=fn_tt_tt_1,194,English,Australia,PG-13,65000000,2014,593,5.1,2.35,15000;',
#  'Color,Sut Jhally,16,80,3,0,Seth Ackerman,103,,Documentary,Noam Chomsky,"Peace, Propaganda & the Promised Land\xa0",496,103,Arik Ascherman,3,arab israeli conflict|israel|media|middle east|palestine,http://www.imdb.com/title/tt0428959/?ref_=fn_tt_tt_1,13,English,USA,,70000,2004,0,8.3,,110;',
#  'Color,Taylor Hackford,12,330,138,672,Jesse Borrego,848,4496583,Crime|Drama,Delroy Lindo,"Blood In, Blood Out\xa0",23181,3227,Raymond Cruz,2,1970s|1980s|barrio|gang war|mexican,http://www.imdb.com/title/tt0106469/?ref_=fn_tt_tt_1,129,English,USA,R,35000000,1993,674,8.0,1.66,6000;',
#  'Color,Tim McCanlies,15,97,23,326,Michael O\'Neill,982,565592,Comedy|Drama|Family,Ethan Embry,"Dancer, Texas Pop. 81\xa0",2189,2580,Alexandra Holden,0,best friend|friendship|population|state in title|texas,http://www.imdb.com/title/tt0118925/?ref_=fn_tt_tt_1,63,English,USA,PG,,1998,599,6.8,1.85,500;',
#  'Color,Yimou Zhang,101,95,611,3,Ni Yan,9,190666,Comedy|Drama,Honglei Sun,"A Woman, a Gun and a Noodle Shop\xa0",2410,18,Dahong Ni,1,betrayal|husband wife relationship|murder|noodles|salary,http://www.imdb.com/title/tt1428556/?ref_=fn_tt_tt_1,20,Mandarin,China,R,,2009,4,5.7,2.35,784;',
#  'Colour',
#  'color',
#  'unknown']

# %% [markdown]
# Мне не ясно почему в "Цвет" записаны сразу все значения в некоторых местах, но приведем их к одному.

# %% [markdown]
# Начнем исправлять значения.
# Для этого создадим функцию которая это исполняет.

# %%
def replace_wrong (column, wrong, correct):
    for wrong in wrong:
        df[column] = df[column].replace(wrong, correct)

# %% [markdown]
# И начнем заменять

# %%
duplicates = ['West Germany']
name = 'Germany'
column = 'country'
replace_wrong(column, duplicates, name)

# %%
duplicates = [' Black and White',
 ' Black and White,Eugène Lourié,67,80,7,21,Cecil Kellaway,57,5000000,Adventure|Horror|Sci-Fi,Kenneth Tobey,"The Beast from 20,000 Fathoms\xa0",4812,205,Ross Elliott,0,arctic|beast|dinosaur|monster|rhedosaurus,http://www.imdb.com/title/tt0045546/?ref_=fn_tt_tt_1,88,English,USA,Approved,210000,1953,40,6.7,1.37,465;',
 ' Black and White,George Clooney,351,93,0,566,Tate Donovan,21000,31501218,Biography|Drama|History,Robert Downey Jr.,"Good Night, and Good Luck.\xa0",84070,22745,Alex Borstein,0,cbs|expose|fear|paranoia|reporter,http://www.imdb.com/title/tt0433383/?ref_=fn_tt_tt_1,526,English,USA,PG,7500000,2005,650,7.5,1.85,0;']
name = 'Black and White'
column = 'color'
replace_wrong(column, duplicates, name)

# %%
duplicates = ['Color',
 'Color,,,43,,211,Jenni \'Jwoww\' Farley,341,,Comedy|Drama|Reality-TV|Romance,Nicole \'Snooki\' Polizzi,"Gone, Baby, Gone\xa0            ",29,1462,Paul \'Pauly D\' DelVecchio,1,lifestyle,http://www.imdb.com/title/tt1697237/?ref_=fn_tt_tt_1,,English,,TV-14,,,230,6.6,1.33,0;',
 'Color,,20,22,,271,Soleil Moon Frye,870,,Comedy|Family|Fantasy,Nate Richert,"Sabrina, the Teenage Witch\xa0            ",24420,2433,Caroline Rhea,1,female protagonist|hereditary gift of witchcraft|magic|supernatural|witch,http://www.imdb.com/title/tt0115341/?ref_=fn_tt_tt_1,94,English,USA,TV-G,3000000,,558,6.6,1.33,990;',
 'Color,Adam Brooks,160,112,20,61,Sakina Jaffrey,16000,31973840,Comedy|Drama|Romance,Ryan Reynolds,"Definitely, Maybe\xa0",127760,16289,Paulina Gerzon,5,college|daughter|girl|sex|wisconsin,http://www.imdb.com/title/tt0832266/?ref_=fn_tt_tt_1,168,English,Germany,PG-13,,2008,109,7.2,2.35,0;',
 'Color,Alex Proyas,225,115,295,466,Bruce Greenwood,10000,144795350,Action|Mystery|Sci-Fi|Thriller,Will Smith,"I, Robot\xa0",387632,12068,Chi McBride,1,humanoid robot|man versus machine|prosthetic limb|robot as pathos|robot vs. robot,http://www.imdb.com/title/tt0343818/?ref_=fn_tt_tt_1,789,English,USA,PG-13,120000000,2004,981,7.1,2.35,0;',
 'Color,Andrew Adamson,284,150,80,82,Kiran Shah,1000,291709845,Adventure|Family|Fantasy,Jim Broadbent,"The Chronicles of Narnia: The Lion, the Witch and the Wardrobe\xa0",286506,1317,Shane Rangi,5,hide and seek|lion|magic|professor|snow,http://www.imdb.com/title/tt0363771/?ref_=fn_tt_tt_1,1463,English,USA,PG,180000000,2005,190,6.9,2.35,0;',
 'Color,Ang Lee,287,120,0,5,Pei-Pei Cheng,103,128067808,Action|Drama|Romance,Chen Chang,"Crouching Tiger, Hidden Dragon\xa0",217740,129,Sihung Lung,3,bare midriff|china|magical realism|martial arts|sword,http://www.imdb.com/title/tt0190332/?ref_=fn_tt_tt_1,1641,Mandarin,Taiwan,PG-13,15000000,2000,21,7.9,2.35,0;',
 'Color,Steven Soderbergh,58,100,0,65,Laura San Giacomo,828,24741700,Drama,Peter Gallagher,"Sex, Lies, and Videotape\xa0",37785,1431,Steven Brill,2,affair|interview|marriage|sex|videotape,http://www.imdb.com/title/tt0098724/?ref_=fn_tt_tt_1,95,English,USA,R,1200000,1989,531,7.2,1.85,2000;',
 'Color,Stuart Beattie,308,92,72,568,Kevin Grevioux,623,19059018,Action|Fantasy|Sci-Fi|Thriller,Caitlin Stasey,"I, Frankenstein\xa0",65709,3165,Miranda Otto,0,army|creature|demon|frankenstein|gargoyle,http://www.imdb.com/title/tt1418377/?ref_=fn_tt_tt_1,194,English,Australia,PG-13,65000000,2014,593,5.1,2.35,15000;',
 'Color,Sut Jhally,16,80,3,0,Seth Ackerman,103,,Documentary,Noam Chomsky,"Peace, Propaganda & the Promised Land\xa0",496,103,Arik Ascherman,3,arab israeli conflict|israel|media|middle east|palestine,http://www.imdb.com/title/tt0428959/?ref_=fn_tt_tt_1,13,English,USA,,70000,2004,0,8.3,,110;',
 'Color,Taylor Hackford,12,330,138,672,Jesse Borrego,848,4496583,Crime|Drama,Delroy Lindo,"Blood In, Blood Out\xa0",23181,3227,Raymond Cruz,2,1970s|1980s|barrio|gang war|mexican,http://www.imdb.com/title/tt0106469/?ref_=fn_tt_tt_1,129,English,USA,R,35000000,1993,674,8.0,1.66,6000;',
 'Color,Tim McCanlies,15,97,23,326,Michael O\'Neill,982,565592,Comedy|Drama|Family,Ethan Embry,"Dancer, Texas Pop. 81\xa0",2189,2580,Alexandra Holden,0,best friend|friendship|population|state in title|texas,http://www.imdb.com/title/tt0118925/?ref_=fn_tt_tt_1,63,English,USA,PG,,1998,599,6.8,1.85,500;',
 'Color,Yimou Zhang,101,95,611,3,Ni Yan,9,190666,Comedy|Drama,Honglei Sun,"A Woman, a Gun and a Noodle Shop\xa0",2410,18,Dahong Ni,1,betrayal|husband wife relationship|murder|noodles|salary,http://www.imdb.com/title/tt1428556/?ref_=fn_tt_tt_1,20,Mandarin,China,R,,2009,4,5.7,2.35,784;',
 'Colour',
 'color']
name = 'Color'
column = 'color'
replace_wrong(column, duplicates, name)

# %%
duplicates = [',Christopher Barnard,,22,0,,,5,,Comedy,Mathew Buck,"10,000 B.C.\xa0            ",6,5,,0,,http://www.imdb.com/title/tt1869849/?ref_=fn_tt_tt_1,,,,,,,,7.2,,0;']
name = 'unknown'
column = 'color'
replace_wrong(column, duplicates, name)

# %%
sorted (df['color'].unique())
# Out:
# ['Black and White', 'Color', 'unknown']

# %%
sorted (df['country'].unique())
# Out:
# ['Afghanistan',
#  'Argentina',
#  'Aruba',
#  'Australia',
#  'Bahamas',
#  'Belgium',
#  'Brazil',
#  'Bulgaria',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chile',
#  'China',
#  'Colombia',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Egypt',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Libya',
#  'Mexico',
#  'Netherlands',
#  'New Line',
#  'New Zealand',
#  'Nigeria',
#  'Norway',
#  'Official site',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Romania',
#  'Russia',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'South Korea',
#  'Soviet Union',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Thailand',
#  'Turkey',
#  'UK',
#  'USA',
#  'United Arab Emirates',
#  'unknown']

# %% [markdown]
# Теперь, когда все совпадает можно удалить дубликаты в записях.

# %%
df.duplicated().sum()
# Out:
# 110

# %% [markdown]
# Их не так уж и много

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Этап 3. Задачи <a id='tasks'></a>
# <br>

# %% [markdown]
# ### Задание №1. Цены<a id='prices'></a>
# <br>
# Для успешной проверки гипотез следует привести любые цены к одному году. Тк инфляция и покупательская способность горожан была разной в разное время.

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Это нужно для извлечения данных из HTML

# %%
index_names = df[ df['title_year'] == -1 ].index
df.drop(index_names, inplace = True)
url = "https://www.usinflationcalculator.com/inflation/consumer-price-index-and-annual-percent-changes-from-1913-to-2008/"
r = requests.get(url)
data = r.text
soup = BeautifulSoup(data, 'html.parser')

table = soup.find("table")
rows = table.tbody.findAll("tr")

years = []
cpis = []

for row in rows:
    year = row.findAll('td')[0].get_text()
    if year.isdigit() and int(year) < 2017:
        years.append(int(year))
        cpis.append(float(row.findAll('td')[13].get_text()))

cpi_table = pd.DataFrame({
    'year': years,
    'avg_annual_cpi': cpis
})

cpi_table.head()
# Out:
#    year  avg_annual_cpi
# 0  1913             9.9
# 1  1914            10.0
# 2  1915            10.1
# 3  1916            10.9
# 4  1917            12.8

# %% [markdown]
# Определим функцию для перевода номинальных долларов в реальные доллары в
# 2016 году с использованием ИПЦ. Будем использовать следующую формулу для расчета
# реальной стоимости:
# Прошлые доллары в пересчете на недавние доллары = (сумма в долларах × CPI на
# конец периода) ÷ CPI на начало периода

# %%
def get_real_value(nominal_amt, old_cpi, new_cpi):
    real_value = (nominal_amt * new_cpi) / old_cpi
    return real_value

# %% [markdown]
# В 2016 г. нас интересуют реальные доллары, поэтому упростим себе задачу и
# установим константу.

# %%
CPI_2016 = float (cpi_table[cpi_table['year'] == 2016]['avg_annual_cpi'].iloc[0])

# %% [markdown]
# Теперь преобразуем значения столбцов ‘budget’ и ‘gross’ для каждого фильма в
# реальные долларовые эквиваленты 2016 г:

# %%
real_domestic_gross = []
real_budget_values = []

for index, row in df.iterrows():
    gross = row['gross']
    budget = row['budget']
    year = row['title_year']
    cpi = float(cpi_table[cpi_table['year'] == int(year)]['avg_annual_cpi'].iloc[0])
    real_gross = get_real_value(gross, cpi, CPI_2016)
    real_budget = get_real_value(budget, cpi, CPI_2016)
    real_domestic_gross.append(real_gross)
    real_budget_values.append(real_budget)

df['real_domestic_gross'] = real_domestic_gross
df['real_budget_values'] = real_budget_values

# %% [markdown]
# Давайте также посчитаем окупаемость инвестиций (ROI) и абсолютную прибыль для каждого фильма. ROI покажет, какая киностудия получила наибольшую
# прибыль, исходя из первоначального бюджета фильма, и будет полезен при оценке успеха фильма в экономическом смысле. Мы будем хранить значения рентабельности инвестиций в процентах

# %%
profits = []
roi_vals = []

for index, row in df.iterrows():
    profit = row['real_domestic_gross'] - row['real_budget_values']
    budget = row['real_budget_values']
    num = profit - budget
    den = budget
    roi = (num/den)*100
    profits.append(profit)
    roi_vals.append(roi)
    
df['profit'] = profits
df['roi'] = roi_vals

# %% [markdown]
# Создадим из Cpi_table ДатаСет

# %%
os.chdir('../data')
cpi_table.to_csv('Lab1_Раевских_ФИТ-222.csv')

# %%
df.head (10)
# Out:
#     actor_1_facebook_likes     actor_1_name  actor_2_facebook_likes  \
# 0                   1000.0      CCH Pounder                   936.0
# 1                  40000.0      Johnny Depp                  5000.0
# 2                  11000.0  Christoph Waltz                   393.0
# 3                  27000.0        Tom Hardy                 23000.0
# 5                    640.0     Daryl Sabara                   632.0
# 6                  24000.0     J.K. Simmons                 11000.0
# 7                    799.0     Brad Garrett                   553.0
# 8                  26000.0  Chris Hemsworth                 21000.0
# 9                  25000.0     Alan Rickman                 11000.0
# 10                 15000.0     Henry Cavill                  4000.0
#
#          actor_2_name  actor_3_facebook_likes          actor_3_name  \
# 0    Joel David Moore                   855.0             Wes Studi
# 1       Orlando Bloom                  1000.0        Jack Davenport
# 2        Rory Kinnear                   161.0      Stephanie Sigman
# 3      Christian Bale                 23000.0  Joseph Gordon-Levitt
# 5     Samantha Morton                   530.0          Polly Walker
# 6        James Franco                  4000.0         Kirsten Dunst
# 7        Donna Murphy                   284.0           M.C. Gainey
# 8   Robert Downey Jr.                 19000.0    Scarlett Johansson
# 9    Daniel Radcliffe                 10000.0          Rupert Grint
# 10       Lauren Cohan                  2000.0        Alan D. Purwin
#
#     aspect_ratio       budget  cast_total_facebook_likes  color  ...  \
# 0           1.78  237000000.0                     4834.0  Color  ...
# 1           2.35  300000000.0                    48350.0  Color  ...
# 2           2.35  245000000.0                    11700.0  Color  ...
# 3           2.35  250000000.0                   106759.0  Color  ...
# 5           2.35  263700000.0                     1873.0  Color  ...
# 6           2.35  258000000.0                    46055.0  Color  ...
# 7           1.85  260000000.0                     2036.0  Color  ...
# 8           2.35  250000000.0                    92000.0  Color  ...
# 9           2.35  250000000.0                    58753.0  Color  ...
# 10          2.35  250000000.0                    24450.0  Color  ...
#
#                                   movie_title num_critic_for_reviews  \
# 0                                     Avatar                   723.0
# 1   Pirates of the Caribbean: At World's End                   302.0
# 2                                    Spectre                   602.0
# 3                      The Dark Knight Rises                   813.0
# 5                                John Carter                   462.0
# 6                               Spider-Man 3                   392.0
# 7                                    Tangled                   324.0
# 8                    Avengers: Age of Ultron                   635.0
# 9     Harry Potter and the Half-Blood Prince                   375.0
# 10        Batman v Superman: Dawn of Justice                   673.0
#
#     num_user_for_reviews num_voted_users  \
# 0                 3054.0        886204.0
# 1                 1238.0        471220.0
# 2                  994.0        275868.0
# 3                 2701.0       1144337.0
# 5                  738.0        212204.0
# 6                 1902.0        383056.0
# 7                  387.0        294810.0
# 8                 1117.0        462669.0
# 9                  973.0        321795.0
# 10                3018.0        371639.0
#
#                                         plot_keywords  title_year  \
# 0              avatar|future|marine|native|paraplegic      2009.0
# 1   goddess|marriage ceremony|marriage proposal|pi...      2007.0
# 2                 bomb|espionage|sequel|spy|terrorist      2015.0
# 3   deception|imprisonment|lawlessness|police offi...      2012.0
# 5   alien|american civil war|male nipple|mars|prin...      2012.0
# 6           sandman|spider man|symbiote|venom|villain      2007.0
# 7   17th century|based on fairy tale|disney|flower...      2010.0
# 8   artificial intelligence|based on comic book|ca...      2015.0
# 9                    blood|book|love|potion|professor      2009.0
# 10  based on comic book|batman|sequel to a reboot|...      2016.0
#
#    real_domestic_gross  real_budget_values        profit         roi
# 0         8.507937e+08        2.651368e+08  5.856569e+08  120.888543
# 1         3.582208e+08        3.473329e+08  1.088790e+07  -96.865283
# 2         2.025981e+08        2.480907e+08 -4.549257e+07 -118.337071
# 3         4.684551e+08        2.613385e+08  2.071167e+08  -20.747743
# 5         7.637218e+07        2.756598e+08 -1.992877e+08 -172.294775
# 6         3.896268e+08        2.987063e+08  9.092051e+07  -69.561898
# 7         2.210219e+08        2.861734e+08 -6.515148e+07 -122.766438
# 8         4.647818e+08        2.531538e+08  2.116281e+08  -16.403360
# 9         3.378055e+08        2.796802e+08  5.812535e+07  -79.217208
# 10        3.302491e+08        2.500000e+08  8.024906e+07  -67.900375
#
# [10 rows x 32 columns]

# %% [markdown]
# ### Задание №2. Гипотеза №1 Фильмы из США имеют больший средний рейтинг чем фильмы из СССР и России<a id='prices'></a>
# <br>
# Начнем с чего нибудь простого и сравним рейтинги фильмов..

# %%
df_country = df[df['country'].isin(['USA', 'Russia', 'Soviet Union'])].groupby('country')['imdb_score'].mean()
print(df_country)
# Out:
# country
# Russia          6.081818
# Soviet Union    8.100000
# USA             6.346678
# Name: imdb_score, dtype: float64

# %% [markdown]
# Как видно, рейтинг фильмов из СССР выше в среднем чем у России и США, но как результат будет выглядить если сложить Россию и СССР?

# %%
df_country = df[df['country'].isin(['USA', 'Russia', 'Soviet Union'])].copy()
df_country['country'] = df_country['country'].replace({'Soviet Union': 'Russia/Soviet Union'})
df_country['country'] = df_country['country'].replace({'Russia': 'Russia/Soviet Union'})
df_country = df_country.groupby('country')['imdb_score'].mean()
print(df_country)
# Out:
# country
# Russia/Soviet Union    6.250000
# USA                    6.346678
# Name: imdb_score, dtype: float64

# %% [markdown]
# Теперь точно видно, что гипотеза подтвердилась. И в правду, рейтинг фильмов из США больше чем в России и СССР вместе взятых.

# %% [markdown]
# Но на самом деле такой способ решения меня не устраивает тк, он требудет копирования таблицы и замены данных так что сделаем по-другому
# Для начала узнаем количество всех фильмов снятых в данных странах, у которых есть рейтинг.

# %%
df_films1 = df[df['country'].isin(['USA', 'Russia', 'Soviet Union'])].groupby('country')['imdb_score'].count()
print(df_films1)
# Out:
# country
# Russia            11
# Soviet Union       1
# USA             3657
# Name: imdb_score, dtype: int64

# %% [markdown]
# Затем суммируем все возможные рейтинги.

# %%
df_score_sum = df[df['country'].isin(['USA', 'Russia', 'Soviet Union'])].groupby('country')['imdb_score'].sum()
print(df_score_sum)
# Out:
# country
# Russia             66.9
# Soviet Union        8.1
# USA             23209.8
# Name: imdb_score, dtype: float64

# %% [markdown]
# Сложим сумму рейтингов СССР и России и поделим сумму рейтинга на количество фильмов.

# %%
df_score_SR = float(df_score_sum.iloc[0]) + float(df_score_sum.iloc[1])
df_score_US = float(df_score_sum.iloc[2])
df_filmsSR = float(df_films1.iloc[0]) + float(df_films1.iloc[1])
df_filmsUS = float(df_films1.iloc[2])

US_r = df_score_SR / df_filmsSR
SR_r = df_score_US / df_filmsUS
print(US_r)
print(SR_r)
# Out:
# 6.25
# 6.346677604593929

# %% [markdown]
# Как видим результат оказался таким же. Значит все сделано верно. Гипотеза подтверждена.

# %% [markdown]
# ### Гипотеза №2 У фильмов в жанре "Драма" средняя окупаемость больше чем у фильмов из 80х<a id='prices'></a>

# %% [markdown]
# Раз уж в первом задании привели валюты к 2016 году и посчитали окупаемость, то давайте ей и воспользуемся

# %% [markdown]
# Для начала найдем количество всех фильмов в жанре "Драма" и фильмов, которые были сняты с 1980 по 1990 года.

# %%
drama_movies = len(df[df['plot_keywords'].str.contains('drama')])
eighties_movies = len(df[df['title_year'].between(1980, 1990)])
print(drama_movies)
print(eighties_movies)
# Out:
# 4
# 313

# %% [markdown]
# Затем просуммируем их окупаемость

# %%
drama_roi_sum = df[df['plot_keywords'].str.contains('drama')]['roi'].sum()
eighties_roi_sum = df[df['title_year'].between(1980, 1990)]['roi'].sum()
print(drama_roi_sum)
print(eighties_roi_sum)
# Out:
# 2028.4993113209107
# -20252190800.83043

# %% [markdown]
# Ну и найти среднее

# %%
print(drama_roi_sum / drama_movies)
print(eighties_roi_sum / eighties_movies)
# Out:
# 507.1248278302277
# -64703484.98667869

# %% [markdown]
# Вообще это можно сделать и одной командой

# %%
drama_roi_sum_one = df[df['plot_keywords'].str.contains('drama')]['roi'].mean()
eighties_roi_sum_one = df[df['title_year'].between(1980, 1990)]['roi'].mean()
print(drama_roi_sum_one)
print(eighties_roi_sum_one)
# Out:
# 507.1248278302277
# -64703484.98667869

# %% [markdown]
# Да, гипотеза подтвердилась. У фильмов с жанром Драма окупаемость больше чем у фильмов 80х годов.

# %% [markdown]
# ### Гипотеза №3 У самого дешевого фильма США больше лайков в фейсбуке, чем у самого дорого фильма из России<a id='prices'></a>

# %% [markdown]
# Для начала стоит найти самый дешевый фильм в США и самый дорогой в России.

# %%
usa_min_budget_movie = df[df['country'] == 'USA'].sort_values(by='budget').iloc[0]
russia_max_budget_movie = df[df['country'] == 'Russia'].sort_values(by='budget', ascending=False).iloc[0]
print(usa_min_budget_movie['movie_title'])
print(russia_max_budget_movie['movie_title'])
# Out:
# Out of the Dark
# A Warrior's Tail

# %% [markdown]
# Раз уж мы знаем название, то по нему выведем количество лайков.

# %%
russia_movie_title = russia_max_budget_movie['movie_title']
usa_movie_title = usa_min_budget_movie['movie_title']
df_likes = df[df['movie_title'].isin([usa_movie_title, russia_movie_title])].groupby('country')['movie_facebook_likes'].sum()
print(df_likes)
# Out:
# country
# Russia    161;
# USA       844;
# Name: movie_facebook_likes, dtype: object

# %% [markdown]
# Гипотеза неожиданно подтвердилась. У самого дорого фильма из России и в правду меньше лайков.

# %% [markdown]
# ### Задание №3. Дополнительное задание

# %% [markdown]
# В дополнительном задании было сказано выполнить вторую гипотезу из примера с помощью pandas.pivot_table

# %%
pd.pivot_table(df,
               index=["City"],
               values=["Monday", 'Wednesday', 'Friday'],
               aggfunc=lambda x: number_tracks(x.name, x.index.day_name())
              )

# %% [markdown]
# Будет оно выглядить как то так, но проверить я это без ДатаСета не смогу.
