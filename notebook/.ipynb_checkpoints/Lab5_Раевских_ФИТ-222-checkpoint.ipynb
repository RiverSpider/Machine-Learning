# %% [markdown]
# Лабораторная работа №5. "ДРЕВОВИДНЫЕ МОДЕЛИ: РЕШАЮЩИЕ ДЕРЕВЬЯ И ИХ КОМПОЗИЦИИ"
#
# Задание №1.
# A). Реализовать DecisionTreeClassifier и DecisionTreeRegressor из Sclearn для соответствующих наборов данных своего варианта. Осуществить настройку гиперпараметров. Выполнить оценку качества модели, визуализировать дерево решений, вывести решающие правила. Сравнить полученные результаты обучения моделей с данными, полученными с помощью PyCaret (открытая low-code библиотека ML на Python, см. Lab5_Ex3 DRs_classifier.ipynb)
# B). Реализовать обучение и вычисление дерева с использованием алгоритма CART для задачи регрессии и задачи классификации. Выполнить оценку качества моделей, визуализировать дерево решений, вывести решающие правила.
#
# Задание №2. Применить ансамбли для наборов данных своего варианта:
# o BaggingClassifier
# o BaggingRegressor
#
# o GradientBoostingClassifier
# o GradientBoostingRegressor
#
# o StackingClassifier
# o StackingRegressor
#
# Выполнить оценку качества моделей и выбрать лучшую модель.
#
# Задание №3. Реализовать для решения задачи регрессии и задачи классификации следующие библиотеки:
# o Catboost,
# o XGBoost,
# o LightGBM
# Выполнить оценку качества моделей и выбрать лучшую модель.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
import os

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
import matplotlib.pyplot as plt
from sklearn import tree

# %%
os.chdir('../data')
#Вариант 1
df_regression = pd.read_csv('lab3.csv')
df_classifier = pd.read_csv('lab4.csv')

# %%
df_classifier
# Out:
#         flight  dayofweek  time  length  delay  airline_9E  airline_AA  \
# 0         3036          4  1195     131      0       False       False
# 1          315          7   707     145      0       False       False
# 2         6673          5   499      42      1       False       False
# 3         3668          2   810      70      1       False       False
# 4          623          5   985     143      0       False       False
# ...        ...        ...   ...     ...    ...         ...         ...
# 244063    2699          7   910      62      0       False       False
# 244064    3995          2   985      80      0       False       False
# 244065    6474          6   652     138      0       False       False
# 244066     486          7   365     107      0       False       False
# 244067    1037          4   605     150      1       False       False
#
#         airline_AS  airline_B6  airline_CO  ...  airportto_TXK  airportto_TYR  \
# 0            False       False       False  ...          False          False
# 1            False       False       False  ...          False          False
# 2            False       False       False  ...          False          False
# 3            False       False       False  ...          False          False
# 4             True       False       False  ...          False          False
# ...            ...         ...         ...  ...            ...            ...
# 244063       False       False       False  ...          False          False
# 244064       False       False       False  ...          False          False
# 244065       False       False       False  ...          False          False
# 244066       False       False       False  ...          False          False
# 244067       False       False       False  ...          False          False
#
#         airportto_TYS  airportto_UTM  airportto_VLD  airportto_VPS  \
# 0               False          False          False          False
# 1               False          False          False          False
# 2               False          False          False          False
# 3               False          False          False          False
# 4               False          False          False          False
# ...               ...            ...            ...            ...
# 244063          False          False          False          False
# 244064          False          False          False          False
# 244065          False          False          False          False
# 244066          False          False          False          False
# 244067          False          False          False          False
#
#         airportto_WRG  airportto_XNA  airportto_YAK  airportto_YUM
# 0               False          False          False          False
# 1               False          False          False          False
# 2               False          False          False          False
# 3               False          False          False          False
# 4               False          False          False          False
# ...               ...            ...            ...            ...
# 244063          False          False          False          False
# 244064          False          False          False          False
# 244065          False          False          False          False
# 244066          False          False          False          False
# 244067          False          False          False          False
#
# [244068 rows x 609 columns]

# %%
df_regression
# Out:
#        year  distance  engine_capacity(cm3)  price(euro)  make_ARO  \
# 0      2011    195000                  1800         7750     False
# 1      2014    135000                  1500         8550     False
# 2      1998         1                  1400         2200     False
# 3      2012    110000                  1500         6550     False
# 4      2006    200000                  1600         4100     False
# ...     ...       ...                   ...          ...       ...
# 30058  2002    225000                  1800         4400     False
# 30059  2015     89000                  1500         7000     False
# 30060  2009       225                  1500         4500     False
# 30061  2006    370000                  2000         4000     False
# 30062  2006    300000                  1500         4000     False
#
#        make_Abarth  make_Acura  make_Alfa Romeo  make_Alta marca  \
# 0            False       False            False            False
# 1            False       False            False            False
# 2            False       False            False            False
# 3            False       False            False            False
# 4            False       False            False            False
# ...            ...         ...              ...              ...
# 30058        False       False            False            False
# 30059        False       False            False            False
# 30060        False       False            False            False
# 30061        False       False            False            False
# 30062        False       False            False            False
#
#        make_Aston Martin  ...  style_Sedan  style_Universal  fuel_type_Diesel  \
# 0                  False  ...        False            False             False
# 1                  False  ...        False             True              True
# 2                  False  ...        False            False             False
# 3                  False  ...        False             True              True
# 4                  False  ...        False             True             False
# ...                  ...  ...          ...              ...               ...
# 30058              False  ...        False            False             False
# 30059              False  ...        False             True              True
# 30060              False  ...        False            False              True
# 30061              False  ...        False            False              True
# 30062              False  ...        False            False              True
#
#        fuel_type_Electric  fuel_type_Hybrid  fuel_type_Metan/Propan  \
# 0                   False              True                   False
# 1                   False             False                   False
# 2                   False             False                   False
# 3                   False             False                   False
# 4                   False             False                    True
# ...                   ...               ...                     ...
# 30058               False             False                    True
# 30059               False             False                   False
# 30060               False             False                   False
# 30061               False             False                   False
# 30062               False             False                   False
#
#        fuel_type_Petrol  fuel_type_Plug-in Hybrid  transmission_Automatic  \
# 0                 False                     False                    True
# 1                 False                     False                   False
# 2                  True                     False                   False
# 3                 False                     False                   False
# 4                 False                     False                   False
# ...                 ...                       ...                     ...
# 30058             False                     False                   False
# 30059             False                     False                   False
# 30060             False                     False                   False
# 30061             False                     False                   False
# 30062             False                     False                   False
#
#        transmission_Manual
# 0                    False
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ...                    ...
# 30058                 True
# 30059                 True
# 30060                 True
# 30061                 True
# 30062                 True
#
# [30063 rows x 940 columns]

# %%
df_regression = df_regression.rename(columns={"engine_capacity(cm3)": "enginecapacity", "price(euro)": "price"})

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

numeric_features_classifier = ['time','length'] 
df_classifier[numeric_features_classifier] = scaler.fit_transform(df_classifier[numeric_features_classifier])

# %%
y_classifier = df_classifier["delay"]
X_classifier = df_classifier.drop(["delay"], axis=1)
X_classifier, _, y_classifier, _ = train_test_split(X_classifier, y_classifier, test_size=0.9, random_state=42)


y_regression = df_regression["price"]
X_regression = df_regression.drop(["price"], axis=1)

# %%
X_train_classifier, X_test_classifier, y_train_classifier, y_test_classifier = train_test_split(X_classifier, y_classifier, test_size=0.2)
X_train_regression, X_test_regression, y_train_regression, y_test_regression = train_test_split(X_regression, y_regression, test_size=0.2)

# %% [markdown]
# ## Реализовать DecisionTreeClassifier и DecisionTreeRegressor из Sclearn для соответствующих наборов данных своего варианта. Осуществить настройку гиперпараметров.

# %%
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV
classifier = DecisionTreeClassifier()

param_dist = {
    "criterion": ["gini", "entropy"],
    "max_depth": randint(1, 4),
    "min_samples_split": randint(2, 20),
    "min_samples_leaf": randint(1, 10)
}

clf_random_search = RandomizedSearchCV(classifier, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
clf_random_search.fit(X_train_classifier, y_train_classifier)

best_classifier = clf_random_search.best_estimator_

# %%
regressor = DecisionTreeRegressor()

param_dist = {
    "criterion": ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "max_depth": randint(1, 4),
    "min_samples_split": randint(2, 20),
    "min_samples_leaf": randint(1, 10)
}

reg_random_search = RandomizedSearchCV(regressor, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
reg_random_search.fit(X_train_regression, y_train_regression)

best_regressor = reg_random_search.best_estimator_

# %% [markdown]
# ## Выполнить оценку качества модели, визуализировать дерево решений

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

def calculate_metrics(model, X, y_true):
    y_pred = model.predict(X)
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return r2, mae, mse, rmse, mape

# %%
metrics_classifier = calculate_metrics(best_classifier, X_test_classifier, y_test_classifier)
metrics_regressor = calculate_metrics(best_regressor, X_test_regression, y_test_regression)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

clf_predictions = best_classifier.predict(X_test_classifier)

print('Accuracy: {:.3f}'.format(accuracy_score(y_test_classifier, clf_predictions)))
print('Precision: {:.3f}'.format(precision_score(y_test_classifier, clf_predictions)))
print('Recall: {:.3f}'.format(recall_score(y_test_classifier, clf_predictions)))
print('F1-score: {:.3f}'.format(f1_score(y_test_classifier, clf_predictions)))
print('ROC-AUC: {:.3f}'.format(roc_auc_score(y_test_classifier, clf_predictions)))
# Out:
# Accuracy: 0.688
# Precision: 0.637
# Recall: 0.157
# F1-score: 0.252
# ROC-AUC: 0.556

# %%
print(f'MAE: {metrics_regressor[1]}')
print(f'MSE: {metrics_regressor[2]}')
print(f'RMSE: {metrics_regressor[3]}')
print(f'MAPE: {metrics_regressor[4]}')
print(f'R^2: {metrics_regressor[0]}')
# Out:
# MAE: 2103.8874561827015
# MSE: 8241907.693198926
# RMSE: 2870.872287859376
# MAPE: 87.64493258126124
# R^2: 0.6949840022174547

# %% [markdown]
# ## Визуализировать дерево решений:

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plot_tree(best_classifier, filled=True)
plt.show()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plot_tree(best_regressor, filled=True)
plt.show()

# %% [markdown]
# ## вывести решающие правила

# %%
from sklearn.tree import export_text
tree_rules = export_text(best_classifier, feature_names=list(X_classifier.columns))
print(tree_rules)
# Out:
# |--- airline_WN <= 0.50
# |   |--- time <= -0.39
# |   |   |--- dayofweek <= 5.50
# |   |   |   |--- class: 0
# |   |   |--- dayofweek >  5.50
# |   |   |   |--- class: 0
# |   |--- time >  -0.39
# |   |   |--- dayofweek <= 5.50
# |   |   |   |--- class: 0
# |   |   |--- dayofweek >  5.50
# |   |   |   |--- class: 0
# |--- airline_WN >  0.50
# |   |--- time <= -0.43
# |   |   |--- time <= -0.90
# |   |   |   |--- class: 0
# |   |   |--- time >  -0.90
# |   |   |   |--- class: 0
# |   |--- time >  -0.43
# |   |   |--- dayofweek <= 5.50
# |   |   |   |--- class: 1
# |   |   |--- dayofweek >  5.50
# |   |   |   |--- class: 0

# %%
tree_rules = export_text(best_regressor, feature_names=list(X_regression.columns))
print(tree_rules)
# Out:
# |--- year <= 2010.50
# |   |--- year <= 2005.50
# |   |   |--- year <= 2000.50
# |   |   |   |--- value: [2427.93]
# |   |   |--- year >  2000.50
# |   |   |   |--- value: [3751.26]
# |   |--- year >  2005.50
# |   |   |--- enginecapacity <= 1784.50
# |   |   |   |--- value: [4491.91]
# |   |   |--- enginecapacity >  1784.50
# |   |   |   |--- value: [7270.34]
# |--- year >  2010.50
# |   |--- enginecapacity <= 1925.00
# |   |   |--- year <= 2014.50
# |   |   |   |--- value: [7365.31]
# |   |   |--- year >  2014.50
# |   |   |   |--- value: [11639.29]
# |   |--- enginecapacity >  1925.00
# |   |   |--- year <= 2014.50
# |   |   |   |--- value: [13857.60]
# |   |   |--- year >  2014.50
# |   |   |   |--- value: [17352.15]

# %% [markdown]
# ## PyCaret

# %%
#!pip install --pre pycaret

# %%
#from pycaret.regression import *

# %%
#setup(data=df_regression,  target='price(euro)', session_id=555, train_size=0.7, preprocess=True)

# %%
#models()

# %%
#dt_reg = create_model(estimator='dt')

# %%
#tuned_dt_reg = tune_model(dt_reg)

# %% [markdown]
# ## Реализовать обучение и вычисление дерева с использованием алгоритма CART для задачи регрессии и задачи классификации.

# %%
import numpy as np

class CARTRegressor:
    def __init__(self, max_depth=None, min_samples_split=2):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split

    def fit(self, X, y):
        self.root = self._build_tree(X, y, depth=0)
 # метод _build_tree рекурсивно создает узлы дерева до достижения максимальной глубины или min_samples_split
    def _build_tree(self, X, y, depth):
        # Условие остановки рекурсии: достигнута максимальная глубина или число примеров в узле меньше min_samples_split
        if (self.max_depth is not None and depth >= self.max_depth) or len(X) <= self.min_samples_split:
            leaf_value = np.mean(y)
            # Если условие остановки выполнено, создаем лист дерева с агрегированным значением целевого признака
            return {'leaf': True, 'value': leaf_value}
        
        # Находим наилучшие признак и порог для разделения
        best_feature, best_threshold = self._find_best_split(X, y)
        # Создаем индексы для левого и правого поддеревьев 
        left_child_indices = X[:, best_feature] <= best_threshold
        right_child_indices = X[:, best_feature] > best_threshold
        
        # Рекурсивно строим поддеревья для левой и правой ветви
        node = {
            'feature': best_feature,
            'threshold': best_threshold,
            'left': self._build_tree(X[left_child_indices], y[left_child_indices], depth + 1),
            'right': self._build_tree(X[right_child_indices], y[right_child_indices], depth + 1)
        }
        # Возвращаем узел с указанием признака и порога для разделения, а также с поддеревьями
        return node
    
    # Метод _find_best_split ищет лучший разделитель, основываясь на снижении среднеквадратичной ошибки
    def _find_best_split(self, X, y):
        # Начальные значения для наилучшего признака, наилучшего порога и наилучшего mse
        best_mse = float('inf')
        best_feature = None
        best_threshold = None
        
        # Перебор всех возможных признаков и пороговых значений
        for feature in range(X.shape[1]):
            thresholds = np.unique(X[:, feature])
            for threshold in thresholds:
                # Деление на подгруппы по каждому порогу для данного признака
                left_indices = X[:, feature] <= threshold
                right_indices = X[:, feature] > threshold
                
                # Вычисление значения среднеквадратичной ошибки в результате разделения
                mse = self._mse(y[left_indices], y[right_indices])
                # Если новое mse меньше предыдущего наилучшего, 
                # то обновляем наилучший признак и наилучший порог разделения
                if mse < best_mse:
                    best_mse = mse
                    best_feature = feature
                    best_threshold = threshold
        
        return best_feature, best_threshold
    
    # Метод _mse вычисляет среднеквадратичную ошибку между целевым и предсказанным значениями
    def _mse(self, left_y, right_y):
        left_mse = np.mean((left_y - np.mean(left_y))**2)
        right_mse = np.mean((right_y - np.mean(right_y))**2)
        mse = (len(left_y) * left_mse + len(right_y) * right_mse) / (len(left_y) + len(right_y))
        return mse
    
    # Метод predict предсказывает целевые значения для входного массива X
    def predict(self, X):
        # Вызов метода _traverse_tree для каждого элемента массива X
        return np.array([self._traverse_tree(x, self.root) for x in X])
    
    # Метод _traverse_tree обходит дерево, начиная от корня, и возвращает значение в листе для заданного образца
    def _traverse_tree(self, x, node):
        if 'leaf' in node:
            return node['value']
        
        feature_value = x[node['feature']]
        
        if not isinstance(feature_value, (int, float)):
            return self._traverse_tree(x, node['left'])
        
        if feature_value <= node['threshold']:
            return self._traverse_tree(x, node['left'])
        else:
            return self._traverse_tree(x, node['right'])

# %%
regressor = CARTRegressor(max_depth=5, min_samples_split=10)
regressor.fit(X_train_regressor, y_train_regressor)

predictions = regressor.predict(X_test_regressor)

r2 = r2_score(y_test_regressor, predictions)
print('R^2:', r2)
# Out:
# C:\Users\raevs\Desktop\ML\venv\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\raevs\Desktop\ML\venv\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# R^2: 0.37308801769052446

# %%
class CARTClassifier:
    def __init__(self, max_depth=None, min_samples_split=2):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split

    def fit(self, X, y):
        self.root = self._build_tree(X, y, depth=0)
        
    # Рекурсивная функция для построения дерева.
    def _build_tree(self, X, y, depth):
        # Условие остановки - если достигли максимальной глубины или количество элементов недостаточно для разделения
        if (self.max_depth is not None and depth >= self.max_depth) or len(X) <= self.min_samples_split:
            class_counts = np.bincount(y)
            class_probability = class_counts / np.sum(class_counts)
            # Если остановились - возвращаем лист с наиболее популярным классом
            return {'leaf': True, 'class': np.argmax(class_counts), 'probability': class_probability}
        
        best_feature, best_threshold = self._find_best_split(X, y)
        # Делим датасет на две части
        left_child_indices = X[:, best_feature] <= best_threshold
        right_child_indices = X[:, best_feature] > best_threshold
        
        node = {
            'feature': best_feature,
            'threshold': best_threshold,
            # Строим детей для текущего узла
            'left': self._build_tree(X[left_child_indices], y[left_child_indices], depth + 1),
            'right': self._build_tree(X[right_child_indices], y[right_child_indices], depth + 1)
        }
        return node

    # Функция для нахождения лучшего разбиения в узле.
    def _find_best_split(self, X, y): 
        best_gini = float('inf')
        best_feature = None
        best_threshold = None
        
        for feature in range(X.shape[1]):
            thresholds = np.unique(X[:, feature])
            for threshold in thresholds:
                left_indices = X[:, feature] <= threshold
                right_indices = X[:, feature] > threshold
                
                left_y = y[left_indices]
                right_y = y[right_indices]
                
                gini = self._gini(left_y, right_y)
                if gini < best_gini:
                    best_gini = gini
                    best_feature = feature
                    best_threshold = threshold
        
        return best_feature, best_threshold

    # Функция для расчета индекса Джини
    def _gini(self, left_y, right_y):
        
        left_gini = 1 - np.sum((np.bincount(left_y) / len(left_y))**2)
        right_gini = 1 - np.sum((np.bincount(right_y) / len(right_y))**2)
        gini = (len(left_y) * left_gini + len(right_y) * right_gini) / (len(left_y) + len(right_y))
        return gini

    # Функция для предсказания класса. :param X: матрица признаков
    def predict(self, X):  
        if isinstance(X, pd.DataFrame):
            X = X.values
        elif isinstance(X, list):
            X = np.array(X)
        if X.ndim == 1:
            X = np.expand_dims(X, 0)
        return np.array([self._traverse_tree(x, self.root) for x in X])

    # Функция для обхода дерева с целью классификации объекта.
    def _traverse_tree(self, x, node):  
        if 'leaf' in node:
            return node['class']
        if x[node['feature']] <= node['threshold']:
            # Перемещаемся по дереву влево (если значение признака меньше или равно порогу)
            return self._traverse_tree(x, node['left'])
        else:
            # Перемещаемся по дереву вправо (если значение признака больше порога)
            return self._traverse_tree(x, node['right'])

# %%
cartClassifier = CARTClassifier(max_depth=10, min_samples_split=5)

cartClassifier.fit(X_train_classifier, y_train_classifier)

# %%
y_pred_classifier = cartClassifier.predict(X_test_classifier)

accuracy = accuracy_score(y_test_classifier, y_pred_classifier)
print(f'Model Accuracy: {accuracy}')
# Out:
# Model Accuracy: 0.6734944694797215

# %% [markdown]
# ## Задание №2. Применить ансамбли для наборов данных своего варианта:

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier, BaggingRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.ensemble import StackingClassifier, StackingRegressor

# %%
# Создание экземпляров моделей
bagging_classifier = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=10)
bagging_regressor = BaggingRegressor(estimator=DecisionTreeRegressor(), n_estimators=10)
gradient_boosting_classifier = GradientBoostingClassifier()
gradient_boosting_regressor = GradientBoostingRegressor()
stacking_classifier = StackingClassifier(
    estimators=[('bagging', bagging_classifier), ('gb', gradient_boosting_classifier)],
    final_estimator=LogisticRegression()
)
stacking_regressor = StackingRegressor(
    estimators=[('bagging', bagging_regressor), ('gb', gradient_boosting_regressor)],
    final_estimator=LinearRegression()
)

# %%
# Обучение моделей
bagging_classifier.fit(X_train_classifier, y_train_classifier)
bagging_regressor.fit(X_train_regression, y_train_regression)

gradient_boosting_classifier.fit(X_train_classifier, y_train_classifier)
gradient_boosting_regressor.fit(X_train_regression, y_train_regression)

stacking_classifier.fit(X_train_classifier, y_train_classifier)
stacking_regressor.fit(X_train_regression, y_train_regression)
# Out:
# StackingRegressor(estimators=[('bagging',
#                                BaggingRegressor(estimator=DecisionTreeRegressor())),
#                               ('gb', GradientBoostingRegressor())],
#                   final_estimator=LinearRegression())

# %%
# Прогнозы на тестовых данных
bagging_classifier_predictions = bagging_classifier.predict(X_test_classifier)
bagging_regressor_predictions = bagging_regressor.predict(X_test_regression)

gradient_boosting_classifier_predictions = gradient_boosting_classifier.predict(X_test_classifier)
gradient_boosting_regressor_predictions = gradient_boosting_regressor.predict(X_test_regression)

stacking_classifier_predictions = stacking_classifier.predict(X_test_classifier)
stacking_regressor_predictions = stacking_regressor.predict(X_test_regression)

# %%
# Оценка качества моделей
bagging_classifier_accuracy = accuracy_score(y_test_classifier, bagging_classifier_predictions)
bagging_regressor_accuracy = mean_squared_error(y_test_regression, bagging_regressor_predictions)
gradient_boosting_classifier_accuracy = accuracy_score(y_test_classifier, gradient_boosting_classifier_predictions)
gradient_boosting_regressor_accuracy = mean_squared_error(y_test_regression, gradient_boosting_regressor_predictions)
stacking_classifier_accuracy = accuracy_score(y_test_classifier, stacking_classifier_predictions)
stacking_regressor_accuracy = mean_squared_error(y_test_regression, stacking_regressor_predictions)

print('Bagging Classifier Accuracy:', bagging_classifier_accuracy)
print('Bagging Regressor Accuracy:', bagging_regressor_accuracy)
print('Gradient Boosting Classifier Accuracy:', gradient_boosting_classifier_accuracy)
print('Gradient Boosting Regressor Accuracy:', gradient_boosting_regressor_accuracy)
print('Stacking Classifier Accuracy:', stacking_classifier_accuracy)
print('Stacking Regressor Accuracy:', stacking_regressor_accuracy)
# Out:
# Bagging Classifier Accuracy: 0.650757886112249
# Bagging Regressor Accuracy: 4238530.33577848
# Gradient Boosting Classifier Accuracy: 0.6868086849651782
# Gradient Boosting Regressor Accuracy: 4802029.407432147
# Stacking Classifier Accuracy: 0.6863990167963949
# Stacking Regressor Accuracy: 4070776.126395151

# %% [markdown]
# ## Задание №3. Реализовать для решения задачи регрессии и задачи классификации следующие библиотеки:

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from catboost import CatBoostRegressor, CatBoostClassifier
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier

# %%
# Создание экземпляров моделей 
catboost_regressor = CatBoostRegressor()
catboost_classifier = CatBoostClassifier()

xgboost_regressor = XGBRegressor()
xgboost_classifier = XGBClassifier()

lightgbm_regressor = LGBMRegressor(feature_pre_filter=False)
lightgbm_classifier = LGBMClassifier()

# %%
X_train_regression.columns = X_train_regression.columns.str.replace('\W', '_')
X_train_classifier.columns = X_train_classifier.columns.str.replace('\W', '_')
X_train_regression = X_train_regression.values
y_train_regression = y_train_regression.values
X_train_classifier = X_train_classifier.values
y_train_classifier = y_train_classifier.values
# Обучение моделей 
catboost_regressor.fit(X_train_regression, y_train_regression)
catboost_classifier.fit(X_train_classifier, y_train_classifier)

xgboost_regressor.fit(X_train_regression, y_train_regression)
xgboost_classifier.fit(X_train_classifier, y_train_classifier)

lightgbm_regressor.fit(X_train_regression, y_train_regression)
lightgbm_classifier.fit(X_train_classifier, y_train_classifier)
# Out:
# Learning rate set to 0.06767
# 0:	learn: 4997.5874092	total: 158ms	remaining: 2m 37s
# 1:	learn: 4762.1782241	total: 165ms	remaining: 1m 22s
# 2:	learn: 4546.4206781	total: 172ms	remaining: 57.1s
# 3:	learn: 4352.7168576	total: 179ms	remaining: 44.6s
# 4:	learn: 4173.8058803	total: 187ms	remaining: 37.2s
# 5:	learn: 4014.2500336	total: 195ms	remaining: 32.2s
# 6:	learn: 3863.0967545	total: 202ms	remaining: 28.7s
# 7:	learn: 3723.8912156	total: 209ms	remaining: 25.9s
# 8:	learn: 3606.3580110	total: 217ms	remaining: 23.9s
# 9:	learn: 3498.9571490	total: 224ms	remaining: 22.2s
# 10:	learn: 3397.5678431	total: 232ms	remaining: 20.9s
# 11:	learn: 3302.9865291	total: 239ms	remaining: 19.7s
# 12:	learn: 3212.7203862	total: 247ms	remaining: 18.7s
# 13:	learn: 3135.3063162	total: 254ms	remaining: 17.9s
# 14:	learn: 3064.7236244	total: 262ms	remaining: 17.2s
# 15:	learn: 2995.7489915	total: 270ms	remaining: 16.6s
# 16:	learn: 2933.7972813	total: 279ms	remaining: 16.1s
# 17:	learn: 2878.0526935	total: 287ms	remaining: 15.6s
# 18:	learn: 2829.2337876	total: 295ms	remaining: 15.2s
# 19:	learn: 2783.2087462	total: 302ms	remaining: 14.8s
# 20:	learn: 2743.1044432	total: 310ms	remaining: 14.4s
# 21:	learn: 2704.6746061	total: 317ms	remaining: 14.1s
# 22:	learn: 2669.7937514	total: 325ms	remaining: 13.8s
# 23:	learn: 2638.4107843	total: 333ms	remaining: 13.5s
# 24:	learn: 2612.8921908	total: 341ms	remaining: 13.3s
# 25:	learn: 2586.2982322	total: 349ms	remaining: 13.1s
# 26:	learn: 2564.0631814	total: 356ms	remaining: 12.8s
# 27:	learn: 2542.6946936	total: 363ms	remaining: 12.6s
# 28:	learn: 2522.1044815	total: 371ms	remaining: 12.4s
# 29:	learn: 2503.3097373	total: 378ms	remaining: 12.2s
# 30:	learn: 2485.7101676	total: 385ms	remaining: 12s
# 31:	learn: 2470.8055416	total: 392ms	remaining: 11.9s
# 32:	learn: 2454.9944317	total: 399ms	remaining: 11.7s
# 33:	learn: 2441.3960056	total: 407ms	remaining: 11.6s
# 34:	learn: 2429.2539962	total: 415ms	remaining: 11.4s
# 35:	learn: 2417.1644968	total: 422ms	remaining: 11.3s
# 36:	learn: 2405.4511172	total: 430ms	remaining: 11.2s
# 37:	learn: 2395.6803802	total: 437ms	remaining: 11.1s
# 38:	learn: 2386.9537269	total: 445ms	remaining: 11s
# 39:	learn: 2378.0950812	total: 452ms	remaining: 10.9s
# 40:	learn: 2369.2865357	total: 460ms	remaining: 10.8s
# 41:	learn: 2362.5018911	total: 467ms	remaining: 10.7s
# 42:	learn: 2354.3604576	total: 475ms	remaining: 10.6s
# 43:	learn: 2347.9408473	total: 482ms	remaining: 10.5s
# 44:	learn: 2340.6466279	total: 489ms	remaining: 10.4s
# 45:	learn: 2334.1920016	total: 497ms	remaining: 10.3s
# 46:	learn: 2328.3979634	total: 504ms	remaining: 10.2s
# 47:	learn: 2323.1821879	total: 512ms	remaining: 10.2s
# 48:	learn: 2317.0406755	total: 519ms	remaining: 10.1s
# 49:	learn: 2311.9305050	total: 527ms	remaining: 10s
# 50:	learn: 2307.0811156	total: 534ms	remaining: 9.93s
# 51:	learn: 2302.9225110	total: 541ms	remaining: 9.87s
# 52:	learn: 2297.7753428	total: 549ms	remaining: 9.81s
# 53:	learn: 2292.1448871	total: 556ms	remaining: 9.74s
# 54:	learn: 2288.5737341	total: 563ms	remaining: 9.68s
# 55:	learn: 2284.7940132	total: 571ms	remaining: 9.62s
# 56:	learn: 2281.0752825	total: 578ms	remaining: 9.56s
# 57:	learn: 2276.7902773	total: 586ms	remaining: 9.51s
# 58:	learn: 2273.2480505	total: 593ms	remaining: 9.46s
# 59:	learn: 2269.8267661	total: 600ms	remaining: 9.4s
# 60:	learn: 2266.9308139	total: 609ms	remaining: 9.37s
# 61:	learn: 2263.4244914	total: 617ms	remaining: 9.33s
# 62:	learn: 2259.8642926	total: 624ms	remaining: 9.28s
# 63:	learn: 2257.1172858	total: 632ms	remaining: 9.24s
# 64:	learn: 2253.9510170	total: 640ms	remaining: 9.2s
# 65:	learn: 2249.3574762	total: 647ms	remaining: 9.15s
# 66:	learn: 2247.3181467	total: 654ms	remaining: 9.11s
# 67:	learn: 2244.5636559	total: 661ms	remaining: 9.06s
# 68:	learn: 2242.1757228	total: 669ms	remaining: 9.02s
# 69:	learn: 2239.6564809	total: 676ms	remaining: 8.98s
# 70:	learn: 2237.2223598	total: 683ms	remaining: 8.94s
# 71:	learn: 2233.9230743	total: 691ms	remaining: 8.9s
# 72:	learn: 2231.3239146	total: 698ms	remaining: 8.86s
# 73:	learn: 2229.1231239	total: 705ms	remaining: 8.83s
# 74:	learn: 2225.3016393	total: 713ms	remaining: 8.79s
# 75:	learn: 2221.8770135	total: 720ms	remaining: 8.76s
# 76:	learn: 2219.3058800	total: 728ms	remaining: 8.73s
# 77:	learn: 2216.9556211	total: 735ms	remaining: 8.69s
# 78:	learn: 2215.3260845	total: 743ms	remaining: 8.66s
# 79:	learn: 2213.3904343	total: 750ms	remaining: 8.63s
# 80:	learn: 2212.0406415	total: 758ms	remaining: 8.6s
# 81:	learn: 2210.1015208	total: 765ms	remaining: 8.57s
# 82:	learn: 2208.1277994	total: 773ms	remaining: 8.54s
# 83:	learn: 2205.3649127	total: 780ms	remaining: 8.51s
# 84:	learn: 2202.9139070	total: 788ms	remaining: 8.48s
# 85:	learn: 2201.4139144	total: 796ms	remaining: 8.46s
# 86:	learn: 2199.3142612	total: 803ms	remaining: 8.43s
# 87:	learn: 2197.4688174	total: 810ms	remaining: 8.4s
# 88:	learn: 2195.4595857	total: 818ms	remaining: 8.37s
# 89:	learn: 2193.4765294	total: 826ms	remaining: 8.36s
# 90:	learn: 2191.9899354	total: 834ms	remaining: 8.34s
# 91:	learn: 2190.5358479	total: 842ms	remaining: 8.31s
# 92:	learn: 2188.6146680	total: 849ms	remaining: 8.28s
# 93:	learn: 2186.6157652	total: 857ms	remaining: 8.26s
# 94:	learn: 2185.4547618	total: 864ms	remaining: 8.23s
# 95:	learn: 2184.1191247	total: 871ms	remaining: 8.2s
# 96:	learn: 2182.1839152	total: 879ms	remaining: 8.18s
# 97:	learn: 2180.0207689	total: 886ms	remaining: 8.16s
# 98:	learn: 2178.7368344	total: 894ms	remaining: 8.13s
# 99:	learn: 2177.5515808	total: 901ms	remaining: 8.11s
# 100:	learn: 2177.0864607	total: 909ms	remaining: 8.09s
# 101:	learn: 2175.5958619	total: 916ms	remaining: 8.07s
# 102:	learn: 2174.3178814	total: 924ms	remaining: 8.04s
# 103:	learn: 2172.8150150	total: 931ms	remaining: 8.02s
# 104:	learn: 2171.2785077	total: 939ms	remaining: 8.01s
# 105:	learn: 2169.9994966	total: 947ms	remaining: 7.99s
# 106:	learn: 2169.7259824	total: 955ms	remaining: 7.97s
# 107:	learn: 2168.4281503	total: 962ms	remaining: 7.95s
# 108:	learn: 2165.8827283	total: 970ms	remaining: 7.93s
# 109:	learn: 2164.4477972	total: 978ms	remaining: 7.92s
# 110:	learn: 2163.1783532	total: 986ms	remaining: 7.89s
# 111:	learn: 2163.0135651	total: 993ms	remaining: 7.88s
# 112:	learn: 2162.0179956	total: 1s	remaining: 7.86s
# 113:	learn: 2160.1566594	total: 1.01s	remaining: 7.84s
# 114:	learn: 2158.8141518	total: 1.02s	remaining: 7.82s
# 115:	learn: 2156.8415119	total: 1.02s	remaining: 7.8s
# 116:	learn: 2155.7683635	total: 1.03s	remaining: 7.79s
# 117:	learn: 2153.9068012	total: 1.04s	remaining: 7.77s
# 118:	learn: 2151.9316607	total: 1.05s	remaining: 7.76s
# 119:	learn: 2150.9579390	total: 1.05s	remaining: 7.74s
# 120:	learn: 2149.6050762	total: 1.06s	remaining: 7.72s
# 121:	learn: 2147.8194573	total: 1.07s	remaining: 7.71s
# 122:	learn: 2146.6204000	total: 1.08s	remaining: 7.69s
# 123:	learn: 2145.6197757	total: 1.09s	remaining: 7.68s
# 124:	learn: 2144.2281328	total: 1.09s	remaining: 7.66s
# 125:	learn: 2144.0414226	total: 1.1s	remaining: 7.64s
# 126:	learn: 2142.6242969	total: 1.11s	remaining: 7.63s
# 127:	learn: 2141.8137313	total: 1.12s	remaining: 7.61s
# 128:	learn: 2141.0426865	total: 1.13s	remaining: 7.6s
# 129:	learn: 2139.1870508	total: 1.13s	remaining: 7.58s
# 130:	learn: 2137.3990400	total: 1.14s	remaining: 7.57s
# 131:	learn: 2137.1761937	total: 1.15s	remaining: 7.55s
# 132:	learn: 2135.0384553	total: 1.16s	remaining: 7.53s
# 133:	learn: 2133.8279258	total: 1.16s	remaining: 7.52s
# 134:	learn: 2132.6421928	total: 1.17s	remaining: 7.5s
# 135:	learn: 2131.3308389	total: 1.18s	remaining: 7.49s
# 136:	learn: 2130.2671973	total: 1.19s	remaining: 7.47s
# 137:	learn: 2130.0388761	total: 1.19s	remaining: 7.46s
# 138:	learn: 2129.4787002	total: 1.2s	remaining: 7.44s
# 139:	learn: 2127.5874355	total: 1.21s	remaining: 7.43s
# 140:	learn: 2127.2166777	total: 1.22s	remaining: 7.41s
# 141:	learn: 2125.9215198	total: 1.22s	remaining: 7.4s
# 142:	learn: 2124.7332028	total: 1.23s	remaining: 7.38s
# 143:	learn: 2123.3246805	total: 1.24s	remaining: 7.37s
# 144:	learn: 2122.2461028	total: 1.25s	remaining: 7.36s
# 145:	learn: 2121.1422242	total: 1.25s	remaining: 7.34s
# 146:	learn: 2120.7625170	total: 1.26s	remaining: 7.33s
# 147:	learn: 2120.5622034	total: 1.27s	remaining: 7.31s
# 148:	learn: 2118.7663105	total: 1.28s	remaining: 7.3s
# 149:	learn: 2117.7055670	total: 1.28s	remaining: 7.29s
# 150:	learn: 2116.7086059	total: 1.31s	remaining: 7.36s
# 151:	learn: 2116.2184501	total: 1.32s	remaining: 7.34s
# 152:	learn: 2114.8270207	total: 1.32s	remaining: 7.33s
# 153:	learn: 2114.5788253	total: 1.33s	remaining: 7.32s
# 154:	learn: 2114.3680405	total: 1.34s	remaining: 7.3s
# 155:	learn: 2114.0195488	total: 1.35s	remaining: 7.28s
# 156:	learn: 2112.9907763	total: 1.35s	remaining: 7.27s
# 157:	learn: 2111.4346093	total: 1.36s	remaining: 7.25s
# 158:	learn: 2110.1429915	total: 1.37s	remaining: 7.24s
# 159:	learn: 2108.7338989	total: 1.38s	remaining: 7.22s
# 160:	learn: 2108.5795564	total: 1.38s	remaining: 7.21s
# 161:	learn: 2107.1648113	total: 1.39s	remaining: 7.19s
# 162:	learn: 2106.5095541	total: 1.4s	remaining: 7.18s
# 163:	learn: 2104.8797646	total: 1.41s	remaining: 7.17s
# 164:	learn: 2103.5953360	total: 1.41s	remaining: 7.15s
# 165:	learn: 2102.6215627	total: 1.42s	remaining: 7.14s
# 166:	learn: 2101.7577486	total: 1.43s	remaining: 7.12s
# 167:	learn: 2100.9132091	total: 1.44s	remaining: 7.11s
# 168:	learn: 2099.6088524	total: 1.44s	remaining: 7.1s
# 169:	learn: 2098.4040264	total: 1.45s	remaining: 7.09s
# 170:	learn: 2097.1268690	total: 1.46s	remaining: 7.08s
# 171:	learn: 2096.8371693	total: 1.47s	remaining: 7.06s
# 172:	learn: 2096.1466122	total: 1.47s	remaining: 7.05s
# 173:	learn: 2095.9629037	total: 1.48s	remaining: 7.03s
# 174:	learn: 2095.7931741	total: 1.49s	remaining: 7.02s
# 175:	learn: 2095.0524782	total: 1.5s	remaining: 7.01s
# 176:	learn: 2093.8946578	total: 1.5s	remaining: 7s
# 177:	learn: 2093.2188599	total: 1.51s	remaining: 6.98s
# 178:	learn: 2093.0383453	total: 1.52s	remaining: 6.97s
# 179:	learn: 2091.4081214	total: 1.53s	remaining: 6.96s
# 180:	learn: 2089.9758202	total: 1.53s	remaining: 6.94s
# 181:	learn: 2088.5196356	total: 1.54s	remaining: 6.93s
# 182:	learn: 2088.3448115	total: 1.55s	remaining: 6.92s
# 183:	learn: 2088.1906658	total: 1.56s	remaining: 6.91s
# 184:	learn: 2086.8206986	total: 1.57s	remaining: 6.9s
# 185:	learn: 2086.0345763	total: 1.57s	remaining: 6.89s
# 186:	learn: 2085.0486783	total: 1.58s	remaining: 6.88s
# 187:	learn: 2084.4462714	total: 1.59s	remaining: 6.87s
# 188:	learn: 2084.2883021	total: 1.6s	remaining: 6.85s
# 189:	learn: 2083.5853916	total: 1.6s	remaining: 6.84s
# 190:	learn: 2082.7823828	total: 1.61s	remaining: 6.83s
# 191:	learn: 2081.4173455	total: 1.62s	remaining: 6.82s
# 192:	learn: 2081.2654123	total: 1.63s	remaining: 6.8s
# 193:	learn: 2080.1559429	total: 1.64s	remaining: 6.79s
# 194:	learn: 2079.9119507	total: 1.64s	remaining: 6.78s
# 195:	learn: 2079.7655898	total: 1.65s	remaining: 6.77s
# 196:	learn: 2079.1220426	total: 1.66s	remaining: 6.76s
# 197:	learn: 2077.7900138	total: 1.67s	remaining: 6.75s
# 198:	learn: 2076.8688054	total: 1.67s	remaining: 6.74s
# 199:	learn: 2076.1791021	total: 1.68s	remaining: 6.73s
# 200:	learn: 2074.8261637	total: 1.69s	remaining: 6.71s
# 201:	learn: 2074.6007297	total: 1.7s	remaining: 6.7s
# 202:	learn: 2073.9028745	total: 1.7s	remaining: 6.69s
# 203:	learn: 2072.8525841	total: 1.71s	remaining: 6.68s
# 204:	learn: 2072.3275960	total: 1.72s	remaining: 6.67s
# 205:	learn: 2072.1933170	total: 1.73s	remaining: 6.65s
# 206:	learn: 2070.9405032	total: 1.73s	remaining: 6.64s
# 207:	learn: 2069.8922541	total: 1.74s	remaining: 6.63s
# 208:	learn: 2068.9229590	total: 1.75s	remaining: 6.62s
# 209:	learn: 2068.3989287	total: 1.76s	remaining: 6.61s
# 210:	learn: 2067.1195474	total: 1.76s	remaining: 6.6s
# 211:	learn: 2066.0004407	total: 1.77s	remaining: 6.59s
# 212:	learn: 2065.8643384	total: 1.78s	remaining: 6.58s
# 213:	learn: 2065.0503583	total: 1.79s	remaining: 6.56s
# 214:	learn: 2064.9173995	total: 1.79s	remaining: 6.55s
# 215:	learn: 2064.0167976	total: 1.8s	remaining: 6.54s
# 216:	learn: 2063.0413458	total: 1.81s	remaining: 6.53s
# 217:	learn: 2062.4802997	total: 1.82s	remaining: 6.52s
# 218:	learn: 2061.4136492	total: 1.82s	remaining: 6.5s
# 219:	learn: 2060.7889261	total: 1.83s	remaining: 6.49s
# 220:	learn: 2060.2799136	total: 1.84s	remaining: 6.48s
# 221:	learn: 2059.3252171	total: 1.85s	remaining: 6.47s
# 222:	learn: 2058.7567513	total: 1.85s	remaining: 6.46s
# 223:	learn: 2058.5422233	total: 1.86s	remaining: 6.45s
# 224:	learn: 2057.9801553	total: 1.87s	remaining: 6.44s
# 225:	learn: 2056.8662960	total: 1.88s	remaining: 6.43s
# 226:	learn: 2055.7595967	total: 1.89s	remaining: 6.42s
# 227:	learn: 2054.8895306	total: 1.89s	remaining: 6.41s
# 228:	learn: 2054.7639475	total: 1.9s	remaining: 6.4s
# 229:	learn: 2053.4792130	total: 1.91s	remaining: 6.39s
# 230:	learn: 2053.0455292	total: 1.92s	remaining: 6.38s
# 231:	learn: 2051.6824721	total: 1.92s	remaining: 6.37s
# 232:	learn: 2051.0153393	total: 1.93s	remaining: 6.36s
# 233:	learn: 2050.2204463	total: 1.94s	remaining: 6.35s
# 234:	learn: 2049.4113541	total: 1.95s	remaining: 6.34s
# 235:	learn: 2048.7398651	total: 1.95s	remaining: 6.33s
# 236:	learn: 2048.4118283	total: 1.96s	remaining: 6.31s
# 237:	learn: 2047.5921367	total: 1.97s	remaining: 6.3s
# 238:	learn: 2047.1326013	total: 1.98s	remaining: 6.29s
# 239:	learn: 2046.1506878	total: 1.98s	remaining: 6.28s
# 240:	learn: 2045.3497187	total: 1.99s	remaining: 6.27s
# 241:	learn: 2044.8329774	total: 2s	remaining: 6.26s
# 242:	learn: 2044.7159082	total: 2.01s	remaining: 6.25s
# 243:	learn: 2043.8431370	total: 2.01s	remaining: 6.24s
# 244:	learn: 2042.3664629	total: 2.02s	remaining: 6.23s
# 245:	learn: 2041.4003980	total: 2.03s	remaining: 6.22s
# 246:	learn: 2040.3099152	total: 2.04s	remaining: 6.21s
# 247:	learn: 2039.3723350	total: 2.04s	remaining: 6.2s
# 248:	learn: 2038.4147024	total: 2.05s	remaining: 6.19s
# 249:	learn: 2037.6885118	total: 2.06s	remaining: 6.18s
# 250:	learn: 2036.9799907	total: 2.07s	remaining: 6.17s
# 251:	learn: 2036.7848311	total: 2.08s	remaining: 6.17s
# 252:	learn: 2036.3445004	total: 2.08s	remaining: 6.16s
# 253:	learn: 2035.1115503	total: 2.09s	remaining: 6.14s
# 254:	learn: 2034.9918765	total: 2.1s	remaining: 6.13s
# 255:	learn: 2034.0396914	total: 2.11s	remaining: 6.12s
# 256:	learn: 2033.6965931	total: 2.11s	remaining: 6.11s
# 257:	learn: 2033.3087452	total: 2.12s	remaining: 6.1s
# 258:	learn: 2032.2917602	total: 2.13s	remaining: 6.09s
# 259:	learn: 2031.8256864	total: 2.14s	remaining: 6.08s
# 260:	learn: 2031.4277161	total: 2.14s	remaining: 6.07s
# 261:	learn: 2030.6419511	total: 2.15s	remaining: 6.06s
# 262:	learn: 2030.5254447	total: 2.16s	remaining: 6.05s
# 263:	learn: 2029.6884919	total: 2.17s	remaining: 6.04s
# 264:	learn: 2028.5598406	total: 2.17s	remaining: 6.03s
# 265:	learn: 2027.6605667	total: 2.18s	remaining: 6.02s
# 266:	learn: 2026.6284507	total: 2.19s	remaining: 6.01s
# 267:	learn: 2026.5166374	total: 2.2s	remaining: 6s
# 268:	learn: 2026.1447129	total: 2.21s	remaining: 5.99s
# 269:	learn: 2025.7873596	total: 2.21s	remaining: 5.98s
# 270:	learn: 2024.9165708	total: 2.22s	remaining: 5.97s
# 271:	learn: 2024.0367700	total: 2.23s	remaining: 5.97s
# 272:	learn: 2023.1464091	total: 2.24s	remaining: 5.96s
# 273:	learn: 2022.9070686	total: 2.25s	remaining: 5.95s
# 274:	learn: 2021.8218276	total: 2.25s	remaining: 5.94s
# 275:	learn: 2021.0261991	total: 2.27s	remaining: 5.97s
# 276:	learn: 2020.3517820	total: 2.28s	remaining: 5.96s
# 277:	learn: 2019.4563597	total: 2.29s	remaining: 5.95s
# 278:	learn: 2019.0847760	total: 2.3s	remaining: 5.93s
# 279:	learn: 2017.9773887	total: 2.31s	remaining: 5.93s
# 280:	learn: 2017.0033375	total: 2.31s	remaining: 5.92s
# 281:	learn: 2016.7795445	total: 2.32s	remaining: 5.91s
# 282:	learn: 2016.1532538	total: 2.33s	remaining: 5.9s
# 283:	learn: 2015.4921303	total: 2.33s	remaining: 5.89s
# 284:	learn: 2014.9536808	total: 2.34s	remaining: 5.88s
# 285:	learn: 2014.7507798	total: 2.35s	remaining: 5.87s
# 286:	learn: 2013.8445707	total: 2.36s	remaining: 5.86s
# 287:	learn: 2013.4215290	total: 2.37s	remaining: 5.85s
# 288:	learn: 2012.7941311	total: 2.37s	remaining: 5.84s
# 289:	learn: 2012.1497240	total: 2.38s	remaining: 5.83s
# 290:	learn: 2011.5264672	total: 2.39s	remaining: 5.82s
# 291:	learn: 2011.3680034	total: 2.4s	remaining: 5.81s
# 292:	learn: 2010.9021880	total: 2.4s	remaining: 5.8s
# 293:	learn: 2010.1765957	total: 2.41s	remaining: 5.79s
# 294:	learn: 2009.9728753	total: 2.42s	remaining: 5.79s
# 295:	learn: 2009.3013651	total: 2.43s	remaining: 5.78s
# 296:	learn: 2008.9500600	total: 2.44s	remaining: 5.77s
# 297:	learn: 2008.4944849	total: 2.44s	remaining: 5.76s
# 298:	learn: 2007.2930134	total: 2.45s	remaining: 5.75s
# 299:	learn: 2006.5833663	total: 2.46s	remaining: 5.74s
# 300:	learn: 2006.0883162	total: 2.47s	remaining: 5.73s
# 301:	learn: 2005.5730658	total: 2.48s	remaining: 5.72s
# 302:	learn: 2005.2416438	total: 2.48s	remaining: 5.71s
# 303:	learn: 2004.7840837	total: 2.49s	remaining: 5.71s
# 304:	learn: 2004.2194734	total: 2.5s	remaining: 5.7s
# 305:	learn: 2003.3088912	total: 2.51s	remaining: 5.69s
# 306:	learn: 2002.6661952	total: 2.52s	remaining: 5.68s
# 307:	learn: 2002.5559673	total: 2.52s	remaining: 5.67s
# 308:	learn: 2001.7391831	total: 2.53s	remaining: 5.66s
# 309:	learn: 2001.4234355	total: 2.54s	remaining: 5.65s
# 310:	learn: 2000.6283026	total: 2.55s	remaining: 5.64s
# 311:	learn: 2000.0143268	total: 2.55s	remaining: 5.63s
# 312:	learn: 1999.6673334	total: 2.56s	remaining: 5.62s
# 313:	learn: 1999.4417329	total: 2.57s	remaining: 5.61s
# 314:	learn: 1999.0996507	total: 2.58s	remaining: 5.61s
# 315:	learn: 1998.0878548	total: 2.58s	remaining: 5.6s
# 316:	learn: 1997.9809577	total: 2.59s	remaining: 5.59s
# 317:	learn: 1997.2457260	total: 2.6s	remaining: 5.58s
# 318:	learn: 1996.9640485	total: 2.61s	remaining: 5.57s
# 319:	learn: 1996.1245380	total: 2.62s	remaining: 5.56s
# 320:	learn: 1995.3656208	total: 2.62s	remaining: 5.55s
# 321:	learn: 1994.7737287	total: 2.63s	remaining: 5.54s
# 322:	learn: 1994.6709445	total: 2.64s	remaining: 5.53s
# 323:	learn: 1994.0013724	total: 2.65s	remaining: 5.52s
# 324:	learn: 1993.2302151	total: 2.65s	remaining: 5.51s
# 325:	learn: 1992.9046686	total: 2.66s	remaining: 5.51s
# 326:	learn: 1992.7021965	total: 2.67s	remaining: 5.5s
# 327:	learn: 1991.7131343	total: 2.68s	remaining: 5.49s
# 328:	learn: 1990.9671176	total: 2.69s	remaining: 5.48s
# 329:	learn: 1990.4681718	total: 2.69s	remaining: 5.47s
# 330:	learn: 1989.4638817	total: 2.7s	remaining: 5.46s
# 331:	learn: 1989.0587012	total: 2.71s	remaining: 5.46s
# 332:	learn: 1988.7106024	total: 2.72s	remaining: 5.45s
# 333:	learn: 1988.1611756	total: 2.73s	remaining: 5.44s
# 334:	learn: 1987.4017707	total: 2.73s	remaining: 5.43s
# 335:	learn: 1986.5689473	total: 2.74s	remaining: 5.42s
# 336:	learn: 1986.4682070	total: 2.75s	remaining: 5.41s
# 337:	learn: 1985.8457646	total: 2.76s	remaining: 5.4s
# 338:	learn: 1984.9424444	total: 2.77s	remaining: 5.39s
# 339:	learn: 1984.6614508	total: 2.77s	remaining: 5.38s
# 340:	learn: 1984.2203965	total: 2.78s	remaining: 5.37s
# 341:	learn: 1983.6330437	total: 2.79s	remaining: 5.37s
# 342:	learn: 1982.9577945	total: 2.8s	remaining: 5.36s
# 343:	learn: 1982.2570057	total: 2.8s	remaining: 5.35s
# 344:	learn: 1981.8564857	total: 2.81s	remaining: 5.34s
# 345:	learn: 1981.3002412	total: 2.82s	remaining: 5.33s
# 346:	learn: 1980.5800493	total: 2.83s	remaining: 5.32s
# 347:	learn: 1979.5670635	total: 2.83s	remaining: 5.31s
# 348:	learn: 1979.0530046	total: 2.84s	remaining: 5.3s
# 349:	learn: 1978.3302232	total: 2.85s	remaining: 5.29s
# 350:	learn: 1977.8022526	total: 2.86s	remaining: 5.29s
# 351:	learn: 1977.0174724	total: 2.87s	remaining: 5.28s
# 352:	learn: 1976.8692032	total: 2.87s	remaining: 5.27s
# 353:	learn: 1976.3412261	total: 2.88s	remaining: 5.26s
# 354:	learn: 1975.8464693	total: 2.89s	remaining: 5.25s
# 355:	learn: 1975.4673603	total: 2.9s	remaining: 5.24s
# 356:	learn: 1975.3699896	total: 2.9s	remaining: 5.23s
# 357:	learn: 1974.8604816	total: 2.91s	remaining: 5.22s
# 358:	learn: 1974.4879208	total: 2.92s	remaining: 5.21s
# 359:	learn: 1973.8624836	total: 2.93s	remaining: 5.21s
# 360:	learn: 1973.5465057	total: 2.94s	remaining: 5.2s
# 361:	learn: 1973.3258900	total: 2.94s	remaining: 5.19s
# 362:	learn: 1972.5889588	total: 2.95s	remaining: 5.18s
# 363:	learn: 1972.3333293	total: 2.96s	remaining: 5.17s
# 364:	learn: 1971.8060536	total: 2.97s	remaining: 5.16s
# 365:	learn: 1971.5546039	total: 2.97s	remaining: 5.15s
# 366:	learn: 1970.8662310	total: 2.98s	remaining: 5.14s
# 367:	learn: 1970.4500756	total: 2.99s	remaining: 5.13s
# 368:	learn: 1969.7154066	total: 3s	remaining: 5.13s
# 369:	learn: 1969.5178742	total: 3.01s	remaining: 5.12s
# 370:	learn: 1968.9235229	total: 3.01s	remaining: 5.11s
# 371:	learn: 1968.2372427	total: 3.02s	remaining: 5.1s
# 372:	learn: 1968.1426333	total: 3.03s	remaining: 5.09s
# 373:	learn: 1968.0505220	total: 3.04s	remaining: 5.08s
# 374:	learn: 1967.3654342	total: 3.04s	remaining: 5.08s
# 375:	learn: 1966.8067206	total: 3.05s	remaining: 5.07s
# 376:	learn: 1965.9930075	total: 3.06s	remaining: 5.06s
# 377:	learn: 1965.8387593	total: 3.07s	remaining: 5.05s
# 378:	learn: 1965.4136404	total: 3.08s	remaining: 5.04s
# 379:	learn: 1965.0312242	total: 3.08s	remaining: 5.03s
# 380:	learn: 1964.1668310	total: 3.09s	remaining: 5.02s
# 381:	learn: 1963.8837534	total: 3.1s	remaining: 5.01s
# 382:	learn: 1963.5097012	total: 3.11s	remaining: 5.01s
# 383:	learn: 1962.7792541	total: 3.12s	remaining: 5s
# 384:	learn: 1962.5102669	total: 3.12s	remaining: 4.99s
# 385:	learn: 1962.3221358	total: 3.13s	remaining: 4.98s
# 386:	learn: 1961.7322581	total: 3.14s	remaining: 4.97s
# 387:	learn: 1960.9393729	total: 3.15s	remaining: 4.96s
# 388:	learn: 1960.8488540	total: 3.15s	remaining: 4.95s
# 389:	learn: 1960.1123658	total: 3.16s	remaining: 4.94s
# 390:	learn: 1959.7452681	total: 3.17s	remaining: 4.93s
# 391:	learn: 1958.8989400	total: 3.17s	remaining: 4.92s
# 392:	learn: 1958.3657835	total: 3.18s	remaining: 4.92s
# 393:	learn: 1957.6144447	total: 3.19s	remaining: 4.91s
# 394:	learn: 1957.3711924	total: 3.2s	remaining: 4.9s
# 395:	learn: 1956.6699054	total: 3.2s	remaining: 4.89s
# 396:	learn: 1956.0082492	total: 3.21s	remaining: 4.88s
# 397:	learn: 1955.6935549	total: 3.22s	remaining: 4.87s
# 398:	learn: 1954.8731847	total: 3.23s	remaining: 4.86s
# 399:	learn: 1954.6271413	total: 3.23s	remaining: 4.85s
# 400:	learn: 1954.3867731	total: 3.24s	remaining: 4.84s
# 401:	learn: 1954.0970475	total: 3.25s	remaining: 4.83s
# 402:	learn: 1953.4016286	total: 3.26s	remaining: 4.83s
# 403:	learn: 1953.2623667	total: 3.27s	remaining: 4.82s
# 404:	learn: 1953.0197906	total: 3.27s	remaining: 4.81s
# 405:	learn: 1952.4424943	total: 3.28s	remaining: 4.8s
# 406:	learn: 1952.0532945	total: 3.29s	remaining: 4.79s
# 407:	learn: 1951.9649644	total: 3.29s	remaining: 4.78s
# 408:	learn: 1951.7731895	total: 3.3s	remaining: 4.77s
# 409:	learn: 1951.0820164	total: 3.31s	remaining: 4.76s
# 410:	learn: 1950.7016038	total: 3.32s	remaining: 4.75s
# 411:	learn: 1950.2911541	total: 3.33s	remaining: 4.75s
# 412:	learn: 1949.5452973	total: 3.33s	remaining: 4.74s
# 413:	learn: 1949.1429614	total: 3.34s	remaining: 4.73s
# 414:	learn: 1948.7980869	total: 3.35s	remaining: 4.72s
# 415:	learn: 1948.6129659	total: 3.35s	remaining: 4.71s
# 416:	learn: 1948.3951438	total: 3.36s	remaining: 4.7s
# 417:	learn: 1947.6882334	total: 3.37s	remaining: 4.69s
# 418:	learn: 1947.0978970	total: 3.38s	remaining: 4.68s
# 419:	learn: 1946.6972745	total: 3.39s	remaining: 4.67s
# 420:	learn: 1946.6112229	total: 3.39s	remaining: 4.67s
# 421:	learn: 1946.0582354	total: 3.4s	remaining: 4.66s
# 422:	learn: 1945.2967795	total: 3.41s	remaining: 4.65s
# 423:	learn: 1945.2129994	total: 3.42s	remaining: 4.64s
# 424:	learn: 1944.8863139	total: 3.42s	remaining: 4.63s
# 425:	learn: 1944.3526372	total: 3.43s	remaining: 4.62s
# 426:	learn: 1944.0754255	total: 3.44s	remaining: 4.62s
# 427:	learn: 1943.9243220	total: 3.45s	remaining: 4.61s
# 428:	learn: 1943.7965820	total: 3.45s	remaining: 4.6s
# 429:	learn: 1943.5548151	total: 3.46s	remaining: 4.59s
# 430:	learn: 1942.9105930	total: 3.47s	remaining: 4.58s
# 431:	learn: 1942.8288531	total: 3.48s	remaining: 4.57s
# 432:	learn: 1942.4842173	total: 3.48s	remaining: 4.56s
# 433:	learn: 1942.0415397	total: 3.49s	remaining: 4.55s
# 434:	learn: 1941.9302403	total: 3.5s	remaining: 4.54s
# 435:	learn: 1941.5649494	total: 3.51s	remaining: 4.54s
# 436:	learn: 1941.1185665	total: 3.52s	remaining: 4.54s
# 437:	learn: 1940.1804770	total: 3.53s	remaining: 4.53s
# 438:	learn: 1939.5264900	total: 3.54s	remaining: 4.52s
# 439:	learn: 1938.9336386	total: 3.55s	remaining: 4.51s
# 440:	learn: 1938.4780913	total: 3.56s	remaining: 4.51s
# 441:	learn: 1938.2575338	total: 3.56s	remaining: 4.5s
# 442:	learn: 1937.7247086	total: 3.57s	remaining: 4.49s
# 443:	learn: 1937.0352974	total: 3.58s	remaining: 4.48s
# 444:	learn: 1936.6630465	total: 3.58s	remaining: 4.47s
# 445:	learn: 1936.1810144	total: 3.59s	remaining: 4.46s
# 446:	learn: 1935.7832916	total: 3.6s	remaining: 4.45s
# 447:	learn: 1935.6154807	total: 3.61s	remaining: 4.45s
# 448:	learn: 1935.2785466	total: 3.62s	remaining: 4.44s
# 449:	learn: 1934.6825307	total: 3.62s	remaining: 4.43s
# 450:	learn: 1933.9447590	total: 3.63s	remaining: 4.42s
# 451:	learn: 1933.4403381	total: 3.64s	remaining: 4.41s
# 452:	learn: 1932.9485384	total: 3.65s	remaining: 4.4s
# 453:	learn: 1932.3107502	total: 3.65s	remaining: 4.39s
# 454:	learn: 1931.5672736	total: 3.66s	remaining: 4.38s
# 455:	learn: 1931.3437707	total: 3.67s	remaining: 4.38s
# 456:	learn: 1931.1571005	total: 3.67s	remaining: 4.37s
# 457:	learn: 1930.4675232	total: 3.68s	remaining: 4.36s
# 458:	learn: 1929.7428331	total: 3.69s	remaining: 4.35s
# 459:	learn: 1929.3224932	total: 3.7s	remaining: 4.34s
# 460:	learn: 1928.8827832	total: 3.71s	remaining: 4.33s
# 461:	learn: 1928.6987373	total: 3.71s	remaining: 4.32s
# 462:	learn: 1928.4886367	total: 3.72s	remaining: 4.32s
# 463:	learn: 1928.0522970	total: 3.73s	remaining: 4.31s
# 464:	learn: 1927.9729956	total: 3.73s	remaining: 4.3s
# 465:	learn: 1927.4107593	total: 3.74s	remaining: 4.29s
# 466:	learn: 1926.9066486	total: 3.75s	remaining: 4.28s
# 467:	learn: 1926.3857698	total: 3.76s	remaining: 4.27s
# 468:	learn: 1926.0361335	total: 3.77s	remaining: 4.26s
# 469:	learn: 1925.4751123	total: 3.77s	remaining: 4.25s
# 470:	learn: 1925.2642055	total: 3.78s	remaining: 4.25s
# 471:	learn: 1924.6768876	total: 3.79s	remaining: 4.24s
# 472:	learn: 1924.4813765	total: 3.79s	remaining: 4.23s
# 473:	learn: 1924.2599484	total: 3.8s	remaining: 4.22s
# 474:	learn: 1923.6516790	total: 3.81s	remaining: 4.21s
# 475:	learn: 1922.9847503	total: 3.82s	remaining: 4.2s
# 476:	learn: 1922.8006616	total: 3.82s	remaining: 4.19s
# 477:	learn: 1922.4817096	total: 3.83s	remaining: 4.18s
# 478:	learn: 1921.7654622	total: 3.84s	remaining: 4.18s
# 479:	learn: 1921.2022340	total: 3.85s	remaining: 4.17s
# 480:	learn: 1920.9913789	total: 3.85s	remaining: 4.16s
# 481:	learn: 1920.6807319	total: 3.86s	remaining: 4.15s
# 482:	learn: 1920.5221463	total: 3.87s	remaining: 4.14s
# 483:	learn: 1920.0320552	total: 3.88s	remaining: 4.13s
# 484:	learn: 1919.5137063	total: 3.88s	remaining: 4.12s
# 485:	learn: 1919.1084037	total: 3.89s	remaining: 4.11s
# 486:	learn: 1918.9087481	total: 3.9s	remaining: 4.11s
# 487:	learn: 1918.6545511	total: 3.9s	remaining: 4.1s
# 488:	learn: 1918.0424304	total: 3.91s	remaining: 4.09s
# 489:	learn: 1917.4549296	total: 3.92s	remaining: 4.08s
# 490:	learn: 1917.3517213	total: 3.93s	remaining: 4.08s
# 491:	learn: 1916.8412728	total: 3.94s	remaining: 4.07s
# 492:	learn: 1916.6674179	total: 3.95s	remaining: 4.06s
# 493:	learn: 1916.2223877	total: 3.95s	remaining: 4.05s
# 494:	learn: 1915.8071967	total: 3.96s	remaining: 4.04s
# 495:	learn: 1915.2794837	total: 3.97s	remaining: 4.03s
# 496:	learn: 1914.8554986	total: 3.98s	remaining: 4.02s
# 497:	learn: 1914.6769075	total: 3.98s	remaining: 4.01s
# 498:	learn: 1914.3504401	total: 3.99s	remaining: 4.01s
# 499:	learn: 1914.0584206	total: 4s	remaining: 4s
# 500:	learn: 1913.6628927	total: 4.01s	remaining: 3.99s
# 501:	learn: 1913.5110552	total: 4.01s	remaining: 3.98s
# 502:	learn: 1913.3079520	total: 4.02s	remaining: 3.97s
# 503:	learn: 1913.0970300	total: 4.03s	remaining: 3.96s
# 504:	learn: 1912.8117066	total: 4.04s	remaining: 3.96s
# 505:	learn: 1912.7369887	total: 4.04s	remaining: 3.95s
# 506:	learn: 1912.5041811	total: 4.05s	remaining: 3.94s
# 507:	learn: 1912.1412647	total: 4.06s	remaining: 3.93s
# 508:	learn: 1911.5190015	total: 4.07s	remaining: 3.92s
# 509:	learn: 1911.1701398	total: 4.07s	remaining: 3.91s
# 510:	learn: 1910.5983870	total: 4.08s	remaining: 3.9s
# 511:	learn: 1910.4356227	total: 4.09s	remaining: 3.9s
# 512:	learn: 1910.1849502	total: 4.09s	remaining: 3.89s
# 513:	learn: 1910.0094400	total: 4.1s	remaining: 3.88s
# 514:	learn: 1909.4919107	total: 4.11s	remaining: 3.87s
# 515:	learn: 1909.4178902	total: 4.12s	remaining: 3.86s
# 516:	learn: 1908.6186491	total: 4.13s	remaining: 3.85s
# 517:	learn: 1907.9946761	total: 4.13s	remaining: 3.85s
# 518:	learn: 1907.4227868	total: 4.14s	remaining: 3.84s
# 519:	learn: 1907.0145959	total: 4.15s	remaining: 3.83s
# 520:	learn: 1906.5709560	total: 4.16s	remaining: 3.82s
# 521:	learn: 1906.1123947	total: 4.16s	remaining: 3.81s
# 522:	learn: 1905.7607799	total: 4.17s	remaining: 3.8s
# 523:	learn: 1905.3139673	total: 4.18s	remaining: 3.79s
# 524:	learn: 1904.7457290	total: 4.18s	remaining: 3.79s
# 525:	learn: 1904.6777224	total: 4.19s	remaining: 3.78s
# 526:	learn: 1904.5088841	total: 4.2s	remaining: 3.77s
# 527:	learn: 1903.9018146	total: 4.21s	remaining: 3.76s
# 528:	learn: 1903.5669458	total: 4.21s	remaining: 3.75s
# 529:	learn: 1903.4158191	total: 4.22s	remaining: 3.74s
# 530:	learn: 1903.0579094	total: 4.23s	remaining: 3.74s
# 531:	learn: 1902.5816554	total: 4.24s	remaining: 3.73s
# 532:	learn: 1902.0950863	total: 4.25s	remaining: 3.72s
# 533:	learn: 1901.4854554	total: 4.25s	remaining: 3.71s
# 534:	learn: 1901.2407447	total: 4.26s	remaining: 3.7s
# 535:	learn: 1900.8019514	total: 4.27s	remaining: 3.69s
# 536:	learn: 1900.6019517	total: 4.28s	remaining: 3.69s
# 537:	learn: 1900.0351281	total: 4.28s	remaining: 3.68s
# 538:	learn: 1899.5787191	total: 4.29s	remaining: 3.67s
# 539:	learn: 1899.5075960	total: 4.3s	remaining: 3.66s
# 540:	learn: 1898.9323355	total: 4.3s	remaining: 3.65s
# 541:	learn: 1898.6843998	total: 4.31s	remaining: 3.64s
# 542:	learn: 1898.5304240	total: 4.32s	remaining: 3.64s
# 543:	learn: 1898.2476172	total: 4.33s	remaining: 3.63s
# 544:	learn: 1897.9463845	total: 4.34s	remaining: 3.62s
# 545:	learn: 1897.8346510	total: 4.34s	remaining: 3.61s
# 546:	learn: 1897.5464167	total: 4.35s	remaining: 3.6s
# 547:	learn: 1897.1434661	total: 4.36s	remaining: 3.6s
# 548:	learn: 1897.0738367	total: 4.37s	remaining: 3.59s
# 549:	learn: 1896.4946567	total: 4.37s	remaining: 3.58s
# 550:	learn: 1896.2654046	total: 4.38s	remaining: 3.57s
# 551:	learn: 1895.8105977	total: 4.39s	remaining: 3.56s
# 552:	learn: 1895.2871274	total: 4.4s	remaining: 3.55s
# 553:	learn: 1895.1004300	total: 4.4s	remaining: 3.54s
# 554:	learn: 1894.8723245	total: 4.41s	remaining: 3.54s
# 555:	learn: 1894.6779463	total: 4.42s	remaining: 3.53s
# 556:	learn: 1894.4711417	total: 4.42s	remaining: 3.52s
# 557:	learn: 1894.1557812	total: 4.43s	remaining: 3.51s
# 558:	learn: 1893.9725990	total: 4.44s	remaining: 3.5s
# 559:	learn: 1893.5857631	total: 4.45s	remaining: 3.49s
# 560:	learn: 1893.0098386	total: 4.46s	remaining: 3.49s
# 561:	learn: 1892.3894080	total: 4.46s	remaining: 3.48s
# 562:	learn: 1892.1679231	total: 4.47s	remaining: 3.47s
# 563:	learn: 1892.0605642	total: 4.48s	remaining: 3.46s
# 564:	learn: 1891.4737645	total: 4.48s	remaining: 3.45s
# 565:	learn: 1891.4054951	total: 4.49s	remaining: 3.44s
# 566:	learn: 1890.9628684	total: 4.5s	remaining: 3.44s
# 567:	learn: 1890.5901007	total: 4.51s	remaining: 3.43s
# 568:	learn: 1890.3559036	total: 4.51s	remaining: 3.42s
# 569:	learn: 1890.1095741	total: 4.52s	remaining: 3.41s
# 570:	learn: 1889.7774356	total: 4.53s	remaining: 3.4s
# 571:	learn: 1889.6659815	total: 4.54s	remaining: 3.4s
# 572:	learn: 1889.1305372	total: 4.54s	remaining: 3.39s
# 573:	learn: 1889.0636522	total: 4.55s	remaining: 3.38s
# 574:	learn: 1888.5087467	total: 4.56s	remaining: 3.37s
# 575:	learn: 1888.1663489	total: 4.57s	remaining: 3.36s
# 576:	learn: 1887.9965085	total: 4.58s	remaining: 3.35s
# 577:	learn: 1887.8400580	total: 4.58s	remaining: 3.35s
# 578:	learn: 1887.4264470	total: 4.59s	remaining: 3.34s
# 579:	learn: 1887.3192573	total: 4.6s	remaining: 3.33s
# 580:	learn: 1886.9879151	total: 4.61s	remaining: 3.32s
# 581:	learn: 1886.4944066	total: 4.61s	remaining: 3.31s
# 582:	learn: 1886.0615895	total: 4.62s	remaining: 3.3s
# 583:	learn: 1885.7301656	total: 4.63s	remaining: 3.3s
# 584:	learn: 1885.5897471	total: 4.63s	remaining: 3.29s
# 585:	learn: 1885.5241223	total: 4.64s	remaining: 3.28s
# 586:	learn: 1885.3936165	total: 4.65s	remaining: 3.27s
# 587:	learn: 1885.0292246	total: 4.66s	remaining: 3.26s
# 588:	learn: 1884.8296338	total: 4.66s	remaining: 3.25s
# 589:	learn: 1884.1912022	total: 4.67s	remaining: 3.25s
# 590:	learn: 1883.9100468	total: 4.68s	remaining: 3.24s
# 591:	learn: 1883.6447641	total: 4.69s	remaining: 3.23s
# 592:	learn: 1883.5441198	total: 4.69s	remaining: 3.22s
# 593:	learn: 1883.2347398	total: 4.7s	remaining: 3.21s
# 594:	learn: 1882.8422189	total: 4.71s	remaining: 3.21s
# 595:	learn: 1882.6699284	total: 4.72s	remaining: 3.2s
# 596:	learn: 1882.1592062	total: 4.72s	remaining: 3.19s
# 597:	learn: 1881.4942376	total: 4.73s	remaining: 3.18s
# 598:	learn: 1881.1349690	total: 4.74s	remaining: 3.17s
# 599:	learn: 1880.9593684	total: 4.75s	remaining: 3.16s
# 600:	learn: 1880.4181277	total: 4.75s	remaining: 3.16s
# 601:	learn: 1880.2574968	total: 4.76s	remaining: 3.15s
# 602:	learn: 1880.1869212	total: 4.77s	remaining: 3.14s
# 603:	learn: 1880.1184894	total: 4.78s	remaining: 3.13s
# 604:	learn: 1879.2840291	total: 4.78s	remaining: 3.12s
# 605:	learn: 1879.2170314	total: 4.79s	remaining: 3.12s
# 606:	learn: 1879.1518611	total: 4.8s	remaining: 3.11s
# 607:	learn: 1879.0886054	total: 4.81s	remaining: 3.1s
# 608:	learn: 1879.0267364	total: 4.81s	remaining: 3.09s
# 609:	learn: 1878.6029345	total: 4.82s	remaining: 3.08s
# 610:	learn: 1878.5425137	total: 4.83s	remaining: 3.07s
# 611:	learn: 1878.3807996	total: 4.84s	remaining: 3.07s
# 612:	learn: 1877.8962473	total: 4.84s	remaining: 3.06s
# 613:	learn: 1877.8373963	total: 4.85s	remaining: 3.05s
# 614:	learn: 1877.6725535	total: 4.86s	remaining: 3.04s
# 615:	learn: 1877.6149593	total: 4.87s	remaining: 3.03s
# 616:	learn: 1877.3608023	total: 4.87s	remaining: 3.02s
# 617:	learn: 1876.9439603	total: 4.88s	remaining: 3.02s
# 618:	learn: 1876.7014780	total: 4.89s	remaining: 3.01s
# 619:	learn: 1876.2460219	total: 4.89s	remaining: 3s
# 620:	learn: 1876.1884521	total: 4.9s	remaining: 2.99s
# 621:	learn: 1875.8467896	total: 4.91s	remaining: 2.98s
# 622:	learn: 1875.7922664	total: 4.92s	remaining: 2.98s
# 623:	learn: 1875.7365488	total: 4.92s	remaining: 2.97s
# 624:	learn: 1875.4528225	total: 4.93s	remaining: 2.96s
# 625:	learn: 1874.8972445	total: 4.94s	remaining: 2.95s
# 626:	learn: 1874.5738567	total: 4.95s	remaining: 2.94s
# 627:	learn: 1874.4336454	total: 4.96s	remaining: 2.94s
# 628:	learn: 1874.1752665	total: 4.96s	remaining: 2.93s
# 629:	learn: 1874.1233864	total: 4.97s	remaining: 2.92s
# 630:	learn: 1873.8109768	total: 4.98s	remaining: 2.91s
# 631:	learn: 1873.6192881	total: 4.99s	remaining: 2.9s
# 632:	learn: 1873.1515395	total: 4.99s	remaining: 2.9s
# 633:	learn: 1872.7536747	total: 5s	remaining: 2.89s
# 634:	learn: 1872.5997058	total: 5.01s	remaining: 2.88s
# 635:	learn: 1872.3352509	total: 5.01s	remaining: 2.87s
# 636:	learn: 1872.2815286	total: 5.02s	remaining: 2.86s
# 637:	learn: 1872.1559121	total: 5.03s	remaining: 2.85s
# 638:	learn: 1871.9809818	total: 5.04s	remaining: 2.85s
# 639:	learn: 1871.7468051	total: 5.04s	remaining: 2.84s
# 640:	learn: 1871.3765380	total: 5.05s	remaining: 2.83s
# 641:	learn: 1871.2544996	total: 5.06s	remaining: 2.82s
# 642:	learn: 1870.9753588	total: 5.07s	remaining: 2.81s
# 643:	learn: 1870.9178551	total: 5.08s	remaining: 2.81s
# 644:	learn: 1870.7153349	total: 5.08s	remaining: 2.8s
# 645:	learn: 1870.3469155	total: 5.09s	remaining: 2.79s
# 646:	learn: 1869.7840584	total: 5.1s	remaining: 2.78s
# 647:	learn: 1869.2683125	total: 5.1s	remaining: 2.77s
# 648:	learn: 1868.9157083	total: 5.11s	remaining: 2.76s
# 649:	learn: 1868.7882086	total: 5.12s	remaining: 2.76s
# 650:	learn: 1868.3762701	total: 5.13s	remaining: 2.75s
# 651:	learn: 1868.1351374	total: 5.13s	remaining: 2.74s
# 652:	learn: 1867.6162287	total: 5.14s	remaining: 2.73s
# 653:	learn: 1866.8977507	total: 5.15s	remaining: 2.72s
# 654:	learn: 1866.2905183	total: 5.16s	remaining: 2.72s
# 655:	learn: 1865.7647795	total: 5.17s	remaining: 2.71s
# 656:	learn: 1865.6252401	total: 5.17s	remaining: 2.7s
# 657:	learn: 1865.5732178	total: 5.18s	remaining: 2.69s
# 658:	learn: 1865.2727305	total: 5.19s	remaining: 2.68s
# 659:	learn: 1865.1162032	total: 5.2s	remaining: 2.68s
# 660:	learn: 1865.0121231	total: 5.2s	remaining: 2.67s
# 661:	learn: 1864.4969302	total: 5.21s	remaining: 2.66s
# 662:	learn: 1864.2212894	total: 5.22s	remaining: 2.65s
# 663:	learn: 1863.9936609	total: 5.22s	remaining: 2.64s
# 664:	learn: 1863.4045745	total: 5.23s	remaining: 2.64s
# 665:	learn: 1863.1309622	total: 5.24s	remaining: 2.63s
# 666:	learn: 1862.5735818	total: 5.25s	remaining: 2.62s
# 667:	learn: 1862.4657900	total: 5.25s	remaining: 2.61s
# 668:	learn: 1862.1696916	total: 5.26s	remaining: 2.6s
# 669:	learn: 1861.5741044	total: 5.27s	remaining: 2.6s
# 670:	learn: 1861.5233266	total: 5.28s	remaining: 2.59s
# 671:	learn: 1861.3228673	total: 5.29s	remaining: 2.58s
# 672:	learn: 1860.6806267	total: 5.29s	remaining: 2.57s
# 673:	learn: 1860.3269929	total: 5.3s	remaining: 2.56s
# 674:	learn: 1860.0168027	total: 5.31s	remaining: 2.56s
# 675:	learn: 1859.6665679	total: 5.31s	remaining: 2.55s
# 676:	learn: 1859.1173590	total: 5.32s	remaining: 2.54s
# 677:	learn: 1858.9406225	total: 5.33s	remaining: 2.53s
# 678:	learn: 1858.4708517	total: 5.34s	remaining: 2.52s
# 679:	learn: 1858.0594852	total: 5.34s	remaining: 2.52s
# 680:	learn: 1857.8303682	total: 5.35s	remaining: 2.51s
# 681:	learn: 1857.6915014	total: 5.36s	remaining: 2.5s
# 682:	learn: 1857.3413564	total: 5.37s	remaining: 2.49s
# 683:	learn: 1856.7319702	total: 5.38s	remaining: 2.48s
# 684:	learn: 1856.5394424	total: 5.38s	remaining: 2.48s
# 685:	learn: 1856.0347451	total: 5.39s	remaining: 2.47s
# 686:	learn: 1855.6938826	total: 5.4s	remaining: 2.46s
# 687:	learn: 1855.3257723	total: 5.41s	remaining: 2.45s
# 688:	learn: 1855.1192701	total: 5.41s	remaining: 2.44s
# 689:	learn: 1854.9314068	total: 5.42s	remaining: 2.44s
# 690:	learn: 1854.4195625	total: 5.43s	remaining: 2.43s
# 691:	learn: 1853.9316347	total: 5.44s	remaining: 2.42s
# 692:	learn: 1853.6119657	total: 5.44s	remaining: 2.41s
# 693:	learn: 1853.4339625	total: 5.45s	remaining: 2.4s
# 694:	learn: 1853.0594490	total: 5.46s	remaining: 2.4s
# 695:	learn: 1852.7340507	total: 5.47s	remaining: 2.39s
# 696:	learn: 1852.5675026	total: 5.47s	remaining: 2.38s
# 697:	learn: 1852.3853592	total: 5.48s	remaining: 2.37s
# 698:	learn: 1852.0407800	total: 5.49s	remaining: 2.36s
# 699:	learn: 1851.6835475	total: 5.5s	remaining: 2.35s
# 700:	learn: 1851.3630415	total: 5.5s	remaining: 2.35s
# 701:	learn: 1851.2201607	total: 5.51s	remaining: 2.34s
# 702:	learn: 1851.1698375	total: 5.52s	remaining: 2.33s
# 703:	learn: 1850.9538838	total: 5.53s	remaining: 2.32s
# 704:	learn: 1850.6538868	total: 5.53s	remaining: 2.31s
# 705:	learn: 1850.5138323	total: 5.54s	remaining: 2.31s
# 706:	learn: 1850.3404267	total: 5.55s	remaining: 2.3s
# 707:	learn: 1850.0675265	total: 5.56s	remaining: 2.29s
# 708:	learn: 1849.6963307	total: 5.56s	remaining: 2.28s
# 709:	learn: 1849.3999108	total: 5.57s	remaining: 2.27s
# 710:	learn: 1849.2034301	total: 5.58s	remaining: 2.27s
# 711:	learn: 1849.0634072	total: 5.59s	remaining: 2.26s
# 712:	learn: 1848.9911466	total: 5.59s	remaining: 2.25s
# 713:	learn: 1848.8276311	total: 5.6s	remaining: 2.24s
# 714:	learn: 1848.6736900	total: 5.61s	remaining: 2.23s
# 715:	learn: 1848.3528758	total: 5.62s	remaining: 2.23s
# 716:	learn: 1848.1160931	total: 5.62s	remaining: 2.22s
# 717:	learn: 1848.0649511	total: 5.63s	remaining: 2.21s
# 718:	learn: 1847.9506314	total: 5.64s	remaining: 2.2s
# 719:	learn: 1847.7478095	total: 5.65s	remaining: 2.19s
# 720:	learn: 1847.4230308	total: 5.65s	remaining: 2.19s
# 721:	learn: 1847.1174685	total: 5.66s	remaining: 2.18s
# 722:	learn: 1846.8935956	total: 5.67s	remaining: 2.17s
# 723:	learn: 1846.3855840	total: 5.68s	remaining: 2.16s
# 724:	learn: 1846.2825888	total: 5.68s	remaining: 2.15s
# 725:	learn: 1845.9093945	total: 5.69s	remaining: 2.15s
# 726:	learn: 1845.5018629	total: 5.7s	remaining: 2.14s
# 727:	learn: 1844.9872659	total: 5.71s	remaining: 2.13s
# 728:	learn: 1844.6608084	total: 5.71s	remaining: 2.12s
# 729:	learn: 1844.6137601	total: 5.72s	remaining: 2.12s
# 730:	learn: 1844.3475318	total: 5.73s	remaining: 2.11s
# 731:	learn: 1844.0556688	total: 5.74s	remaining: 2.1s
# 732:	learn: 1843.7472320	total: 5.74s	remaining: 2.09s
# 733:	learn: 1843.0724591	total: 5.75s	remaining: 2.08s
# 734:	learn: 1842.8845427	total: 5.76s	remaining: 2.08s
# 735:	learn: 1842.6062603	total: 5.77s	remaining: 2.07s
# 736:	learn: 1842.4193436	total: 5.77s	remaining: 2.06s
# 737:	learn: 1841.9805203	total: 5.78s	remaining: 2.05s
# 738:	learn: 1841.6165927	total: 5.79s	remaining: 2.04s
# 739:	learn: 1841.3934932	total: 5.8s	remaining: 2.04s
# 740:	learn: 1841.1394587	total: 5.8s	remaining: 2.03s
# 741:	learn: 1841.0930760	total: 5.81s	remaining: 2.02s
# 742:	learn: 1840.8773132	total: 5.82s	remaining: 2.01s
# 743:	learn: 1840.4129445	total: 5.83s	remaining: 2s
# 744:	learn: 1840.0737285	total: 5.83s	remaining: 2s
# 745:	learn: 1839.9999529	total: 5.84s	remaining: 1.99s
# 746:	learn: 1839.7300387	total: 5.85s	remaining: 1.98s
# 747:	learn: 1839.4435111	total: 5.86s	remaining: 1.97s
# 748:	learn: 1839.2506193	total: 5.87s	remaining: 1.97s
# 749:	learn: 1838.8440794	total: 5.87s	remaining: 1.96s
# 750:	learn: 1838.4399754	total: 5.88s	remaining: 1.95s
# 751:	learn: 1838.0491920	total: 5.89s	remaining: 1.94s
# 752:	learn: 1837.6615578	total: 5.89s	remaining: 1.93s
# 753:	learn: 1837.4088739	total: 5.9s	remaining: 1.93s
# 754:	learn: 1837.1845503	total: 5.91s	remaining: 1.92s
# 755:	learn: 1836.7058994	total: 5.92s	remaining: 1.91s
# 756:	learn: 1836.5314189	total: 5.93s	remaining: 1.9s
# 757:	learn: 1836.3069272	total: 5.93s	remaining: 1.89s
# 758:	learn: 1835.7608516	total: 5.94s	remaining: 1.89s
# 759:	learn: 1835.4816962	total: 5.95s	remaining: 1.88s
# 760:	learn: 1835.3551184	total: 5.96s	remaining: 1.87s
# 761:	learn: 1835.0809086	total: 5.96s	remaining: 1.86s
# 762:	learn: 1834.7532084	total: 5.97s	remaining: 1.85s
# 763:	learn: 1834.5254503	total: 5.98s	remaining: 1.85s
# 764:	learn: 1834.0286083	total: 5.99s	remaining: 1.84s
# 765:	learn: 1833.7076632	total: 6s	remaining: 1.83s
# 766:	learn: 1833.1598224	total: 6.01s	remaining: 1.83s
# 767:	learn: 1832.9926259	total: 6.02s	remaining: 1.82s
# 768:	learn: 1832.6634556	total: 6.03s	remaining: 1.81s
# 769:	learn: 1832.5246470	total: 6.04s	remaining: 1.8s
# 770:	learn: 1831.9998521	total: 6.04s	remaining: 1.79s
# 771:	learn: 1831.7167539	total: 6.05s	remaining: 1.79s
# 772:	learn: 1831.3871090	total: 6.06s	remaining: 1.78s
# 773:	learn: 1831.1971866	total: 6.07s	remaining: 1.77s
# 774:	learn: 1831.0027535	total: 6.08s	remaining: 1.76s
# 775:	learn: 1830.6730784	total: 6.08s	remaining: 1.76s
# 776:	learn: 1830.5550108	total: 6.09s	remaining: 1.75s
# 777:	learn: 1830.4356483	total: 6.1s	remaining: 1.74s
# 778:	learn: 1830.3171717	total: 6.11s	remaining: 1.73s
# 779:	learn: 1830.1185352	total: 6.11s	remaining: 1.72s
# 780:	learn: 1829.7714440	total: 6.12s	remaining: 1.72s
# 781:	learn: 1829.3829442	total: 6.13s	remaining: 1.71s
# 782:	learn: 1829.1789124	total: 6.14s	remaining: 1.7s
# 783:	learn: 1828.6629848	total: 6.14s	remaining: 1.69s
# 784:	learn: 1828.6136924	total: 6.15s	remaining: 1.68s
# 785:	learn: 1828.5052176	total: 6.16s	remaining: 1.68s
# 786:	learn: 1828.0684846	total: 6.17s	remaining: 1.67s
# 787:	learn: 1827.8192411	total: 6.18s	remaining: 1.66s
# 788:	learn: 1827.6489129	total: 6.18s	remaining: 1.65s
# 789:	learn: 1827.4532347	total: 6.19s	remaining: 1.65s
# 790:	learn: 1827.3368297	total: 6.2s	remaining: 1.64s
# 791:	learn: 1827.1795924	total: 6.21s	remaining: 1.63s
# 792:	learn: 1826.8843565	total: 6.22s	remaining: 1.62s
# 793:	learn: 1826.5957380	total: 6.22s	remaining: 1.61s
# 794:	learn: 1826.4417765	total: 6.23s	remaining: 1.61s
# 795:	learn: 1825.8594481	total: 6.24s	remaining: 1.6s
# 796:	learn: 1825.6729899	total: 6.25s	remaining: 1.59s
# 797:	learn: 1825.0537469	total: 6.26s	remaining: 1.58s
# 798:	learn: 1824.8742279	total: 6.27s	remaining: 1.58s
# 799:	learn: 1824.5306689	total: 6.27s	remaining: 1.57s
# 800:	learn: 1824.3578814	total: 6.28s	remaining: 1.56s
# 801:	learn: 1823.9422616	total: 6.29s	remaining: 1.55s
# 802:	learn: 1823.8446135	total: 6.3s	remaining: 1.54s
# 803:	learn: 1823.7954934	total: 6.31s	remaining: 1.54s
# 804:	learn: 1823.3155888	total: 6.32s	remaining: 1.53s
# 805:	learn: 1823.1409706	total: 6.32s	remaining: 1.52s
# 806:	learn: 1823.0018914	total: 6.33s	remaining: 1.51s
# 807:	learn: 1822.9038619	total: 6.34s	remaining: 1.51s
# 808:	learn: 1822.7214913	total: 6.35s	remaining: 1.5s
# 809:	learn: 1822.5715782	total: 6.35s	remaining: 1.49s
# 810:	learn: 1822.4900346	total: 6.36s	remaining: 1.48s
# 811:	learn: 1822.2633824	total: 6.37s	remaining: 1.48s
# 812:	learn: 1822.1669435	total: 6.38s	remaining: 1.47s
# 813:	learn: 1821.9299687	total: 6.39s	remaining: 1.46s
# 814:	learn: 1821.8004786	total: 6.39s	remaining: 1.45s
# 815:	learn: 1821.5714958	total: 6.4s	remaining: 1.44s
# 816:	learn: 1821.4172429	total: 6.41s	remaining: 1.44s
# 817:	learn: 1821.0856005	total: 6.42s	remaining: 1.43s
# 818:	learn: 1820.9479375	total: 6.43s	remaining: 1.42s
# 819:	learn: 1820.7817063	total: 6.43s	remaining: 1.41s
# 820:	learn: 1820.5863877	total: 6.44s	remaining: 1.4s
# 821:	learn: 1820.4308941	total: 6.45s	remaining: 1.4s
# 822:	learn: 1820.3105471	total: 6.46s	remaining: 1.39s
# 823:	learn: 1820.0838588	total: 6.47s	remaining: 1.38s
# 824:	learn: 1819.9273009	total: 6.47s	remaining: 1.37s
# 825:	learn: 1819.8259805	total: 6.48s	remaining: 1.36s
# 826:	learn: 1819.6573359	total: 6.49s	remaining: 1.36s
# 827:	learn: 1819.3720804	total: 6.5s	remaining: 1.35s
# 828:	learn: 1818.9608431	total: 6.51s	remaining: 1.34s
# 829:	learn: 1818.8468803	total: 6.51s	remaining: 1.33s
# 830:	learn: 1818.7292872	total: 6.52s	remaining: 1.33s
# 831:	learn: 1818.6032246	total: 6.53s	remaining: 1.32s
# 832:	learn: 1818.3078107	total: 6.54s	remaining: 1.31s
# 833:	learn: 1818.0627261	total: 6.55s	remaining: 1.3s
# 834:	learn: 1817.7256181	total: 6.55s	remaining: 1.29s
# 835:	learn: 1817.6810896	total: 6.56s	remaining: 1.29s
# 836:	learn: 1817.2634452	total: 6.57s	remaining: 1.28s
# 837:	learn: 1816.9825124	total: 6.58s	remaining: 1.27s
# 838:	learn: 1816.6723783	total: 6.59s	remaining: 1.26s
# 839:	learn: 1816.6253197	total: 6.6s	remaining: 1.26s
# 840:	learn: 1816.4990059	total: 6.61s	remaining: 1.25s
# 841:	learn: 1816.2132170	total: 6.62s	remaining: 1.24s
# 842:	learn: 1816.0334017	total: 6.63s	remaining: 1.23s
# 843:	learn: 1815.7828026	total: 6.63s	remaining: 1.23s
# 844:	learn: 1815.6808290	total: 6.65s	remaining: 1.22s
# 845:	learn: 1815.5200595	total: 6.65s	remaining: 1.21s
# 846:	learn: 1815.3802478	total: 6.66s	remaining: 1.2s
# 847:	learn: 1814.9461971	total: 6.67s	remaining: 1.2s
# 848:	learn: 1814.7354952	total: 6.68s	remaining: 1.19s
# 849:	learn: 1814.6946617	total: 6.69s	remaining: 1.18s
# 850:	learn: 1814.3515201	total: 6.69s	remaining: 1.17s
# 851:	learn: 1814.3094206	total: 6.7s	remaining: 1.16s
# 852:	learn: 1814.2620048	total: 6.71s	remaining: 1.16s
# 853:	learn: 1814.1235391	total: 6.72s	remaining: 1.15s
# 854:	learn: 1814.0134130	total: 6.73s	remaining: 1.14s
# 855:	learn: 1813.9298991	total: 6.73s	remaining: 1.13s
# 856:	learn: 1813.7882594	total: 6.74s	remaining: 1.12s
# 857:	learn: 1813.5780667	total: 6.75s	remaining: 1.12s
# 858:	learn: 1813.5354758	total: 6.76s	remaining: 1.11s
# 859:	learn: 1813.1622602	total: 6.77s	remaining: 1.1s
# 860:	learn: 1813.0234337	total: 6.77s	remaining: 1.09s
# 861:	learn: 1812.9440621	total: 6.78s	remaining: 1.08s
# 862:	learn: 1812.9015464	total: 6.79s	remaining: 1.08s
# 863:	learn: 1812.7694901	total: 6.8s	remaining: 1.07s
# 864:	learn: 1812.4699089	total: 6.81s	remaining: 1.06s
# 865:	learn: 1812.3572380	total: 6.82s	remaining: 1.05s
# 866:	learn: 1812.2341636	total: 6.82s	remaining: 1.05s
# 867:	learn: 1812.1085838	total: 6.83s	remaining: 1.04s
# 868:	learn: 1812.0022504	total: 6.84s	remaining: 1.03s
# 869:	learn: 1811.9304657	total: 6.85s	remaining: 1.02s
# 870:	learn: 1811.8549692	total: 6.86s	remaining: 1.01s
# 871:	learn: 1811.3142242	total: 6.86s	remaining: 1.01s
# 872:	learn: 1811.1876705	total: 6.87s	remaining: 1000ms
# 873:	learn: 1811.0126612	total: 6.88s	remaining: 992ms
# 874:	learn: 1810.9413233	total: 6.89s	remaining: 984ms
# 875:	learn: 1810.5449186	total: 6.89s	remaining: 976ms
# 876:	learn: 1810.3865197	total: 6.9s	remaining: 968ms
# ...
# 709:	learn: 0.5494908	total: 7.13s	remaining: 2.91s
# 710:	learn: 0.5494841	total: 7.14s	remaining: 2.9s
# 711:	learn: 0.5493964	total: 7.16s	remaining: 2.9s
# 712:	learn: 0.5493343	total: 7.17s	remaining: 2.89s
# 713:	learn: 0.5492714	total: 7.18s	remaining: 2.88s
# 714:	learn: 0.5492618	total: 7.19s	remaining: 2.87s
# 715:	learn: 0.5491837	total: 7.2s	remaining: 2.86s
# 716:	learn: 0.5491362	total: 7.21s	remaining: 2.85s
# 717:	learn: 0.5490121	total: 7.22s	remaining: 2.84s
# 718:	learn: 0.5490075	total: 7.23s	remaining: 2.83s
# 719:	learn: 0.5489614	total: 7.24s	remaining: 2.82s
# 720:	learn: 0.5489233	total: 7.25s	remaining: 2.81s
# 721:	learn: 0.5489187	total: 7.26s	remaining: 2.8s
# 722:	learn: 0.5488708	total: 7.27s	remaining: 2.79s
# 723:	learn: 0.5488587	total: 7.28s	remaining: 2.78s
# 724:	learn: 0.5487506	total: 7.29s	remaining: 2.77s
# 725:	learn: 0.5487111	total: 7.3s	remaining: 2.76s
# 726:	learn: 0.5486615	total: 7.32s	remaining: 2.75s
# 727:	learn: 0.5486496	total: 7.32s	remaining: 2.74s
# 728:	learn: 0.5486022	total: 7.33s	remaining: 2.73s
# 729:	learn: 0.5484987	total: 7.34s	remaining: 2.72s
# 730:	learn: 0.5484093	total: 7.36s	remaining: 2.71s
# 731:	learn: 0.5483383	total: 7.37s	remaining: 2.7s
# 732:	learn: 0.5483170	total: 7.38s	remaining: 2.69s
# 733:	learn: 0.5482528	total: 7.38s	remaining: 2.68s
# 734:	learn: 0.5481861	total: 7.39s	remaining: 2.67s
# 735:	learn: 0.5481419	total: 7.4s	remaining: 2.65s
# 736:	learn: 0.5480438	total: 7.41s	remaining: 2.65s
# 737:	learn: 0.5479749	total: 7.42s	remaining: 2.63s
# 738:	learn: 0.5479675	total: 7.43s	remaining: 2.63s
# 739:	learn: 0.5479187	total: 7.44s	remaining: 2.62s
# 740:	learn: 0.5478586	total: 7.45s	remaining: 2.6s
# 741:	learn: 0.5478195	total: 7.46s	remaining: 2.6s
# 742:	learn: 0.5477736	total: 7.47s	remaining: 2.58s
# 743:	learn: 0.5477478	total: 7.48s	remaining: 2.57s
# 744:	learn: 0.5476997	total: 7.49s	remaining: 2.56s
# 745:	learn: 0.5476558	total: 7.5s	remaining: 2.55s
# 746:	learn: 0.5476088	total: 7.51s	remaining: 2.54s
# 747:	learn: 0.5475532	total: 7.52s	remaining: 2.53s
# 748:	learn: 0.5474984	total: 7.53s	remaining: 2.52s
# 749:	learn: 0.5474432	total: 7.54s	remaining: 2.51s
# 750:	learn: 0.5473940	total: 7.55s	remaining: 2.5s
# 751:	learn: 0.5473381	total: 7.56s	remaining: 2.49s
# 752:	learn: 0.5472954	total: 7.57s	remaining: 2.48s
# 753:	learn: 0.5472677	total: 7.58s	remaining: 2.47s
# 754:	learn: 0.5472441	total: 7.59s	remaining: 2.46s
# 755:	learn: 0.5471845	total: 7.6s	remaining: 2.45s
# 756:	learn: 0.5471467	total: 7.61s	remaining: 2.44s
# 757:	learn: 0.5471241	total: 7.62s	remaining: 2.43s
# 758:	learn: 0.5470948	total: 7.63s	remaining: 2.42s
# 759:	learn: 0.5470113	total: 7.64s	remaining: 2.41s
# 760:	learn: 0.5469237	total: 7.65s	remaining: 2.4s
# 761:	learn: 0.5468382	total: 7.66s	remaining: 2.39s
# 762:	learn: 0.5468281	total: 7.67s	remaining: 2.38s
# 763:	learn: 0.5467009	total: 7.68s	remaining: 2.37s
# 764:	learn: 0.5466583	total: 7.69s	remaining: 2.36s
# 765:	learn: 0.5466179	total: 7.7s	remaining: 2.35s
# 766:	learn: 0.5465805	total: 7.71s	remaining: 2.34s
# 767:	learn: 0.5465143	total: 7.72s	remaining: 2.33s
# 768:	learn: 0.5464467	total: 7.73s	remaining: 2.32s
# 769:	learn: 0.5463705	total: 7.74s	remaining: 2.31s
# 770:	learn: 0.5463175	total: 7.75s	remaining: 2.3s
# 771:	learn: 0.5462157	total: 7.76s	remaining: 2.29s
# 772:	learn: 0.5461411	total: 7.77s	remaining: 2.28s
# 773:	learn: 0.5460916	total: 7.78s	remaining: 2.27s
# 774:	learn: 0.5460524	total: 7.79s	remaining: 2.26s
# 775:	learn: 0.5459818	total: 7.79s	remaining: 2.25s
# 776:	learn: 0.5459183	total: 7.8s	remaining: 2.24s
# 777:	learn: 0.5458424	total: 7.82s	remaining: 2.23s
# 778:	learn: 0.5457962	total: 7.83s	remaining: 2.22s
# 779:	learn: 0.5457654	total: 7.83s	remaining: 2.21s
# 780:	learn: 0.5456640	total: 7.84s	remaining: 2.2s
# 781:	learn: 0.5456579	total: 7.85s	remaining: 2.19s
# 782:	learn: 0.5456504	total: 7.86s	remaining: 2.18s
# 783:	learn: 0.5455859	total: 7.87s	remaining: 2.17s
# 784:	learn: 0.5455412	total: 7.88s	remaining: 2.16s
# 785:	learn: 0.5454028	total: 7.89s	remaining: 2.15s
# 786:	learn: 0.5453327	total: 7.9s	remaining: 2.14s
# 787:	learn: 0.5453076	total: 7.91s	remaining: 2.13s
# 788:	learn: 0.5452442	total: 7.92s	remaining: 2.12s
# 789:	learn: 0.5452048	total: 7.93s	remaining: 2.11s
# 790:	learn: 0.5451258	total: 7.94s	remaining: 2.1s
# 791:	learn: 0.5450244	total: 7.95s	remaining: 2.09s
# 792:	learn: 0.5449854	total: 7.96s	remaining: 2.08s
# 793:	learn: 0.5449649	total: 7.97s	remaining: 2.07s
# 794:	learn: 0.5449621	total: 7.98s	remaining: 2.06s
# 795:	learn: 0.5449603	total: 7.99s	remaining: 2.05s
# 796:	learn: 0.5449529	total: 8s	remaining: 2.04s
# 797:	learn: 0.5448727	total: 8.01s	remaining: 2.03s
# 798:	learn: 0.5448661	total: 8.02s	remaining: 2.02s
# 799:	learn: 0.5448110	total: 8.03s	remaining: 2.01s
# 800:	learn: 0.5447755	total: 8.04s	remaining: 2s
# 801:	learn: 0.5447261	total: 8.05s	remaining: 1.99s
# 802:	learn: 0.5446312	total: 8.06s	remaining: 1.98s
# 803:	learn: 0.5445314	total: 8.07s	remaining: 1.97s
# 804:	learn: 0.5445272	total: 8.08s	remaining: 1.96s
# 805:	learn: 0.5444560	total: 8.09s	remaining: 1.95s
# 806:	learn: 0.5443970	total: 8.1s	remaining: 1.94s
# 807:	learn: 0.5443397	total: 8.11s	remaining: 1.93s
# 808:	learn: 0.5442612	total: 8.12s	remaining: 1.92s
# 809:	learn: 0.5441907	total: 8.13s	remaining: 1.91s
# 810:	learn: 0.5441588	total: 8.14s	remaining: 1.9s
# 811:	learn: 0.5441154	total: 8.15s	remaining: 1.89s
# 812:	learn: 0.5441066	total: 8.16s	remaining: 1.88s
# 813:	learn: 0.5440267	total: 8.17s	remaining: 1.87s
# 814:	learn: 0.5439291	total: 8.18s	remaining: 1.86s
# 815:	learn: 0.5439019	total: 8.19s	remaining: 1.85s
# 816:	learn: 0.5438323	total: 8.2s	remaining: 1.84s
# 817:	learn: 0.5437824	total: 8.21s	remaining: 1.83s
# 818:	learn: 0.5437555	total: 8.22s	remaining: 1.82s
# 819:	learn: 0.5437079	total: 8.23s	remaining: 1.81s
# 820:	learn: 0.5435972	total: 8.24s	remaining: 1.79s
# 821:	learn: 0.5435555	total: 8.25s	remaining: 1.78s
# 822:	learn: 0.5434792	total: 8.26s	remaining: 1.77s
# 823:	learn: 0.5434536	total: 8.27s	remaining: 1.76s
# 824:	learn: 0.5434313	total: 8.28s	remaining: 1.75s
# 825:	learn: 0.5433971	total: 8.29s	remaining: 1.75s
# 826:	learn: 0.5433019	total: 8.29s	remaining: 1.74s
# 827:	learn: 0.5432999	total: 8.3s	remaining: 1.72s
# 828:	learn: 0.5431982	total: 8.31s	remaining: 1.71s
# 829:	learn: 0.5431091	total: 8.32s	remaining: 1.7s
# 830:	learn: 0.5431051	total: 8.33s	remaining: 1.69s
# 831:	learn: 0.5430196	total: 8.34s	remaining: 1.68s
# 832:	learn: 0.5430165	total: 8.35s	remaining: 1.67s
# 833:	learn: 0.5429717	total: 8.36s	remaining: 1.66s
# 834:	learn: 0.5429587	total: 8.37s	remaining: 1.65s
# 835:	learn: 0.5429194	total: 8.38s	remaining: 1.64s
# 836:	learn: 0.5428612	total: 8.39s	remaining: 1.63s
# 837:	learn: 0.5428550	total: 8.4s	remaining: 1.62s
# 838:	learn: 0.5427863	total: 8.41s	remaining: 1.61s
# 839:	learn: 0.5427843	total: 8.42s	remaining: 1.6s
# 840:	learn: 0.5427159	total: 8.43s	remaining: 1.59s
# 841:	learn: 0.5426591	total: 8.44s	remaining: 1.58s
# 842:	learn: 0.5426515	total: 8.45s	remaining: 1.57s
# 843:	learn: 0.5425821	total: 8.46s	remaining: 1.56s
# 844:	learn: 0.5425555	total: 8.47s	remaining: 1.55s
# 845:	learn: 0.5425176	total: 8.48s	remaining: 1.54s
# 846:	learn: 0.5424740	total: 8.49s	remaining: 1.53s
# 847:	learn: 0.5424176	total: 8.5s	remaining: 1.52s
# 848:	learn: 0.5424116	total: 8.51s	remaining: 1.51s
# 849:	learn: 0.5423575	total: 8.52s	remaining: 1.5s
# 850:	learn: 0.5423519	total: 8.53s	remaining: 1.49s
# 851:	learn: 0.5423485	total: 8.54s	remaining: 1.48s
# 852:	learn: 0.5422900	total: 8.55s	remaining: 1.47s
# 853:	learn: 0.5422571	total: 8.56s	remaining: 1.46s
# 854:	learn: 0.5421980	total: 8.56s	remaining: 1.45s
# 855:	learn: 0.5421117	total: 8.58s	remaining: 1.44s
# 856:	learn: 0.5420388	total: 8.59s	remaining: 1.43s
# 857:	learn: 0.5419660	total: 8.6s	remaining: 1.42s
# 858:	learn: 0.5419411	total: 8.61s	remaining: 1.41s
# 859:	learn: 0.5418438	total: 8.62s	remaining: 1.4s
# 860:	learn: 0.5418185	total: 8.63s	remaining: 1.39s
# 861:	learn: 0.5417263	total: 8.63s	remaining: 1.38s
# 862:	learn: 0.5416314	total: 8.64s	remaining: 1.37s
# 863:	learn: 0.5416287	total: 8.65s	remaining: 1.36s
# 864:	learn: 0.5415928	total: 8.66s	remaining: 1.35s
# 865:	learn: 0.5415546	total: 8.67s	remaining: 1.34s
# 866:	learn: 0.5415378	total: 8.68s	remaining: 1.33s
# 867:	learn: 0.5415324	total: 8.69s	remaining: 1.32s
# 868:	learn: 0.5414705	total: 8.7s	remaining: 1.31s
# 869:	learn: 0.5414402	total: 8.71s	remaining: 1.3s
# 870:	learn: 0.5413276	total: 8.72s	remaining: 1.29s
# 871:	learn: 0.5412678	total: 8.73s	remaining: 1.28s
# 872:	learn: 0.5411871	total: 8.74s	remaining: 1.27s
# 873:	learn: 0.5411259	total: 8.75s	remaining: 1.26s
# 874:	learn: 0.5410518	total: 8.76s	remaining: 1.25s
# 875:	learn: 0.5409989	total: 8.77s	remaining: 1.24s
# 876:	learn: 0.5409484	total: 8.78s	remaining: 1.23s
# 877:	learn: 0.5408990	total: 8.79s	remaining: 1.22s
# 878:	learn: 0.5408964	total: 8.8s	remaining: 1.21s
# 879:	learn: 0.5408413	total: 8.81s	remaining: 1.2s
# 880:	learn: 0.5408000	total: 8.82s	remaining: 1.19s
# 881:	learn: 0.5406991	total: 8.83s	remaining: 1.18s
# 882:	learn: 0.5406047	total: 8.84s	remaining: 1.17s
# 883:	learn: 0.5405764	total: 8.85s	remaining: 1.16s
# 884:	learn: 0.5405348	total: 8.86s	remaining: 1.15s
# 885:	learn: 0.5404531	total: 8.87s	remaining: 1.14s
# 886:	learn: 0.5403487	total: 8.88s	remaining: 1.13s
# 887:	learn: 0.5402860	total: 8.89s	remaining: 1.12s
# 888:	learn: 0.5402686	total: 8.9s	remaining: 1.11s
# 889:	learn: 0.5402642	total: 8.91s	remaining: 1.1s
# 890:	learn: 0.5402311	total: 8.92s	remaining: 1.09s
# 891:	learn: 0.5401904	total: 8.93s	remaining: 1.08s
# 892:	learn: 0.5401522	total: 8.94s	remaining: 1.07s
# 893:	learn: 0.5401137	total: 8.95s	remaining: 1.06s
# 894:	learn: 0.5400719	total: 8.96s	remaining: 1.05s
# 895:	learn: 0.5399963	total: 8.97s	remaining: 1.04s
# 896:	learn: 0.5398928	total: 8.98s	remaining: 1.03s
# 897:	learn: 0.5398208	total: 8.99s	remaining: 1.02s
# 898:	learn: 0.5397947	total: 9s	remaining: 1.01s
# 899:	learn: 0.5397874	total: 9.01s	remaining: 1s
# 900:	learn: 0.5397827	total: 9.02s	remaining: 991ms
# 901:	learn: 0.5396920	total: 9.03s	remaining: 981ms
# 902:	learn: 0.5396109	total: 9.04s	remaining: 971ms
# 903:	learn: 0.5395596	total: 9.05s	remaining: 961ms
# 904:	learn: 0.5394507	total: 9.06s	remaining: 951ms
# 905:	learn: 0.5393994	total: 9.07s	remaining: 941ms
# 906:	learn: 0.5393238	total: 9.08s	remaining: 931ms
# 907:	learn: 0.5392977	total: 9.09s	remaining: 921ms
# 908:	learn: 0.5392573	total: 9.1s	remaining: 911ms
# 909:	learn: 0.5392459	total: 9.11s	remaining: 901ms
# 910:	learn: 0.5391901	total: 9.12s	remaining: 891ms
# 911:	learn: 0.5391880	total: 9.13s	remaining: 881ms
# 912:	learn: 0.5391328	total: 9.14s	remaining: 871ms
# 913:	learn: 0.5390868	total: 9.15s	remaining: 861ms
# 914:	learn: 0.5390407	total: 9.16s	remaining: 851ms
# 915:	learn: 0.5390248	total: 9.17s	remaining: 841ms
# 916:	learn: 0.5389760	total: 9.18s	remaining: 831ms
# 917:	learn: 0.5389113	total: 9.19s	remaining: 821ms
# 918:	learn: 0.5388654	total: 9.2s	remaining: 811ms
# 919:	learn: 0.5387803	total: 9.21s	remaining: 801ms
# 920:	learn: 0.5387227	total: 9.22s	remaining: 791ms
# 921:	learn: 0.5386436	total: 9.23s	remaining: 781ms
# 922:	learn: 0.5385696	total: 9.24s	remaining: 771ms
# 923:	learn: 0.5384996	total: 9.25s	remaining: 761ms
# 924:	learn: 0.5384201	total: 9.26s	remaining: 751ms
# 925:	learn: 0.5383713	total: 9.27s	remaining: 741ms
# 926:	learn: 0.5383261	total: 9.28s	remaining: 731ms
# 927:	learn: 0.5382588	total: 9.29s	remaining: 721ms
# 928:	learn: 0.5381784	total: 9.3s	remaining: 711ms
# 929:	learn: 0.5381741	total: 9.31s	remaining: 701ms
# 930:	learn: 0.5381460	total: 9.32s	remaining: 690ms
# 931:	learn: 0.5380936	total: 9.33s	remaining: 680ms
# 932:	learn: 0.5380711	total: 9.34s	remaining: 670ms
# 933:	learn: 0.5380302	total: 9.34s	remaining: 660ms
# 934:	learn: 0.5379578	total: 9.35s	remaining: 650ms
# 935:	learn: 0.5379537	total: 9.36s	remaining: 640ms
# 936:	learn: 0.5379122	total: 9.37s	remaining: 630ms
# 937:	learn: 0.5378460	total: 9.38s	remaining: 620ms
# 938:	learn: 0.5378035	total: 9.39s	remaining: 610ms
# 939:	learn: 0.5377570	total: 9.4s	remaining: 600ms
# 940:	learn: 0.5377311	total: 9.41s	remaining: 590ms
# 941:	learn: 0.5376249	total: 9.42s	remaining: 580ms
# 942:	learn: 0.5375650	total: 9.43s	remaining: 570ms
# 943:	learn: 0.5374832	total: 9.45s	remaining: 560ms
# 944:	learn: 0.5374082	total: 9.46s	remaining: 551ms
# 945:	learn: 0.5373962	total: 9.47s	remaining: 541ms
# 946:	learn: 0.5373416	total: 9.48s	remaining: 531ms
# 947:	learn: 0.5372823	total: 9.49s	remaining: 521ms
# 948:	learn: 0.5372511	total: 9.51s	remaining: 511ms
# 949:	learn: 0.5372311	total: 9.51s	remaining: 501ms
# 950:	learn: 0.5372116	total: 9.52s	remaining: 491ms
# 951:	learn: 0.5372086	total: 9.53s	remaining: 481ms
# 952:	learn: 0.5371717	total: 9.54s	remaining: 471ms
# 953:	learn: 0.5371033	total: 9.55s	remaining: 461ms
# 954:	learn: 0.5370368	total: 9.56s	remaining: 451ms
# 955:	learn: 0.5370342	total: 9.57s	remaining: 441ms
# 956:	learn: 0.5369952	total: 9.58s	remaining: 431ms
# 957:	learn: 0.5369794	total: 9.59s	remaining: 421ms
# 958:	learn: 0.5369177	total: 9.6s	remaining: 411ms
# 959:	learn: 0.5368888	total: 9.61s	remaining: 401ms
# 960:	learn: 0.5368488	total: 9.62s	remaining: 391ms
# 961:	learn: 0.5368056	total: 9.63s	remaining: 381ms
# 962:	learn: 0.5367690	total: 9.64s	remaining: 371ms
# 963:	learn: 0.5366806	total: 9.66s	remaining: 361ms
# 964:	learn: 0.5365842	total: 9.67s	remaining: 351ms
# 965:	learn: 0.5364814	total: 9.68s	remaining: 341ms
# 966:	learn: 0.5364557	total: 9.69s	remaining: 331ms
# 967:	learn: 0.5363994	total: 9.7s	remaining: 321ms
# 968:	learn: 0.5363203	total: 9.71s	remaining: 311ms
# 969:	learn: 0.5363154	total: 9.71s	remaining: 300ms
# 970:	learn: 0.5362647	total: 9.72s	remaining: 290ms
# 971:	learn: 0.5362074	total: 9.73s	remaining: 280ms
# 972:	learn: 0.5361469	total: 9.74s	remaining: 270ms
# 973:	learn: 0.5360869	total: 9.75s	remaining: 260ms
# 974:	learn: 0.5360405	total: 9.76s	remaining: 250ms
# 975:	learn: 0.5359909	total: 9.77s	remaining: 240ms
# 976:	learn: 0.5359038	total: 9.78s	remaining: 230ms
# 977:	learn: 0.5358004	total: 9.79s	remaining: 220ms
# 978:	learn: 0.5357722	total: 9.8s	remaining: 210ms
# 979:	learn: 0.5357257	total: 9.81s	remaining: 200ms
# 980:	learn: 0.5356599	total: 9.82s	remaining: 190ms
# 981:	learn: 0.5356260	total: 9.83s	remaining: 180ms
# 982:	learn: 0.5355723	total: 9.84s	remaining: 170ms
# 983:	learn: 0.5355209	total: 9.85s	remaining: 160ms
# 984:	learn: 0.5355033	total: 9.86s	remaining: 150ms
# 985:	learn: 0.5354456	total: 9.87s	remaining: 140ms
# 986:	learn: 0.5353553	total: 9.88s	remaining: 130ms
# 987:	learn: 0.5353514	total: 9.89s	remaining: 120ms
# 988:	learn: 0.5352864	total: 9.9s	remaining: 110ms
# 989:	learn: 0.5352477	total: 9.91s	remaining: 100ms
# 990:	learn: 0.5352305	total: 9.92s	remaining: 90.1ms
# 991:	learn: 0.5351667	total: 9.93s	remaining: 80.1ms
# 992:	learn: 0.5350923	total: 9.94s	remaining: 70.1ms
# 993:	learn: 0.5350894	total: 9.95s	remaining: 60.1ms
# 994:	learn: 0.5350487	total: 9.96s	remaining: 50ms
# 995:	learn: 0.5349540	total: 9.97s	remaining: 40ms
# 996:	learn: 0.5348719	total: 9.98s	remaining: 30ms
# 997:	learn: 0.5348398	total: 9.99s	remaining: 20ms
# 998:	learn: 0.5347622	total: 10s	remaining: 10ms
# 999:	learn: 0.5346895	total: 10s	remaining: 0us
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000927 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2008
# [LightGBM] [Info] Number of data points in the train set: 24050, number of used features: 767
# [LightGBM] [Info] Start training from score 7376.900541
# [LightGBM] [Info] Number of positive: 6640, number of negative: 12884
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1298
# [LightGBM] [Info] Number of data points in the train set: 19524, number of used features: 269
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.340094 -> initscore=-0.662874
# [LightGBM] [Info] Start training from score -0.662874
# LGBMClassifier()

# %%
# Прогнозы на тестовых данных
catboost_regressor_predictions = catboost_regressor.predict(X_test_regression)
catboost_classifier_predictions = catboost_classifier.predict(X_test_classifier)

xgboost_regressor_predictions = xgboost_regressor.predict(X_test_regression)
xgboost_classifier_predictions = xgboost_classifier.predict(X_test_classifier)

lightgbm_regressor_predictions = lightgbm_regressor.predict(X_test_regression)
lightgbm_classifier_predictions = lightgbm_classifier.predict(X_test_classifier)

# %%
# Оценка качества моделей
catboost_regressor_accuracy = mean_squared_error(y_test_regression, catboost_regressor_predictions)
catboost_classifier_accuracy = accuracy_score(y_test_classifier, catboost_classifier_predictions)

xgboost_regressor_accuracy = mean_squared_error(y_test_regression, xgboost_regressor_predictions)
xgboost_classifier_accuracy = accuracy_score(y_test_classifier, xgboost_classifier_predictions)

lightgbm_regressor_accuracy = mean_squared_error(y_test_regression, lightgbm_regressor_predictions)
lightgbm_classifier_accuracy = accuracy_score(y_test_classifier, lightgbm_classifier_predictions)

# Вывод результатов
print('CatBoost Regressor Accuracy:', catboost_regressor_accuracy)
print('CatBoost Classifier Accuracy:', catboost_classifier_accuracy)

print('XGBoost Regressor Accuracy:', xgboost_regressor_accuracy)
print('XGBoost Classifier Accuracy:', xgboost_classifier_accuracy)

print('LightGBM Regressor Accuracy:', lightgbm_regressor_accuracy)
print('LightGBM Classifier Accuracy:', lightgbm_classifier_accuracy)
# Out:
# CatBoost Regressor Accuracy: 3853468.8549499516
# CatBoost Classifier Accuracy: 0.6845555100368701
# XGBoost Regressor Accuracy: 3820747.786069222
# XGBoost Classifier Accuracy: 0.6804588283490373
# LightGBM Regressor Accuracy: 3900646.975654965
# LightGBM Classifier Accuracy: 0.6876280213027448
