# %% [markdown]
# Лабораторная работа №5. "ДРЕВОВИДНЫЕ МОДЕЛИ: РЕШАЮЩИЕ ДЕРЕВЬЯ И ИХ КОМПОЗИЦИИ"
#
# Задание №1.
# A). Реализовать DecisionTreeClassifier и DecisionTreeRegressor из Sclearn для соответствующих наборов данных своего варианта. Осуществить настройку гиперпараметров. Выполнить оценку качества модели, визуализировать дерево решений, вывести решающие правила. Сравнить полученные результаты обучения моделей с данными, полученными с помощью PyCaret (открытая low-code библиотека ML на Python, см. Lab5_Ex3 DRs_classifier.ipynb)
# B). Реализовать обучение и вычисление дерева с использованием алгоритма CART для задачи регрессии и задачи классификации. Выполнить оценку качества моделей, визуализировать дерево решений, вывести решающие правила.
#
# Задание №2. Применить ансамбли для наборов данных своего варианта:
# o BaggingClassifier
# o BaggingRegressor
#
# o GradientBoostingClassifier
# o GradientBoostingRegressor
#
# o StackingClassifier
# o StackingRegressor
#
# Выполнить оценку качества моделей и выбрать лучшую модель.
#
# Задание №3. Реализовать для решения задачи регрессии и задачи классификации следующие библиотеки:
# o Catboost,
# o XGBoost,
# o LightGBM
# Выполнить оценку качества моделей и выбрать лучшую модель.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
import os

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
import matplotlib.pyplot as plt
from sklearn import tree

# %%
os.chdir('../data')
#Вариант 1
df_regression = pd.read_csv('lab3.csv')
df_classifier = pd.read_csv('lab4.csv')

# %%
df_classifier
# Out:
#         flight  dayofweek  time  length  delay  airline_9E  airline_AA  \
# 0         3036          4  1195     131      0       False       False
# 1          315          7   707     145      0       False       False
# 2         6673          5   499      42      1       False       False
# 3         3668          2   810      70      1       False       False
# 4          623          5   985     143      0       False       False
# ...        ...        ...   ...     ...    ...         ...         ...
# 244063    2699          7   910      62      0       False       False
# 244064    3995          2   985      80      0       False       False
# 244065    6474          6   652     138      0       False       False
# 244066     486          7   365     107      0       False       False
# 244067    1037          4   605     150      1       False       False
#
#         airline_AS  airline_B6  airline_CO  ...  airportto_TXK  airportto_TYR  \
# 0            False       False       False  ...          False          False
# 1            False       False       False  ...          False          False
# 2            False       False       False  ...          False          False
# 3            False       False       False  ...          False          False
# 4             True       False       False  ...          False          False
# ...            ...         ...         ...  ...            ...            ...
# 244063       False       False       False  ...          False          False
# 244064       False       False       False  ...          False          False
# 244065       False       False       False  ...          False          False
# 244066       False       False       False  ...          False          False
# 244067       False       False       False  ...          False          False
#
#         airportto_TYS  airportto_UTM  airportto_VLD  airportto_VPS  \
# 0               False          False          False          False
# 1               False          False          False          False
# 2               False          False          False          False
# 3               False          False          False          False
# 4               False          False          False          False
# ...               ...            ...            ...            ...
# 244063          False          False          False          False
# 244064          False          False          False          False
# 244065          False          False          False          False
# 244066          False          False          False          False
# 244067          False          False          False          False
#
#         airportto_WRG  airportto_XNA  airportto_YAK  airportto_YUM
# 0               False          False          False          False
# 1               False          False          False          False
# 2               False          False          False          False
# 3               False          False          False          False
# 4               False          False          False          False
# ...               ...            ...            ...            ...
# 244063          False          False          False          False
# 244064          False          False          False          False
# 244065          False          False          False          False
# 244066          False          False          False          False
# 244067          False          False          False          False
#
# [244068 rows x 609 columns]

# %%
df_regression
# Out:
#        year  distance  engine_capacity(cm3)  price(euro)  make_ARO  \
# 0      2011    195000                  1800         7750     False
# 1      2014    135000                  1500         8550     False
# 2      1998         1                  1400         2200     False
# 3      2012    110000                  1500         6550     False
# 4      2006    200000                  1600         4100     False
# ...     ...       ...                   ...          ...       ...
# 30058  2002    225000                  1800         4400     False
# 30059  2015     89000                  1500         7000     False
# 30060  2009       225                  1500         4500     False
# 30061  2006    370000                  2000         4000     False
# 30062  2006    300000                  1500         4000     False
#
#        make_Abarth  make_Acura  make_Alfa Romeo  make_Alta marca  \
# 0            False       False            False            False
# 1            False       False            False            False
# 2            False       False            False            False
# 3            False       False            False            False
# 4            False       False            False            False
# ...            ...         ...              ...              ...
# 30058        False       False            False            False
# 30059        False       False            False            False
# 30060        False       False            False            False
# 30061        False       False            False            False
# 30062        False       False            False            False
#
#        make_Aston Martin  ...  style_Sedan  style_Universal  fuel_type_Diesel  \
# 0                  False  ...        False            False             False
# 1                  False  ...        False             True              True
# 2                  False  ...        False            False             False
# 3                  False  ...        False             True              True
# 4                  False  ...        False             True             False
# ...                  ...  ...          ...              ...               ...
# 30058              False  ...        False            False             False
# 30059              False  ...        False             True              True
# 30060              False  ...        False            False              True
# 30061              False  ...        False            False              True
# 30062              False  ...        False            False              True
#
#        fuel_type_Electric  fuel_type_Hybrid  fuel_type_Metan/Propan  \
# 0                   False              True                   False
# 1                   False             False                   False
# 2                   False             False                   False
# 3                   False             False                   False
# 4                   False             False                    True
# ...                   ...               ...                     ...
# 30058               False             False                    True
# 30059               False             False                   False
# 30060               False             False                   False
# 30061               False             False                   False
# 30062               False             False                   False
#
#        fuel_type_Petrol  fuel_type_Plug-in Hybrid  transmission_Automatic  \
# 0                 False                     False                    True
# 1                 False                     False                   False
# 2                  True                     False                   False
# 3                 False                     False                   False
# 4                 False                     False                   False
# ...                 ...                       ...                     ...
# 30058             False                     False                   False
# 30059             False                     False                   False
# 30060             False                     False                   False
# 30061             False                     False                   False
# 30062             False                     False                   False
#
#        transmission_Manual
# 0                    False
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ...                    ...
# 30058                 True
# 30059                 True
# 30060                 True
# 30061                 True
# 30062                 True
#
# [30063 rows x 940 columns]

# %%
df_regression = df_regression.rename(columns={"engine_capacity(cm3)": "enginecapacity", "price(euro)": "price"})

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

numeric_features_classifier = ['flight','dayofweek','time','length'] 
df_classifier[numeric_features_classifier] = scaler.fit_transform(df_classifier[numeric_features_classifier])

# %%
y_classifier = df_classifier["delay"]
X_classifier = df_classifier.drop(["delay"], axis=1)

y_regression = df_regression["price"]
X_regression = df_regression.drop(["price"], axis=1)

# %%
X_train_classifier, X_test_classifier, y_train_classifier, y_test_classifier = train_test_split(X_classifier, y_classifier, test_size=0.2)
X_train_regression, X_test_regression, y_train_regression, y_test_regression = train_test_split(X_regression, y_regression, test_size=0.2)

# %% [markdown]
# ## Реализовать DecisionTreeClassifier и DecisionTreeRegressor из Sclearn для соответствующих наборов данных своего варианта. Осуществить настройку гиперпараметров.

# %%
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV
classifier = DecisionTreeClassifier()

param_dist = {
    "criterion": ["gini", "entropy"],
    "max_depth": randint(1, 4),
    "min_samples_split": randint(2, 20),
    "min_samples_leaf": randint(1, 10)
}

clf_random_search = RandomizedSearchCV(classifier, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
clf_random_search.fit(X_train_classifier, y_train_classifier)

best_classifier = clf_random_search.best_estimator_

# %%
regressor = DecisionTreeRegressor()

param_dist = {
    "criterion": ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "max_depth": randint(1, 4),
    "min_samples_split": randint(2, 20),
    "min_samples_leaf": randint(1, 10)
}

reg_random_search = RandomizedSearchCV(regressor, param_distributions=param_dist, n_iter=10, cv=5, random_state=42)
reg_random_search.fit(X_train_regression, y_train_regression)

best_regressor = reg_random_search.best_estimator_

# %% [markdown]
# ## Выполнить оценку качества модели, визуализировать дерево решений

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

def calculate_metrics(model, X, y_true):
    y_pred = model.predict(X)
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return r2, mae, mse, rmse, mape

# %%
metrics_classifier = calculate_metrics(best_classifier, X_test_classifier, y_test_classifier)
metrics_regressor = calculate_metrics(best_regressor, X_test_regression, y_test_regression)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

clf_predictions = best_classifier.predict(X_test_classifier)

print('Accuracy: {:.3f}'.format(accuracy_score(y_test_classifier, clf_predictions)))
print('Precision: {:.3f}'.format(precision_score(y_test_classifier, clf_predictions)))
print('Recall: {:.3f}'.format(recall_score(y_test_classifier, clf_predictions)))
print('F1-score: {:.3f}'.format(f1_score(y_test_classifier, clf_predictions)))
print('ROC-AUC: {:.3f}'.format(roc_auc_score(y_test_classifier, clf_predictions)))
# Out:
# Accuracy: 0.687
# Precision: 0.673
# Recall: 0.171
# F1-score: 0.272
# ROC-AUC: 0.564

# %%
print(f'MAE: {metrics_regressor[1]}')
print(f'MSE: {metrics_regressor[2]}')
print(f'RMSE: {metrics_regressor[3]}')
print(f'MAPE: {metrics_regressor[4]}')
print(f'R^2: {metrics_regressor[0]}')
# Out:
# MAE: 2079.779430131533
# MSE: 7994360.171517295
# RMSE: 2827.429958728827
# MAPE: 48.0528739882657
# R^2: 0.7078835089073536

# %% [markdown]
# ## Визуализировать дерево решений:

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plot_tree(best_classifier, filled=True)
plt.show()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plot_tree(best_regressor, filled=True)
plt.show()

# %% [markdown]
# ## вывести решающие правила

# %%
from sklearn.tree import export_text
tree_rules = export_text(best_classifier, feature_names=list(X_classifier.columns))
print(tree_rules)
# Out:
# |--- airline_WN <= 0.50
# |   |--- dayofweek <= 0.82
# |   |   |--- time <= -0.81
# |   |   |   |--- class: 0
# |   |   |--- time >  -0.81
# |   |   |   |--- class: 0
# |   |--- dayofweek >  0.82
# |   |   |--- time <= -0.48
# |   |   |   |--- class: 0
# |   |   |--- time >  -0.48
# |   |   |   |--- class: 0
# |--- airline_WN >  0.50
# |   |--- time <= -0.42
# |   |   |--- time <= -1.08
# |   |   |   |--- class: 0
# |   |   |--- time >  -1.08
# |   |   |   |--- class: 0
# |   |--- time >  -0.42
# |   |   |--- dayofweek <= 0.82
# |   |   |   |--- class: 1
# |   |   |--- dayofweek >  0.82
# |   |   |   |--- class: 0

# %%
tree_rules = export_text(best_regressor, feature_names=list(X_regression.columns))
print(tree_rules)
# Out:
# |--- year <= 2010.50
# |   |--- year <= 2005.50
# |   |   |--- year <= 2000.50
# |   |   |   |--- value: [2469.43]
# |   |   |--- year >  2000.50
# |   |   |   |--- value: [3755.33]
# |   |--- year >  2005.50
# |   |   |--- enginecapacity <= 1725.50
# |   |   |   |--- value: [4492.33]
# |   |   |--- enginecapacity >  1725.50
# |   |   |   |--- value: [7217.73]
# |--- year >  2010.50
# |   |--- enginecapacity <= 1925.00
# |   |   |--- year <= 2014.50
# |   |   |   |--- value: [7355.19]
# |   |   |--- year >  2014.50
# |   |   |   |--- value: [11659.85]
# |   |--- enginecapacity >  1925.00
# |   |   |--- year <= 2014.50
# |   |   |   |--- value: [13835.38]
# |   |   |--- year >  2014.50
# |   |   |   |--- value: [17408.17]

# %% [markdown]
# ## PyCaret

# %%
#!pip install --pre pycaret

# %%
#from pycaret.regression import *

# %%
#setup(data=df_regression,  target='price(euro)', session_id=555, train_size=0.7, preprocess=True)

# %%
#models()

# %%
#dt_reg = create_model(estimator='dt')

# %%
#tuned_dt_reg = tune_model(dt_reg)

# %% [markdown]
# ## Реализовать обучение и вычисление дерева с использованием алгоритма CART для задачи регрессии и задачи классификации.

# %%
import numpy as np

class CARTRegressor:
    def __init__(self, max_depth=None, min_samples_split=2):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split

    def fit(self, X, y):
        self.root = self._build_tree(X, y, depth=0)
 # метод _build_tree рекурсивно создает узлы дерева до достижения максимальной глубины или min_samples_split
    def _build_tree(self, X, y, depth):
        # Условие остановки рекурсии: достигнута максимальная глубина или число примеров в узле меньше min_samples_split
        if (self.max_depth is not None and depth >= self.max_depth) or len(X) <= self.min_samples_split:
            leaf_value = np.mean(y)
            # Если условие остановки выполнено, создаем лист дерева с агрегированным значением целевого признака
            return {'leaf': True, 'value': leaf_value}
        
        # Находим наилучшие признак и порог для разделения
        best_feature, best_threshold = self._find_best_split(X, y)
        # Создаем индексы для левого и правого поддеревьев 
        left_child_indices = X[:, best_feature] <= best_threshold
        right_child_indices = X[:, best_feature] > best_threshold
        
        # Рекурсивно строим поддеревья для левой и правой ветви
        node = {
            'feature': best_feature,
            'threshold': best_threshold,
            'left': self._build_tree(X[left_child_indices], y[left_child_indices], depth + 1),
            'right': self._build_tree(X[right_child_indices], y[right_child_indices], depth + 1)
        }
        # Возвращаем узел с указанием признака и порога для разделения, а также с поддеревьями
        return node
    
    # Метод _find_best_split ищет лучший разделитель, основываясь на снижении среднеквадратичной ошибки
    def _find_best_split(self, X, y):
        # Начальные значения для наилучшего признака, наилучшего порога и наилучшего mse
        best_mse = float('inf')
        best_feature = None
        best_threshold = None
        
        # Перебор всех возможных признаков и пороговых значений
        for feature in range(X.shape[1]):
            thresholds = np.unique(X[:, feature])
            for threshold in thresholds:
                # Деление на подгруппы по каждому порогу для данного признака
                left_indices = X[:, feature] <= threshold
                right_indices = X[:, feature] > threshold
                
                # Вычисление значения среднеквадратичной ошибки в результате разделения
                mse = self._mse(y[left_indices], y[right_indices])
                # Если новое mse меньше предыдущего наилучшего, 
                # то обновляем наилучший признак и наилучший порог разделения
                if mse < best_mse:
                    best_mse = mse
                    best_feature = feature
                    best_threshold = threshold
        
        return best_feature, best_threshold
    
    # Метод _mse вычисляет среднеквадратичную ошибку между целевым и предсказанным значениями
    def _mse(self, left_y, right_y):
        left_mse = np.mean((left_y - np.mean(left_y))**2)
        right_mse = np.mean((right_y - np.mean(right_y))**2)
        mse = (len(left_y) * left_mse + len(right_y) * right_mse) / (len(left_y) + len(right_y))
        return mse
    
    # Метод predict предсказывает целевые значения для входного массива X
    def predict(self, X):
        # Вызов метода _traverse_tree для каждого элемента массива X
        return np.array([self._traverse_tree(x, self.root) for x in X])
    
    # Метод _traverse_tree обходит дерево, начиная от корня, и возвращает значение в листе для заданного образца
    def _traverse_tree(self, x, node):
        # Если узел является листом, возвращаем его значение
        if 'leaf' in node:
            return node['value']
        # Если значение признака в образце меньше или равно порогу узла, продолжаем движение по левому поддереву
        if x[node['feature']] <= node['threshold']:
            return self._traverse_tree(x, node['left'])
        # Иначе продолжаем движение по правому поддереву
        else:
            return self._traverse_tree(x, node['right']) else:
            return self._traverse_tree(x, node['right'])
# Out:
#   Cell In[45], line 82
#     return self._traverse_tree(x, node['right']) else:
#                                                  ^
# SyntaxError: invalid syntax

# %%
regressor = CARTRegressor(max_depth=5, min_samples_split=10)
regressor.fit(X_train_regression, y_train_regression)

predictions = regressor.predict(X_test_regression)

mse = mean_squared_error(y_test_regression, predictions)
print('Mean squared error:', mse)

# %%
class CARTClassifier:
    def __init__(self, max_depth=None, min_samples_split=2):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split

    def fit(self, X, y):
        self.root = self._build_tree(X, y, depth=0)
        
    # Рекурсивная функция для построения дерева.
    def _build_tree(self, X, y, depth):
        # Условие остановки - если достигли максимальной глубины или количество элементов недостаточно для разделения
        if (self.max_depth is not None and depth >= self.max_depth) or len(X) <= self.min_samples_split:
            class_counts = np.bincount(y)
            class_probability = class_counts / np.sum(class_counts)
            # Если остановились - возвращаем лист с наиболее популярным классом
            return {'leaf': True, 'class': np.argmax(class_counts), 'probability': class_probability}
        
        best_feature, best_threshold = self._find_best_split(X, y)
        # Делим датасет на две части
        left_child_indices = X[:, best_feature] <= best_threshold
        right_child_indices = X[:, best_feature] > best_threshold
        
        node = {
            'feature': best_feature,
            'threshold': best_threshold,
            # Строим детей для текущего узла
            'left': self._build_tree(X[left_child_indices], y[left_child_indices], depth + 1),
            'right': self._build_tree(X[right_child_indices], y[right_child_indices], depth + 1)
        }
        return node

    # Функция для нахождения лучшего разбиения в узле.
    def _find_best_split(self, X, y): 
        best_gini = float('inf')
        best_feature = None
        best_threshold = None
        
        for feature in range(X.shape[1]):
            thresholds = np.unique(X[:, feature])
            for threshold in thresholds:
                left_indices = X[:, feature] <= threshold
                right_indices = X[:, feature] > threshold
                
                left_y = y[left_indices]
                right_y = y[right_indices]
                
                gini = self._gini(left_y, right_y)
                if gini < best_gini:
                    best_gini = gini
                    best_feature = feature
                    best_threshold = threshold
        
        return best_feature, best_threshold

    # Функция для расчета индекса Джини
    def _gini(self, left_y, right_y):
        
        left_gini = 1 - np.sum((np.bincount(left_y) / len(left_y))**2)
        right_gini = 1 - np.sum((np.bincount(right_y) / len(right_y))**2)
        gini = (len(left_y) * left_gini + len(right_y) * right_gini) / (len(left_y) + len(right_y))
        return gini

    # Функция для предсказания класса. :param X: матрица признаков
    def predict(self, X):  
        if isinstance(X, pd.DataFrame):
            X = X.values
        elif isinstance(X, list):
            X = np.array(X)
        if X.ndim == 1:
            X = np.expand_dims(X, 0)
        return np.array([self._traverse_tree(x, self.root) for x in X])

    # Функция для обхода дерева с целью классификации объекта.
    def _traverse_tree(self, x, node):  
        if 'leaf' in node:
            return node['class']
        if x[node['feature']] <= node['threshold']:
            # Перемещаемся по дереву влево (если значение признака меньше или равно порогу)
            return self._traverse_tree(x, node['left'])
        else:
            # Перемещаемся по дереву вправо (если значение признака больше порога)
            return self._traverse_tree(x, node['right'])

# %%
cartClassifier = CARTClassifier(max_depth=10, min_samples_split=5)

cartClassifier.fit(X_train_classifier, y_train_classifier)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 7
#       3 cartClassifier.fit(X_train_classifier, y_train_classifier)
#       5 y_pred = cartClassifier.predict(X_test_classifier)
# ----> 7 accuracy = accuracy_score(y_test_classifier, y_pred_classifier)
#       8 print(f'Model Accuracy: {accuracy}')
#
# NameError: name 'y_pred_classifier' is not defined

# %%
y_pred_classifier = cartClassifier.predict(X_test_classifier)

accuracy = accuracy_score(y_test_classifier, y_pred_classifier)
print(f'Model Accuracy: {accuracy}')
# Out:
# Model Accuracy: 0.6884295488999058

# %% [markdown]
# ## Задание №2. Применить ансамбли для наборов данных своего варианта:

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier, BaggingRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.ensemble import StackingClassifier, StackingRegressor

# %%
# Создание экземпляров моделей
bagging_classifier = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=10)
bagging_regressor = BaggingRegressor(estimator=DecisionTreeRegressor(), n_estimators=10)
gradient_boosting_classifier = GradientBoostingClassifier()
gradient_boosting_regressor = GradientBoostingRegressor()
stacking_classifier = StackingClassifier(
    estimators=[('bagging', bagging_classifier), ('gb', gradient_boosting_classifier)],
    final_estimator=LogisticRegression()
)
stacking_regressor = StackingRegressor(
    estimators=[('bagging', bagging_regressor), ('gb', gradient_boosting_regressor)],
    final_estimator=LinearRegression()
)

# %%
# Обучение моделей
bagging_classifier.fit(X_train_classifier, y_train_classifier)
bagging_regressor.fit(X_train_regression, y_train_regression)

gradient_boosting_classifier.fit(X_train_classifier, y_train_classifier)
gradient_boosting_regressor.fit(X_train_regression, y_train_regression)

stacking_classifier.fit(X_train_classifier, y_train_classifier)
stacking_regressor.fit(X_train_regression, y_train_regression)
# Out:
# StackingRegressor(estimators=[('bagging',
#                                BaggingRegressor(estimator=DecisionTreeRegressor())),
#                               ('gb', GradientBoostingRegressor())],
#                   final_estimator=LinearRegression())

# %%
# Прогнозы на тестовых данных
bagging_classifier_predictions = bagging_classifier.predict(X_test_classifier)
bagging_regressor_predictions = bagging_regressor.predict(X_test_regression)

gradient_boosting_classifier_predictions = gradient_boosting_classifier.predict(X_test_classifier)
gradient_boosting_regressor_predictions = gradient_boosting_regressor.predict(X_test_regression)

stacking_classifier_predictions = stacking_classifier.predict(X_test_classifier)
stacking_regressor_predictions = stacking_regressor.predict(X_test_regression)

# %%
# Оценка качества моделей
bagging_classifier_accuracy = accuracy_score(y_test_classifier, bagging_classifier_predictions)
bagging_regressor_accuracy = mean_squared_error(y_test_regression, bagging_regressor_predictions)
gradient_boosting_classifier_accuracy = accuracy_score(y_test_classifier, gradient_boosting_classifier_predictions)
gradient_boosting_regressor_accuracy = mean_squared_error(y_test_regression, gradient_boosting_regressor_predictions)
stacking_classifier_accuracy = accuracy_score(y_test_classifier, stacking_classifier_predictions)
stacking_regressor_accuracy = mean_squared_error(y_test_regression, stacking_regressor_predictions)

print('Bagging Classifier Accuracy:', bagging_classifier_accuracy)
print('Bagging Regressor Accuracy:', bagging_regressor_accuracy)
print('Gradient Boosting Classifier Accuracy:', gradient_boosting_classifier_accuracy)
print('Gradient Boosting Regressor Accuracy:', gradient_boosting_regressor_accuracy)
print('Stacking Classifier Accuracy:', stacking_classifier_accuracy)
print('Stacking Regressor Accuracy:', stacking_regressor_accuracy)
# Out:
# Bagging Classifier Accuracy: 0.5445364034908018
# Bagging Regressor Accuracy: 4430463.63458087
# Gradient Boosting Classifier Accuracy: 0.6907854304093088
# Gradient Boosting Regressor Accuracy: 4668554.229969439
# Stacking Classifier Accuracy: 0.7084852706190847
# Stacking Regressor Accuracy: 4015237.9506953405

# %% [markdown]
# ## Задание №3. Реализовать для решения задачи регрессии и задачи классификации следующие библиотеки:

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from catboost import CatBoostRegressor, CatBoostClassifier
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier

# %%
# Создание экземпляров моделей 
catboost_regressor = CatBoostRegressor()
catboost_classifier = CatBoostClassifier()

xgboost_regressor = XGBRegressor()
xgboost_classifier = XGBClassifier()

lightgbm_regressor = LGBMRegressor(feature_pre_filter=False)
lightgbm_classifier = LGBMClassifier()

# %%
X_train_regression.columns = X_train_regression.columns.str.replace('\W', '_')
X_train_classifier.columns = X_train_classifier.columns.str.replace('\W', '_')
X_train_regression = X_train_regression.values
y_train_regression = y_train_regression.values
X_train_classifier = X_train_classifier.values
y_train_classifier = y_train_classifier.values
# Обучение моделей 
catboost_regressor.fit(X_train_regression, y_train_regression)
catboost_classifier.fit(X_train_classifier, y_train_classifier)

xgboost_regressor.fit(X_train_regression, y_train_regression)
xgboost_classifier.fit(X_train_classifier, y_train_classifier)

lightgbm_regressor.fit(X_train_regression, y_train_regression)
lightgbm_classifier.fit(X_train_classifier, y_train_classifier)
# Out:
# Learning rate set to 0.06767
# 0:	learn: 4990.7205839	total: 90.9ms	remaining: 1m 30s
# 1:	learn: 4764.1562488	total: 101ms	remaining: 50.3s
# 2:	learn: 4551.2840636	total: 111ms	remaining: 37s
# 3:	learn: 4351.5584055	total: 119ms	remaining: 29.7s
# 4:	learn: 4173.2272973	total: 128ms	remaining: 25.5s
# 5:	learn: 4010.9553016	total: 136ms	remaining: 22.6s
# 6:	learn: 3864.6143935	total: 146ms	remaining: 20.7s
# 7:	learn: 3726.6329332	total: 155ms	remaining: 19.2s
# 8:	learn: 3606.4755459	total: 164ms	remaining: 18s
# 9:	learn: 3491.5007483	total: 175ms	remaining: 17.4s
# 10:	learn: 3388.9414514	total: 184ms	remaining: 16.6s
# 11:	learn: 3295.3157286	total: 195ms	remaining: 16s
# 12:	learn: 3208.7080477	total: 203ms	remaining: 15.4s
# 13:	learn: 3130.7203954	total: 213ms	remaining: 15s
# 14:	learn: 3061.8494241	total: 221ms	remaining: 14.5s
# 15:	learn: 2997.1905620	total: 231ms	remaining: 14.2s
# 16:	learn: 2939.2566089	total: 240ms	remaining: 13.9s
# 17:	learn: 2885.0780686	total: 249ms	remaining: 13.6s
# 18:	learn: 2837.1119029	total: 258ms	remaining: 13.3s
# 19:	learn: 2795.6251302	total: 267ms	remaining: 13.1s
# 20:	learn: 2757.6645331	total: 276ms	remaining: 12.9s
# 21:	learn: 2721.4199721	total: 285ms	remaining: 12.7s
# 22:	learn: 2688.5635706	total: 294ms	remaining: 12.5s
# 23:	learn: 2658.8493322	total: 303ms	remaining: 12.3s
# 24:	learn: 2630.8346632	total: 312ms	remaining: 12.2s
# 25:	learn: 2605.5247449	total: 321ms	remaining: 12s
# 26:	learn: 2582.3412399	total: 330ms	remaining: 11.9s
# 27:	learn: 2561.1295813	total: 339ms	remaining: 11.8s
# 28:	learn: 2542.8986924	total: 347ms	remaining: 11.6s
# 29:	learn: 2525.9906263	total: 357ms	remaining: 11.5s
# 30:	learn: 2510.0819630	total: 366ms	remaining: 11.4s
# 31:	learn: 2495.1948521	total: 374ms	remaining: 11.3s
# 32:	learn: 2480.3383223	total: 383ms	remaining: 11.2s
# 33:	learn: 2465.5439767	total: 392ms	remaining: 11.1s
# 34:	learn: 2452.6610442	total: 400ms	remaining: 11s
# 35:	learn: 2440.2598217	total: 409ms	remaining: 10.9s
# 36:	learn: 2428.9059715	total: 418ms	remaining: 10.9s
# 37:	learn: 2417.9478489	total: 427ms	remaining: 10.8s
# 38:	learn: 2408.9635254	total: 435ms	remaining: 10.7s
# 39:	learn: 2399.3024673	total: 445ms	remaining: 10.7s
# 40:	learn: 2390.1131558	total: 455ms	remaining: 10.6s
# 41:	learn: 2382.7243309	total: 464ms	remaining: 10.6s
# 42:	learn: 2375.0862859	total: 474ms	remaining: 10.5s
# 43:	learn: 2367.4511994	total: 483ms	remaining: 10.5s
# 44:	learn: 2361.7070624	total: 491ms	remaining: 10.4s
# 45:	learn: 2355.4263837	total: 503ms	remaining: 10.4s
# 46:	learn: 2349.7447805	total: 512ms	remaining: 10.4s
# 47:	learn: 2344.1084211	total: 520ms	remaining: 10.3s
# 48:	learn: 2336.3853259	total: 528ms	remaining: 10.3s
# 49:	learn: 2331.2591473	total: 537ms	remaining: 10.2s
# 50:	learn: 2325.3729540	total: 545ms	remaining: 10.1s
# 51:	learn: 2320.3095570	total: 553ms	remaining: 10.1s
# 52:	learn: 2315.4616802	total: 562ms	remaining: 10s
# 53:	learn: 2311.0346364	total: 571ms	remaining: 10s
# 54:	learn: 2305.2250474	total: 580ms	remaining: 9.96s
# 55:	learn: 2300.9935893	total: 588ms	remaining: 9.92s
# 56:	learn: 2297.5828481	total: 597ms	remaining: 9.88s
# 57:	learn: 2292.9528585	total: 605ms	remaining: 9.83s
# 58:	learn: 2289.1363814	total: 613ms	remaining: 9.78s
# 59:	learn: 2285.2892715	total: 622ms	remaining: 9.74s
# 60:	learn: 2281.6754243	total: 630ms	remaining: 9.7s
# 61:	learn: 2278.2818555	total: 638ms	remaining: 9.65s
# 62:	learn: 2274.6676218	total: 646ms	remaining: 9.61s
# 63:	learn: 2271.6740441	total: 655ms	remaining: 9.58s
# 64:	learn: 2268.2826392	total: 664ms	remaining: 9.55s
# 65:	learn: 2264.5133550	total: 673ms	remaining: 9.53s
# 66:	learn: 2261.8637460	total: 682ms	remaining: 9.49s
# 67:	learn: 2258.7679419	total: 690ms	remaining: 9.46s
# 68:	learn: 2256.4014763	total: 699ms	remaining: 9.43s
# 69:	learn: 2253.5166973	total: 708ms	remaining: 9.4s
# 70:	learn: 2249.8724773	total: 717ms	remaining: 9.38s
# 71:	learn: 2247.8583265	total: 725ms	remaining: 9.35s
# 72:	learn: 2245.2352870	total: 734ms	remaining: 9.32s
# 73:	learn: 2242.4342584	total: 743ms	remaining: 9.29s
# 74:	learn: 2240.2198971	total: 751ms	remaining: 9.26s
# 75:	learn: 2238.3068334	total: 760ms	remaining: 9.24s
# 76:	learn: 2235.6833244	total: 769ms	remaining: 9.22s
# 77:	learn: 2233.5512581	total: 778ms	remaining: 9.19s
# 78:	learn: 2231.8202885	total: 787ms	remaining: 9.17s
# 79:	learn: 2230.1883450	total: 795ms	remaining: 9.14s
# 80:	learn: 2227.6118794	total: 803ms	remaining: 9.11s
# 81:	learn: 2225.4647356	total: 812ms	remaining: 9.09s
# 82:	learn: 2223.9094557	total: 821ms	remaining: 9.07s
# 83:	learn: 2222.0029166	total: 829ms	remaining: 9.04s
# 84:	learn: 2220.0203973	total: 837ms	remaining: 9.01s
# 85:	learn: 2218.4055070	total: 845ms	remaining: 8.98s
# 86:	learn: 2215.7340119	total: 854ms	remaining: 8.96s
# 87:	learn: 2213.6136550	total: 863ms	remaining: 8.94s
# 88:	learn: 2211.0818036	total: 871ms	remaining: 8.92s
# 89:	learn: 2209.0375671	total: 880ms	remaining: 8.9s
# 90:	learn: 2207.7994823	total: 889ms	remaining: 8.88s
# 91:	learn: 2206.0720067	total: 898ms	remaining: 8.86s
# 92:	learn: 2203.7122726	total: 906ms	remaining: 8.84s
# 93:	learn: 2202.3774772	total: 915ms	remaining: 8.82s
# 94:	learn: 2200.2950948	total: 924ms	remaining: 8.8s
# 95:	learn: 2198.8743061	total: 933ms	remaining: 8.79s
# 96:	learn: 2196.5892228	total: 942ms	remaining: 8.77s
# 97:	learn: 2194.8894339	total: 950ms	remaining: 8.75s
# 98:	learn: 2192.8130703	total: 959ms	remaining: 8.73s
# 99:	learn: 2191.3472876	total: 968ms	remaining: 8.71s
# 100:	learn: 2189.8463966	total: 977ms	remaining: 8.69s
# 101:	learn: 2188.3925448	total: 985ms	remaining: 8.67s
# 102:	learn: 2187.3398461	total: 994ms	remaining: 8.66s
# 103:	learn: 2187.1701765	total: 1s	remaining: 8.63s
# 104:	learn: 2185.8639225	total: 1.01s	remaining: 8.61s
# 105:	learn: 2184.1105134	total: 1.02s	remaining: 8.6s
# 106:	learn: 2182.4463530	total: 1.03s	remaining: 8.58s
# 107:	learn: 2181.3378424	total: 1.04s	remaining: 8.57s
# 108:	learn: 2180.0532141	total: 1.05s	remaining: 8.55s
# 109:	learn: 2178.5686238	total: 1.05s	remaining: 8.54s
# 110:	learn: 2177.4792057	total: 1.06s	remaining: 8.52s
# 111:	learn: 2175.9657871	total: 1.07s	remaining: 8.51s
# 112:	learn: 2174.9180748	total: 1.08s	remaining: 8.49s
# 113:	learn: 2172.5678253	total: 1.09s	remaining: 8.48s
# 114:	learn: 2170.8089412	total: 1.1s	remaining: 8.47s
# 115:	learn: 2169.1644892	total: 1.11s	remaining: 8.45s
# 116:	learn: 2167.5470997	total: 1.12s	remaining: 8.44s
# 117:	learn: 2166.4391027	total: 1.13s	remaining: 8.43s
# 118:	learn: 2165.7192517	total: 1.14s	remaining: 8.41s
# 119:	learn: 2164.2902637	total: 1.15s	remaining: 8.4s
# 120:	learn: 2163.3535761	total: 1.15s	remaining: 8.38s
# 121:	learn: 2162.2504664	total: 1.16s	remaining: 8.37s
# 122:	learn: 2161.3953081	total: 1.17s	remaining: 8.35s
# 123:	learn: 2160.0646868	total: 1.18s	remaining: 8.33s
# 124:	learn: 2158.8669862	total: 1.19s	remaining: 8.32s
# 125:	learn: 2158.0784659	total: 1.2s	remaining: 8.3s
# 126:	learn: 2156.9363784	total: 1.21s	remaining: 8.29s
# 127:	learn: 2155.9062704	total: 1.21s	remaining: 8.27s
# 128:	learn: 2154.8059886	total: 1.22s	remaining: 8.25s
# 129:	learn: 2153.3940430	total: 1.23s	remaining: 8.24s
# 130:	learn: 2152.4091236	total: 1.24s	remaining: 8.22s
# 131:	learn: 2151.5065830	total: 1.25s	remaining: 8.21s
# 132:	learn: 2149.5790400	total: 1.26s	remaining: 8.19s
# 133:	learn: 2149.3025824	total: 1.26s	remaining: 8.18s
# 134:	learn: 2149.0688797	total: 1.27s	remaining: 8.16s
# 135:	learn: 2147.9387887	total: 1.28s	remaining: 8.14s
# 136:	learn: 2146.9977525	total: 1.29s	remaining: 8.12s
# 137:	learn: 2146.7509482	total: 1.3s	remaining: 8.1s
# 138:	learn: 2146.5340868	total: 1.3s	remaining: 8.09s
# 139:	learn: 2145.4494665	total: 1.31s	remaining: 8.07s
# 140:	learn: 2145.2585281	total: 1.32s	remaining: 8.06s
# 141:	learn: 2144.4779050	total: 1.33s	remaining: 8.04s
# 142:	learn: 2143.0859022	total: 1.34s	remaining: 8.03s
# 143:	learn: 2142.8313119	total: 1.35s	remaining: 8.02s
# 144:	learn: 2141.4853846	total: 1.36s	remaining: 8s
# 145:	learn: 2139.5536252	total: 1.36s	remaining: 7.99s
# 146:	learn: 2138.6036446	total: 1.37s	remaining: 7.98s
# 147:	learn: 2136.3632859	total: 1.38s	remaining: 7.96s
# 148:	learn: 2135.1674200	total: 1.39s	remaining: 7.95s
# 149:	learn: 2134.1269897	total: 1.4s	remaining: 7.94s
# 150:	learn: 2133.9200363	total: 1.41s	remaining: 7.92s
# 151:	learn: 2132.9779625	total: 1.42s	remaining: 7.91s
# 152:	learn: 2131.9969714	total: 1.43s	remaining: 7.9s
# 153:	learn: 2130.0262296	total: 1.44s	remaining: 7.88s
# 154:	learn: 2128.7377947	total: 1.44s	remaining: 7.87s
# 155:	learn: 2128.4662331	total: 1.45s	remaining: 7.86s
# 156:	learn: 2127.5713536	total: 1.46s	remaining: 7.84s
# 157:	learn: 2127.3138481	total: 1.47s	remaining: 7.83s
# 158:	learn: 2126.2937105	total: 1.48s	remaining: 7.82s
# 159:	learn: 2124.8355025	total: 1.49s	remaining: 7.81s
# 160:	learn: 2124.6641067	total: 1.5s	remaining: 7.8s
# 161:	learn: 2123.3948894	total: 1.5s	remaining: 7.78s
# 162:	learn: 2122.5054386	total: 1.51s	remaining: 7.78s
# 163:	learn: 2121.7471030	total: 1.52s	remaining: 7.76s
# 164:	learn: 2120.3064062	total: 1.53s	remaining: 7.75s
# 165:	learn: 2119.0939953	total: 1.54s	remaining: 7.73s
# 166:	learn: 2117.5406085	total: 1.55s	remaining: 7.72s
# 167:	learn: 2117.0884588	total: 1.56s	remaining: 7.71s
# 168:	learn: 2116.9154905	total: 1.56s	remaining: 7.7s
# 169:	learn: 2116.6759605	total: 1.57s	remaining: 7.68s
# 170:	learn: 2115.3687394	total: 1.58s	remaining: 7.67s
# 171:	learn: 2115.0879800	total: 1.59s	remaining: 7.67s
# 172:	learn: 2112.8869731	total: 1.6s	remaining: 7.65s
# 173:	learn: 2111.8286800	total: 1.61s	remaining: 7.64s
# 174:	learn: 2111.5742089	total: 1.62s	remaining: 7.63s
# 175:	learn: 2110.7762726	total: 1.63s	remaining: 7.62s
# 176:	learn: 2109.1187641	total: 1.64s	remaining: 7.61s
# 177:	learn: 2107.8270799	total: 1.64s	remaining: 7.59s
# 178:	learn: 2107.6507863	total: 1.65s	remaining: 7.58s
# 179:	learn: 2106.3767559	total: 1.66s	remaining: 7.57s
# 180:	learn: 2104.8505978	total: 1.67s	remaining: 7.55s
# 181:	learn: 2102.9036574	total: 1.68s	remaining: 7.55s
# 182:	learn: 2102.7284211	total: 1.69s	remaining: 7.54s
# 183:	learn: 2101.6378700	total: 1.7s	remaining: 7.53s
# 184:	learn: 2100.9685951	total: 1.71s	remaining: 7.52s
# 185:	learn: 2100.8073699	total: 1.71s	remaining: 7.5s
# 186:	learn: 2099.3839652	total: 1.72s	remaining: 7.49s
# 187:	learn: 2098.2874924	total: 1.73s	remaining: 7.48s
# 188:	learn: 2097.6373633	total: 1.74s	remaining: 7.47s
# 189:	learn: 2097.4696061	total: 1.75s	remaining: 7.46s
# 190:	learn: 2097.1895801	total: 1.76s	remaining: 7.45s
# 191:	learn: 2096.0963868	total: 1.77s	remaining: 7.43s
# 192:	learn: 2095.4216810	total: 1.77s	remaining: 7.42s
# 193:	learn: 2094.3730196	total: 1.78s	remaining: 7.41s
# 194:	learn: 2093.0613140	total: 1.79s	remaining: 7.4s
# 195:	learn: 2091.7095748	total: 1.8s	remaining: 7.39s
# 196:	learn: 2090.6536608	total: 1.81s	remaining: 7.38s
# 197:	learn: 2090.4931930	total: 1.82s	remaining: 7.36s
# 198:	learn: 2088.6979429	total: 1.83s	remaining: 7.35s
# 199:	learn: 2087.7375598	total: 1.84s	remaining: 7.34s
# 200:	learn: 2087.5805208	total: 1.84s	remaining: 7.33s
# 201:	learn: 2086.9987863	total: 1.85s	remaining: 7.33s
# 202:	learn: 2085.8407004	total: 1.86s	remaining: 7.32s
# 203:	learn: 2084.5917128	total: 1.87s	remaining: 7.31s
# 204:	learn: 2084.4482183	total: 1.88s	remaining: 7.3s
# 205:	learn: 2083.8340274	total: 1.89s	remaining: 7.28s
# 206:	learn: 2083.2858856	total: 1.9s	remaining: 7.27s
# 207:	learn: 2081.8963035	total: 1.91s	remaining: 7.27s
# 208:	learn: 2081.4330471	total: 1.92s	remaining: 7.26s
# 209:	learn: 2081.2837378	total: 1.93s	remaining: 7.25s
# 210:	learn: 2081.1391211	total: 1.94s	remaining: 7.24s
# 211:	learn: 2080.0074894	total: 1.95s	remaining: 7.24s
# 212:	learn: 2079.3707261	total: 1.96s	remaining: 7.22s
# 213:	learn: 2077.8746097	total: 1.96s	remaining: 7.22s
# 214:	learn: 2076.5579018	total: 1.97s	remaining: 7.2s
# 215:	learn: 2075.4647770	total: 1.98s	remaining: 7.19s
# 216:	learn: 2074.1702239	total: 1.99s	remaining: 7.18s
# 217:	learn: 2073.3505719	total: 2s	remaining: 7.18s
# 218:	learn: 2072.3401111	total: 2.01s	remaining: 7.17s
# 219:	learn: 2071.4360528	total: 2.02s	remaining: 7.16s
# 220:	learn: 2071.0618235	total: 2.03s	remaining: 7.15s
# 221:	learn: 2070.5357326	total: 2.04s	remaining: 7.14s
# 222:	learn: 2069.4610385	total: 2.05s	remaining: 7.13s
# 223:	learn: 2069.3286731	total: 2.06s	remaining: 7.12s
# 224:	learn: 2067.5938371	total: 2.07s	remaining: 7.12s
# 225:	learn: 2066.3122558	total: 2.08s	remaining: 7.11s
# 226:	learn: 2064.7434689	total: 2.08s	remaining: 7.09s
# 227:	learn: 2063.8699778	total: 2.09s	remaining: 7.08s
# 228:	learn: 2063.2474317	total: 2.1s	remaining: 7.07s
# 229:	learn: 2062.6939558	total: 2.11s	remaining: 7.06s
# 230:	learn: 2061.9457658	total: 2.12s	remaining: 7.04s
# 231:	learn: 2061.8079245	total: 2.13s	remaining: 7.03s
# 232:	learn: 2060.8307787	total: 2.13s	remaining: 7.02s
# 233:	learn: 2060.3443017	total: 2.14s	remaining: 7.01s
# 234:	learn: 2059.6495016	total: 2.15s	remaining: 7s
# 235:	learn: 2059.2522209	total: 2.16s	remaining: 6.99s
# 236:	learn: 2058.1140514	total: 2.17s	remaining: 6.98s
# 237:	learn: 2057.0995911	total: 2.17s	remaining: 6.97s
# 238:	learn: 2056.5866364	total: 2.19s	remaining: 6.96s
# 239:	learn: 2056.4532276	total: 2.19s	remaining: 6.95s
# 240:	learn: 2055.4409827	total: 2.2s	remaining: 6.94s
# 241:	learn: 2054.3356633	total: 2.21s	remaining: 6.93s
# 242:	learn: 2053.3386925	total: 2.22s	remaining: 6.92s
# 243:	learn: 2052.2514471	total: 2.23s	remaining: 6.91s
# 244:	learn: 2051.7641642	total: 2.24s	remaining: 6.9s
# 245:	learn: 2051.1347534	total: 2.25s	remaining: 6.88s
# 246:	learn: 2051.0054774	total: 2.25s	remaining: 6.87s
# 247:	learn: 2050.6585000	total: 2.26s	remaining: 6.86s
# 248:	learn: 2049.5451129	total: 2.27s	remaining: 6.85s
# 249:	learn: 2048.7252021	total: 2.28s	remaining: 6.84s
# 250:	learn: 2047.7361477	total: 2.29s	remaining: 6.83s
# 251:	learn: 2046.7545651	total: 2.3s	remaining: 6.82s
# 252:	learn: 2045.9951883	total: 2.31s	remaining: 6.81s
# 253:	learn: 2045.8689520	total: 2.31s	remaining: 6.8s
# 254:	learn: 2045.0867784	total: 2.32s	remaining: 6.79s
# 255:	learn: 2044.3436593	total: 2.33s	remaining: 6.77s
# 256:	learn: 2043.1797328	total: 2.34s	remaining: 6.76s
# 257:	learn: 2042.3801500	total: 2.35s	remaining: 6.75s
# 258:	learn: 2041.9291803	total: 2.35s	remaining: 6.74s
# 259:	learn: 2040.8039354	total: 2.36s	remaining: 6.73s
# 260:	learn: 2040.6013441	total: 2.37s	remaining: 6.72s
# 261:	learn: 2040.2140730	total: 2.38s	remaining: 6.71s
# 262:	learn: 2039.5165747	total: 2.39s	remaining: 6.7s
# 263:	learn: 2038.5995388	total: 2.4s	remaining: 6.69s
# 264:	learn: 2038.0012129	total: 2.41s	remaining: 6.67s
# 265:	learn: 2037.0920814	total: 2.42s	remaining: 6.67s
# 266:	learn: 2036.1334391	total: 2.42s	remaining: 6.65s
# 267:	learn: 2035.2457534	total: 2.43s	remaining: 6.64s
# 268:	learn: 2035.1280237	total: 2.44s	remaining: 6.63s
# 269:	learn: 2034.4699898	total: 2.45s	remaining: 6.62s
# 270:	learn: 2034.0480481	total: 2.46s	remaining: 6.61s
# 271:	learn: 2032.8771672	total: 2.46s	remaining: 6.6s
# 272:	learn: 2032.7591255	total: 2.47s	remaining: 6.58s
# 273:	learn: 2032.1622136	total: 2.48s	remaining: 6.57s
# 274:	learn: 2031.4054607	total: 2.49s	remaining: 6.56s
# 275:	learn: 2030.5700987	total: 2.5s	remaining: 6.55s
# 276:	learn: 2030.0128938	total: 2.5s	remaining: 6.54s
# 277:	learn: 2029.1290094	total: 2.52s	remaining: 6.53s
# 278:	learn: 2028.5618410	total: 2.52s	remaining: 6.52s
# 279:	learn: 2028.2524832	total: 2.53s	remaining: 6.51s
# 280:	learn: 2027.9276484	total: 2.54s	remaining: 6.5s
# 281:	learn: 2027.2979506	total: 2.55s	remaining: 6.49s
# 282:	learn: 2026.3623213	total: 2.56s	remaining: 6.48s
# 283:	learn: 2025.9245597	total: 2.57s	remaining: 6.47s
# 284:	learn: 2025.1307355	total: 2.58s	remaining: 6.46s
# 285:	learn: 2025.0160928	total: 2.58s	remaining: 6.46s
# 286:	learn: 2024.5794949	total: 2.59s	remaining: 6.44s
# 287:	learn: 2024.4437564	total: 2.6s	remaining: 6.43s
# 288:	learn: 2024.0596868	total: 2.61s	remaining: 6.42s
# 289:	learn: 2023.3890451	total: 2.62s	remaining: 6.41s
# 290:	learn: 2022.8151255	total: 2.63s	remaining: 6.4s
# 291:	learn: 2021.8706469	total: 2.64s	remaining: 6.39s
# 292:	learn: 2021.6226447	total: 2.64s	remaining: 6.38s
# 293:	learn: 2020.7972619	total: 2.65s	remaining: 6.37s
# 294:	learn: 2020.4005025	total: 2.66s	remaining: 6.36s
# 295:	learn: 2019.3579748	total: 2.67s	remaining: 6.35s
# 296:	learn: 2018.3930148	total: 2.68s	remaining: 6.34s
# 297:	learn: 2017.6400359	total: 2.69s	remaining: 6.33s
# 298:	learn: 2016.9420791	total: 2.7s	remaining: 6.32s
# 299:	learn: 2016.4126590	total: 2.7s	remaining: 6.31s
# 300:	learn: 2015.6458719	total: 2.71s	remaining: 6.3s
# 301:	learn: 2015.5362174	total: 2.72s	remaining: 6.29s
# 302:	learn: 2015.0417290	total: 2.73s	remaining: 6.28s
# 303:	learn: 2013.7743964	total: 2.74s	remaining: 6.27s
# 304:	learn: 2012.9770369	total: 2.75s	remaining: 6.26s
# 305:	learn: 2012.3744248	total: 2.76s	remaining: 6.26s
# 306:	learn: 2011.8400207	total: 2.77s	remaining: 6.25s
# 307:	learn: 2011.4141357	total: 2.78s	remaining: 6.24s
# 308:	learn: 2010.8485268	total: 2.79s	remaining: 6.23s
# 309:	learn: 2010.5632549	total: 2.79s	remaining: 6.22s
# 310:	learn: 2010.1810810	total: 2.8s	remaining: 6.21s
# 311:	learn: 2009.2358982	total: 2.81s	remaining: 6.2s
# 312:	learn: 2008.8655666	total: 2.82s	remaining: 6.19s
# 313:	learn: 2007.2597633	total: 2.83s	remaining: 6.18s
# 314:	learn: 2006.4776674	total: 2.84s	remaining: 6.17s
# 315:	learn: 2005.9135052	total: 2.85s	remaining: 6.16s
# 316:	learn: 2005.8074630	total: 2.85s	remaining: 6.15s
# 317:	learn: 2005.6480543	total: 2.86s	remaining: 6.14s
# 318:	learn: 2005.2988955	total: 2.87s	remaining: 6.13s
# 319:	learn: 2004.7029480	total: 2.88s	remaining: 6.12s
# 320:	learn: 2004.3024512	total: 2.89s	remaining: 6.11s
# 321:	learn: 2003.9545735	total: 2.9s	remaining: 6.1s
# 322:	learn: 2003.0467416	total: 2.9s	remaining: 6.09s
# 323:	learn: 2002.4970624	total: 2.91s	remaining: 6.08s
# 324:	learn: 2001.4959806	total: 2.92s	remaining: 6.06s
# 325:	learn: 2000.9835613	total: 2.93s	remaining: 6.05s
# 326:	learn: 2000.7633276	total: 2.94s	remaining: 6.05s
# 327:	learn: 2000.0748978	total: 2.95s	remaining: 6.04s
# 328:	learn: 1999.8298459	total: 2.96s	remaining: 6.03s
# 329:	learn: 1999.2955295	total: 2.97s	remaining: 6.03s
# 330:	learn: 1998.5422303	total: 2.98s	remaining: 6.01s
# 331:	learn: 1998.2107822	total: 2.98s	remaining: 6s
# 332:	learn: 1997.2850985	total: 2.99s	remaining: 6s
# 333:	learn: 1996.5326304	total: 3s	remaining: 5.99s
# 334:	learn: 1995.9889768	total: 3.01s	remaining: 5.98s
# 335:	learn: 1995.8103728	total: 3.02s	remaining: 5.96s
# 336:	learn: 1995.3113448	total: 3.03s	remaining: 5.96s
# 337:	learn: 1995.0737881	total: 3.04s	remaining: 5.94s
# 338:	learn: 1994.8426186	total: 3.04s	remaining: 5.93s
# 339:	learn: 1994.2970796	total: 3.05s	remaining: 5.92s
# 340:	learn: 1993.5997065	total: 3.06s	remaining: 5.91s
# 341:	learn: 1992.4622549	total: 3.07s	remaining: 5.9s
# 342:	learn: 1992.1233053	total: 3.08s	remaining: 5.89s
# 343:	learn: 1991.5775809	total: 3.08s	remaining: 5.88s
# 344:	learn: 1991.4145964	total: 3.09s	remaining: 5.87s
# 345:	learn: 1991.1351077	total: 3.1s	remaining: 5.86s
# 346:	learn: 1990.8707944	total: 3.11s	remaining: 5.85s
# 347:	learn: 1990.5082285	total: 3.12s	remaining: 5.84s
# 348:	learn: 1990.3053080	total: 3.13s	remaining: 5.83s
# 349:	learn: 1989.5134577	total: 3.13s	remaining: 5.82s
# 350:	learn: 1989.1805198	total: 3.14s	remaining: 5.81s
# 351:	learn: 1988.3461551	total: 3.15s	remaining: 5.8s
# 352:	learn: 1987.6254843	total: 3.16s	remaining: 5.79s
# 353:	learn: 1987.3546205	total: 3.17s	remaining: 5.79s
# 354:	learn: 1986.2636346	total: 3.18s	remaining: 5.78s
# 355:	learn: 1985.3998068	total: 3.19s	remaining: 5.77s
# 356:	learn: 1985.0541265	total: 3.2s	remaining: 5.76s
# 357:	learn: 1984.7911449	total: 3.21s	remaining: 5.75s
# 358:	learn: 1984.0158163	total: 3.22s	remaining: 5.74s
# 359:	learn: 1983.5298659	total: 3.22s	remaining: 5.73s
# 360:	learn: 1982.7713339	total: 3.23s	remaining: 5.72s
# 361:	learn: 1982.3962259	total: 3.24s	remaining: 5.71s
# 362:	learn: 1982.0884355	total: 3.25s	remaining: 5.7s
# 363:	learn: 1981.6558051	total: 3.26s	remaining: 5.69s
# 364:	learn: 1981.4007423	total: 3.27s	remaining: 5.69s
# 365:	learn: 1980.4155433	total: 3.28s	remaining: 5.68s
# 366:	learn: 1979.6038968	total: 3.29s	remaining: 5.67s
# 367:	learn: 1978.9174322	total: 3.3s	remaining: 5.66s
# 368:	learn: 1978.6168296	total: 3.31s	remaining: 5.65s
# 369:	learn: 1977.4408940	total: 3.31s	remaining: 5.64s
# 370:	learn: 1977.1493857	total: 3.32s	remaining: 5.64s
# 371:	learn: 1977.0185253	total: 3.33s	remaining: 5.63s
# 372:	learn: 1976.9206909	total: 3.34s	remaining: 5.62s
# 373:	learn: 1976.6054835	total: 3.35s	remaining: 5.61s
# 374:	learn: 1976.0943928	total: 3.36s	remaining: 5.6s
# 375:	learn: 1975.5277830	total: 3.37s	remaining: 5.59s
# 376:	learn: 1975.0302431	total: 3.38s	remaining: 5.58s
# 377:	learn: 1974.3150188	total: 3.39s	remaining: 5.57s
# 378:	learn: 1973.8026406	total: 3.4s	remaining: 5.57s
# 379:	learn: 1973.4747563	total: 3.4s	remaining: 5.55s
# 380:	learn: 1972.9649467	total: 3.41s	remaining: 5.54s
# 381:	learn: 1972.7051489	total: 3.42s	remaining: 5.54s
# 382:	learn: 1971.9317514	total: 3.43s	remaining: 5.53s
# 383:	learn: 1971.3342382	total: 3.44s	remaining: 5.52s
# 384:	learn: 1970.7608806	total: 3.45s	remaining: 5.51s
# 385:	learn: 1970.2542730	total: 3.46s	remaining: 5.5s
# 386:	learn: 1969.3947146	total: 3.47s	remaining: 5.49s
# 387:	learn: 1968.3839193	total: 3.47s	remaining: 5.48s
# 388:	learn: 1967.6822053	total: 3.48s	remaining: 5.47s
# 389:	learn: 1967.5870718	total: 3.49s	remaining: 5.46s
# 390:	learn: 1966.9769075	total: 3.5s	remaining: 5.46s
# 391:	learn: 1966.7432648	total: 3.51s	remaining: 5.45s
# 392:	learn: 1966.3658053	total: 3.52s	remaining: 5.44s
# 393:	learn: 1965.7854673	total: 3.53s	remaining: 5.43s
# 394:	learn: 1965.2172216	total: 3.54s	remaining: 5.42s
# 395:	learn: 1964.4336008	total: 3.54s	remaining: 5.41s
# 396:	learn: 1963.9862090	total: 3.55s	remaining: 5.4s
# 397:	learn: 1963.7257119	total: 3.56s	remaining: 5.39s
# 398:	learn: 1963.4708331	total: 3.57s	remaining: 5.38s
# 399:	learn: 1962.5651438	total: 3.58s	remaining: 5.37s
# 400:	learn: 1962.1923099	total: 3.59s	remaining: 5.36s
# 401:	learn: 1961.9354230	total: 3.6s	remaining: 5.36s
# 402:	learn: 1961.3662668	total: 3.61s	remaining: 5.35s
# 403:	learn: 1960.9451962	total: 3.62s	remaining: 5.34s
# 404:	learn: 1960.6030065	total: 3.63s	remaining: 5.33s
# 405:	learn: 1960.1686014	total: 3.64s	remaining: 5.32s
# 406:	learn: 1959.9528586	total: 3.65s	remaining: 5.32s
# 407:	learn: 1959.4476240	total: 3.66s	remaining: 5.31s
# 408:	learn: 1959.3548710	total: 3.67s	remaining: 5.3s
# 409:	learn: 1959.1834110	total: 3.68s	remaining: 5.29s
# 410:	learn: 1958.6833366	total: 3.68s	remaining: 5.28s
# 411:	learn: 1958.3383729	total: 3.69s	remaining: 5.27s
# 412:	learn: 1957.5740565	total: 3.7s	remaining: 5.26s
# 413:	learn: 1957.2556177	total: 3.71s	remaining: 5.25s
# 414:	learn: 1956.2301666	total: 3.72s	remaining: 5.24s
# 415:	learn: 1956.1395559	total: 3.73s	remaining: 5.23s
# 416:	learn: 1955.8341770	total: 3.73s	remaining: 5.22s
# 417:	learn: 1955.5798355	total: 3.74s	remaining: 5.21s
# 418:	learn: 1955.1772135	total: 3.75s	remaining: 5.2s
# 419:	learn: 1954.9754685	total: 3.76s	remaining: 5.19s
# 420:	learn: 1954.5286383	total: 3.77s	remaining: 5.18s
# 421:	learn: 1953.7631283	total: 3.78s	remaining: 5.17s
# 422:	learn: 1953.3146312	total: 3.79s	remaining: 5.17s
# 423:	learn: 1952.4876688	total: 3.8s	remaining: 5.16s
# 424:	learn: 1952.3173188	total: 3.81s	remaining: 5.15s
# 425:	learn: 1951.9678455	total: 3.82s	remaining: 5.14s
# 426:	learn: 1951.3564956	total: 3.82s	remaining: 5.13s
# 427:	learn: 1951.0308537	total: 3.83s	remaining: 5.12s
# 428:	learn: 1950.4731116	total: 3.84s	remaining: 5.11s
# 429:	learn: 1950.3228958	total: 3.85s	remaining: 5.1s
# 430:	learn: 1950.2343067	total: 3.86s	remaining: 5.09s
# 431:	learn: 1950.0393358	total: 3.87s	remaining: 5.08s
# 432:	learn: 1949.7532911	total: 3.88s	remaining: 5.08s
# 433:	learn: 1949.2209115	total: 3.88s	remaining: 5.07s
# 434:	learn: 1948.8830049	total: 3.89s	remaining: 5.06s
# 435:	learn: 1948.6450451	total: 3.9s	remaining: 5.05s
# 436:	learn: 1948.1844838	total: 3.91s	remaining: 5.04s
# 437:	learn: 1947.4030326	total: 3.92s	remaining: 5.03s
# 438:	learn: 1947.0272668	total: 3.93s	remaining: 5.02s
# 439:	learn: 1946.5515959	total: 3.94s	remaining: 5.01s
# 440:	learn: 1946.3703575	total: 3.94s	remaining: 5s
# 441:	learn: 1946.1312549	total: 3.95s	remaining: 4.99s
# 442:	learn: 1946.0451434	total: 3.96s	remaining: 4.98s
# 443:	learn: 1945.4375204	total: 3.97s	remaining: 4.97s
# 444:	learn: 1944.9018537	total: 3.98s	remaining: 4.96s
# 445:	learn: 1944.4998260	total: 3.98s	remaining: 4.95s
# 446:	learn: 1944.2585466	total: 3.99s	remaining: 4.94s
# 447:	learn: 1943.6813370	total: 4s	remaining: 4.93s
# 448:	learn: 1943.4712254	total: 4.01s	remaining: 4.92s
# 449:	learn: 1942.9168471	total: 4.02s	remaining: 4.91s
# 450:	learn: 1942.6638391	total: 4.03s	remaining: 4.9s
# 451:	learn: 1942.2634535	total: 4.03s	remaining: 4.89s
# 452:	learn: 1941.7845293	total: 4.04s	remaining: 4.88s
# 453:	learn: 1941.1816458	total: 4.05s	remaining: 4.87s
# 454:	learn: 1941.0971983	total: 4.06s	remaining: 4.86s
# 455:	learn: 1940.0315476	total: 4.07s	remaining: 4.86s
# 456:	learn: 1939.1807416	total: 4.08s	remaining: 4.85s
# 457:	learn: 1938.6784202	total: 4.09s	remaining: 4.84s
# 458:	learn: 1938.1009629	total: 4.1s	remaining: 4.83s
# 459:	learn: 1937.6036326	total: 4.11s	remaining: 4.82s
# 460:	learn: 1937.1671104	total: 4.11s	remaining: 4.81s
# 461:	learn: 1936.6103253	total: 4.12s	remaining: 4.8s
# 462:	learn: 1936.4500969	total: 4.13s	remaining: 4.79s
# 463:	learn: 1935.8719567	total: 4.14s	remaining: 4.78s
# 464:	learn: 1935.6920239	total: 4.15s	remaining: 4.77s
# 465:	learn: 1935.1721687	total: 4.16s	remaining: 4.76s
# 466:	learn: 1934.6839223	total: 4.17s	remaining: 4.75s
# 467:	learn: 1934.5478352	total: 4.17s	remaining: 4.74s
# 468:	learn: 1934.3009633	total: 4.18s	remaining: 4.73s
# 469:	learn: 1933.4644690	total: 4.19s	remaining: 4.72s
# 470:	learn: 1932.7777027	total: 4.2s	remaining: 4.72s
# 471:	learn: 1932.1953653	total: 4.21s	remaining: 4.71s
# 472:	learn: 1932.1125162	total: 4.22s	remaining: 4.7s
# 473:	learn: 1931.6829426	total: 4.22s	remaining: 4.69s
# 474:	learn: 1930.6818875	total: 4.23s	remaining: 4.68s
# 475:	learn: 1930.2563352	total: 4.24s	remaining: 4.67s
# 476:	learn: 1929.8518965	total: 4.25s	remaining: 4.66s
# 477:	learn: 1929.3829102	total: 4.26s	remaining: 4.65s
# 478:	learn: 1928.9282005	total: 4.27s	remaining: 4.64s
# 479:	learn: 1928.6577052	total: 4.28s	remaining: 4.63s
# 480:	learn: 1928.4931853	total: 4.28s	remaining: 4.62s
# 481:	learn: 1928.3337933	total: 4.29s	remaining: 4.61s
# 482:	learn: 1927.7481493	total: 4.3s	remaining: 4.6s
# 483:	learn: 1927.1691798	total: 4.31s	remaining: 4.59s
# 484:	learn: 1926.9917000	total: 4.32s	remaining: 4.58s
# 485:	learn: 1926.5446341	total: 4.32s	remaining: 4.57s
# 486:	learn: 1925.9175548	total: 4.33s	remaining: 4.57s
# 487:	learn: 1925.6345276	total: 4.34s	remaining: 4.56s
# 488:	learn: 1925.4002024	total: 4.35s	remaining: 4.55s
# 489:	learn: 1924.9534577	total: 4.36s	remaining: 4.54s
# 490:	learn: 1924.4498230	total: 4.37s	remaining: 4.53s
# 491:	learn: 1924.2741340	total: 4.38s	remaining: 4.52s
# 492:	learn: 1923.8801285	total: 4.39s	remaining: 4.51s
# 493:	learn: 1923.5673692	total: 4.39s	remaining: 4.5s
# 494:	learn: 1923.0989108	total: 4.4s	remaining: 4.49s
# 495:	learn: 1922.9467865	total: 4.41s	remaining: 4.48s
# 496:	learn: 1922.4361186	total: 4.42s	remaining: 4.47s
# 497:	learn: 1922.1124291	total: 4.43s	remaining: 4.46s
# 498:	learn: 1921.1851488	total: 4.44s	remaining: 4.46s
# 499:	learn: 1921.0067294	total: 4.45s	remaining: 4.45s
# 500:	learn: 1920.8410316	total: 4.46s	remaining: 4.44s
# 501:	learn: 1920.7652280	total: 4.47s	remaining: 4.43s
# 502:	learn: 1920.6220522	total: 4.47s	remaining: 4.42s
# 503:	learn: 1920.4833854	total: 4.48s	remaining: 4.41s
# 504:	learn: 1919.8451532	total: 4.49s	remaining: 4.4s
# 505:	learn: 1919.6297579	total: 4.5s	remaining: 4.39s
# 506:	learn: 1919.2045944	total: 4.51s	remaining: 4.38s
# 507:	learn: 1918.8447565	total: 4.52s	remaining: 4.38s
# 508:	learn: 1918.6891122	total: 4.53s	remaining: 4.37s
# 509:	learn: 1917.7493097	total: 4.54s	remaining: 4.36s
# 510:	learn: 1917.6212187	total: 4.55s	remaining: 4.35s
# 511:	learn: 1917.4967815	total: 4.56s	remaining: 4.34s
# 512:	learn: 1917.2063685	total: 4.57s	remaining: 4.33s
# 513:	learn: 1917.0853564	total: 4.57s	remaining: 4.33s
# 514:	learn: 1916.9637355	total: 4.58s	remaining: 4.32s
# 515:	learn: 1916.4278908	total: 4.59s	remaining: 4.31s
# 516:	learn: 1916.0466245	total: 4.6s	remaining: 4.3s
# 517:	learn: 1915.8433293	total: 4.61s	remaining: 4.29s
# 518:	learn: 1915.7255219	total: 4.62s	remaining: 4.28s
# 519:	learn: 1915.5578728	total: 4.62s	remaining: 4.27s
# 520:	learn: 1915.3915964	total: 4.63s	remaining: 4.26s
# 521:	learn: 1915.0783962	total: 4.64s	remaining: 4.25s
# 522:	learn: 1914.3991513	total: 4.65s	remaining: 4.24s
# 523:	learn: 1914.1870499	total: 4.66s	remaining: 4.23s
# 524:	learn: 1913.8676703	total: 4.67s	remaining: 4.22s
# 525:	learn: 1913.7984340	total: 4.68s	remaining: 4.21s
# 526:	learn: 1913.5554410	total: 4.68s	remaining: 4.21s
# 527:	learn: 1913.2147270	total: 4.69s	remaining: 4.2s
# 528:	learn: 1912.8714417	total: 4.7s	remaining: 4.19s
# 529:	learn: 1912.7469826	total: 4.71s	remaining: 4.18s
# 530:	learn: 1912.2065073	total: 4.72s	remaining: 4.17s
# 531:	learn: 1912.0078583	total: 4.73s	remaining: 4.16s
# 532:	learn: 1911.4721668	total: 4.74s	remaining: 4.15s
# 533:	learn: 1910.9381392	total: 4.75s	remaining: 4.14s
# 534:	learn: 1910.6485946	total: 4.75s	remaining: 4.13s
# 535:	learn: 1910.3120222	total: 4.76s	remaining: 4.12s
# 536:	learn: 1909.8512731	total: 4.77s	remaining: 4.12s
# 537:	learn: 1908.9732327	total: 4.78s	remaining: 4.11s
# 538:	learn: 1908.5243943	total: 4.79s	remaining: 4.1s
# 539:	learn: 1908.0275571	total: 4.8s	remaining: 4.09s
# 540:	learn: 1907.8669176	total: 4.81s	remaining: 4.08s
# 541:	learn: 1907.5940814	total: 4.82s	remaining: 4.07s
# 542:	learn: 1907.3686587	total: 4.82s	remaining: 4.06s
# 543:	learn: 1907.1598703	total: 4.83s	remaining: 4.05s
# 544:	learn: 1906.9495232	total: 4.84s	remaining: 4.04s
# 545:	learn: 1906.6582025	total: 4.85s	remaining: 4.03s
# 546:	learn: 1906.0559705	total: 4.86s	remaining: 4.02s
# 547:	learn: 1905.4736059	total: 4.87s	remaining: 4.02s
# 548:	learn: 1904.5890393	total: 4.88s	remaining: 4.01s
# 549:	learn: 1904.3048737	total: 4.89s	remaining: 4s
# 550:	learn: 1903.7457253	total: 4.9s	remaining: 3.99s
# 551:	learn: 1903.1423406	total: 4.91s	remaining: 3.98s
# 552:	learn: 1902.4675612	total: 4.92s	remaining: 3.97s
# 553:	learn: 1901.9681541	total: 4.92s	remaining: 3.96s
# 554:	learn: 1901.5359351	total: 4.93s	remaining: 3.96s
# 555:	learn: 1901.1092672	total: 4.94s	remaining: 3.95s
# 556:	learn: 1900.7104713	total: 4.95s	remaining: 3.94s
# 557:	learn: 1900.1908133	total: 4.96s	remaining: 3.93s
# 558:	learn: 1899.6891455	total: 4.97s	remaining: 3.92s
# 559:	learn: 1899.2420749	total: 4.98s	remaining: 3.91s
# 560:	learn: 1899.0411227	total: 4.99s	remaining: 3.9s
# 561:	learn: 1898.8115470	total: 5s	remaining: 3.89s
# 562:	learn: 1898.4525031	total: 5.01s	remaining: 3.89s
# 563:	learn: 1898.2574382	total: 5.01s	remaining: 3.88s
# 564:	learn: 1898.0349915	total: 5.02s	remaining: 3.87s
# 565:	learn: 1897.8318396	total: 5.03s	remaining: 3.86s
# 566:	learn: 1897.7611081	total: 5.04s	remaining: 3.85s
# 567:	learn: 1897.4712813	total: 5.05s	remaining: 3.84s
# 568:	learn: 1897.1913136	total: 5.06s	remaining: 3.83s
# 569:	learn: 1896.7446007	total: 5.07s	remaining: 3.82s
# 570:	learn: 1896.3597034	total: 5.07s	remaining: 3.81s
# 571:	learn: 1896.1637169	total: 5.08s	remaining: 3.8s
# 572:	learn: 1895.9579558	total: 5.09s	remaining: 3.79s
# 573:	learn: 1895.5490360	total: 5.1s	remaining: 3.78s
# 574:	learn: 1894.7428566	total: 5.11s	remaining: 3.77s
# 575:	learn: 1894.5975232	total: 5.12s	remaining: 3.77s
# 576:	learn: 1893.9102332	total: 5.13s	remaining: 3.76s
# 577:	learn: 1893.5077399	total: 5.13s	remaining: 3.75s
# 578:	learn: 1893.3868331	total: 5.14s	remaining: 3.74s
# 579:	learn: 1893.3176068	total: 5.16s	remaining: 3.73s
# 580:	learn: 1893.0567835	total: 5.16s	remaining: 3.72s
# 581:	learn: 1892.9006290	total: 5.17s	remaining: 3.71s
# 582:	learn: 1892.7115623	total: 5.18s	remaining: 3.71s
# 583:	learn: 1892.2192088	total: 5.19s	remaining: 3.7s
# 584:	learn: 1892.1170654	total: 5.2s	remaining: 3.69s
# 585:	learn: 1891.5995302	total: 5.21s	remaining: 3.68s
# 586:	learn: 1891.2786552	total: 5.22s	remaining: 3.67s
# 587:	learn: 1890.6188937	total: 5.23s	remaining: 3.66s
# 588:	learn: 1890.3636015	total: 5.23s	remaining: 3.65s
# 589:	learn: 1889.9329700	total: 5.24s	remaining: 3.64s
# 590:	learn: 1889.4525622	total: 5.25s	remaining: 3.63s
# 591:	learn: 1888.6042809	total: 5.26s	remaining: 3.62s
# 592:	learn: 1888.4946662	total: 5.27s	remaining: 3.62s
# 593:	learn: 1887.8881560	total: 5.28s	remaining: 3.61s
# 594:	learn: 1887.4624753	total: 5.29s	remaining: 3.6s
# 595:	learn: 1887.1985749	total: 5.29s	remaining: 3.59s
# 596:	learn: 1886.8909980	total: 5.3s	remaining: 3.58s
# 597:	learn: 1886.4525103	total: 5.31s	remaining: 3.57s
# 598:	learn: 1886.3848338	total: 5.32s	remaining: 3.56s
# 599:	learn: 1886.1309975	total: 5.33s	remaining: 3.55s
# 600:	learn: 1885.8880102	total: 5.34s	remaining: 3.54s
# 601:	learn: 1885.6722971	total: 5.34s	remaining: 3.53s
# 602:	learn: 1885.1114136	total: 5.35s	remaining: 3.52s
# 603:	learn: 1884.5135412	total: 5.36s	remaining: 3.52s
# 604:	learn: 1884.4467411	total: 5.37s	remaining: 3.51s
# 605:	learn: 1884.2555835	total: 5.38s	remaining: 3.5s
# 606:	learn: 1884.0756954	total: 5.39s	remaining: 3.49s
# 607:	learn: 1883.8917878	total: 5.4s	remaining: 3.48s
# 608:	learn: 1883.4993334	total: 5.41s	remaining: 3.47s
# 609:	learn: 1883.3404806	total: 5.42s	remaining: 3.46s
# 610:	learn: 1883.0363101	total: 5.43s	remaining: 3.46s
# 611:	learn: 1882.8055279	total: 5.44s	remaining: 3.45s
# 612:	learn: 1882.5066407	total: 5.45s	remaining: 3.44s
# 613:	learn: 1881.9081943	total: 5.46s	remaining: 3.43s
# 614:	learn: 1881.6866730	total: 5.46s	remaining: 3.42s
# 615:	learn: 1881.4657725	total: 5.47s	remaining: 3.41s
# 616:	learn: 1881.1212514	total: 5.48s	remaining: 3.4s
# 617:	learn: 1880.9640601	total: 5.49s	remaining: 3.4s
# 618:	learn: 1880.7134106	total: 5.5s	remaining: 3.38s
# 619:	learn: 1880.2550582	total: 5.51s	remaining: 3.38s
# 620:	learn: 1879.6376071	total: 5.52s	remaining: 3.37s
# 621:	learn: 1879.2720749	total: 5.53s	remaining: 3.36s
# 622:	learn: 1879.2063845	total: 5.53s	remaining: 3.35s
# 623:	learn: 1878.9500312	total: 5.54s	remaining: 3.34s
# 624:	learn: 1878.6917723	total: 5.55s	remaining: 3.33s
# 625:	learn: 1878.5307877	total: 5.56s	remaining: 3.32s
# 626:	learn: 1878.3971062	total: 5.57s	remaining: 3.31s
# 627:	learn: 1877.7495984	total: 5.58s	remaining: 3.3s
# 628:	learn: 1877.2399984	total: 5.59s	remaining: 3.29s
# 629:	learn: 1877.1767542	total: 5.59s	remaining: 3.29s
# 630:	learn: 1876.8411878	total: 5.6s	remaining: 3.28s
# 631:	learn: 1876.7295925	total: 5.61s	remaining: 3.27s
# 632:	learn: 1876.2264953	total: 5.62s	remaining: 3.26s
# 633:	learn: 1876.0341718	total: 5.63s	remaining: 3.25s
# 634:	learn: 1875.8821559	total: 5.64s	remaining: 3.24s
# 635:	learn: 1875.4056723	total: 5.65s	remaining: 3.23s
# 636:	learn: 1874.6647871	total: 5.65s	remaining: 3.22s
# 637:	learn: 1874.3529560	total: 5.66s	remaining: 3.21s
# 638:	learn: 1874.2637718	total: 5.67s	remaining: 3.2s
# 639:	learn: 1873.8258274	total: 5.68s	remaining: 3.19s
# 640:	learn: 1873.7003380	total: 5.69s	remaining: 3.19s
# 641:	learn: 1873.5524916	total: 5.7s	remaining: 3.18s
# 642:	learn: 1873.2983248	total: 5.7s	remaining: 3.17s
# 643:	learn: 1873.0944313	total: 5.71s	remaining: 3.16s
# 644:	learn: 1872.8061609	total: 5.72s	remaining: 3.15s
# 645:	learn: 1872.2169089	total: 5.73s	remaining: 3.14s
# 646:	learn: 1871.9593458	total: 5.74s	remaining: 3.13s
# 647:	learn: 1871.8305340	total: 5.75s	remaining: 3.12s
# 648:	learn: 1871.7126111	total: 5.76s	remaining: 3.11s
# 649:	learn: 1871.5349875	total: 5.77s	remaining: 3.1s
# 650:	learn: 1871.4232463	total: 5.77s	remaining: 3.1s
# 651:	learn: 1871.3041833	total: 5.78s	remaining: 3.09s
# 652:	learn: 1871.2044415	total: 5.79s	remaining: 3.08s
# 653:	learn: 1870.5529324	total: 5.8s	remaining: 3.07s
# 654:	learn: 1870.3635040	total: 5.81s	remaining: 3.06s
# 655:	learn: 1869.8669619	total: 5.81s	remaining: 3.05s
# 656:	learn: 1869.4929299	total: 5.82s	remaining: 3.04s
# 657:	learn: 1869.2409107	total: 5.83s	remaining: 3.03s
# 658:	learn: 1869.1298995	total: 5.84s	remaining: 3.02s
# 659:	learn: 1868.6072768	total: 5.85s	remaining: 3.01s
# 660:	learn: 1868.5436714	total: 5.86s	remaining: 3s
# 661:	learn: 1868.3009043	total: 5.87s	remaining: 2.99s
# 662:	learn: 1868.0760873	total: 5.87s	remaining: 2.98s
# 663:	learn: 1867.7511529	total: 5.88s	remaining: 2.98s
# 664:	learn: 1867.1719962	total: 5.89s	remaining: 2.97s
# 665:	learn: 1867.0732400	total: 5.9s	remaining: 2.96s
# 666:	learn: 1866.9529251	total: 5.91s	remaining: 2.95s
# 667:	learn: 1866.8269741	total: 5.91s	remaining: 2.94s
# 668:	learn: 1866.4630583	total: 5.92s	remaining: 2.93s
# 669:	learn: 1865.9270657	total: 5.93s	remaining: 2.92s
# 670:	learn: 1865.8325014	total: 5.94s	remaining: 2.91s
# 671:	learn: 1865.5526017	total: 5.95s	remaining: 2.9s
# 672:	learn: 1865.3106702	total: 5.96s	remaining: 2.89s
# 673:	learn: 1865.0712478	total: 5.96s	remaining: 2.88s
# 674:	learn: 1864.7118601	total: 5.97s	remaining: 2.88s
# 675:	learn: 1864.6555822	total: 5.98s	remaining: 2.87s
# 676:	learn: 1864.3204965	total: 5.99s	remaining: 2.86s
# 677:	learn: 1863.9675903	total: 6s	remaining: 2.85s
# 678:	learn: 1863.9059326	total: 6.01s	remaining: 2.84s
# 679:	learn: 1863.7521142	total: 6.02s	remaining: 2.83s
# 680:	learn: 1863.5919972	total: 6.03s	remaining: 2.82s
# 681:	learn: 1863.1298808	total: 6.03s	remaining: 2.81s
# 682:	learn: 1863.0355467	total: 6.04s	remaining: 2.8s
# 683:	learn: 1862.4820670	total: 6.05s	remaining: 2.79s
# 684:	learn: 1862.3826888	total: 6.06s	remaining: 2.79s
# 685:	learn: 1862.3244267	total: 6.07s	remaining: 2.78s
# 686:	learn: 1862.2080857	total: 6.08s	remaining: 2.77s
# 687:	learn: 1862.0663812	total: 6.08s	remaining: 2.76s
# 688:	learn: 1861.6495536	total: 6.09s	remaining: 2.75s
# 689:	learn: 1861.3814928	total: 6.1s	remaining: 2.74s
# 690:	learn: 1861.0000589	total: 6.11s	remaining: 2.73s
# 691:	learn: 1860.6096548	total: 6.12s	remaining: 2.72s
# 692:	learn: 1860.5348250	total: 6.13s	remaining: 2.72s
# 693:	learn: 1860.1284812	total: 6.14s	remaining: 2.71s
# 694:	learn: 1860.0282426	total: 6.15s	remaining: 2.7s
# 695:	learn: 1859.6327000	total: 6.16s	remaining: 2.69s
# 696:	learn: 1859.5276905	total: 6.17s	remaining: 2.68s
# 697:	learn: 1858.9981894	total: 6.18s	remaining: 2.67s
# 698:	learn: 1858.5008490	total: 6.19s	remaining: 2.66s
# 699:	learn: 1858.2713003	total: 6.2s	remaining: 2.65s
# 700:	learn: 1857.8218015	total: 6.2s	remaining: 2.65s
# 701:	learn: 1857.5128001	total: 6.21s	remaining: 2.64s
# 702:	learn: 1857.2130436	total: 6.22s	remaining: 2.63s
# 703:	learn: 1857.0502924	total: 6.23s	remaining: 2.62s
# 704:	learn: 1856.9921599	total: 6.24s	remaining: 2.61s
# 705:	learn: 1856.6635502	total: 6.25s	remaining: 2.6s
# 706:	learn: 1856.1572726	total: 6.26s	remaining: 2.59s
# 707:	learn: 1855.8865120	total: 6.27s	remaining: 2.58s
# 708:	learn: 1855.8298768	total: 6.28s	remaining: 2.58s
# 709:	learn: 1855.6586117	total: 6.28s	remaining: 2.57s
# 710:	learn: 1855.2288067	total: 6.29s	remaining: 2.56s
# 711:	learn: 1854.8996634	total: 6.3s	remaining: 2.55s
# 712:	learn: 1854.7104401	total: 6.31s	remaining: 2.54s
# 713:	learn: 1854.6523188	total: 6.32s	remaining: 2.53s
# 714:	learn: 1854.4329749	total: 6.33s	remaining: 2.52s
# 715:	learn: 1854.2074015	total: 6.34s	remaining: 2.51s
# 716:	learn: 1853.7886100	total: 6.35s	remaining: 2.5s
# 717:	learn: 1853.3181149	total: 6.36s	remaining: 2.5s
# 718:	learn: 1853.0463132	total: 6.37s	remaining: 2.49s
# 719:	learn: 1852.6946113	total: 6.38s	remaining: 2.48s
# 720:	learn: 1852.5829908	total: 6.39s	remaining: 2.47s
# 721:	learn: 1852.2692703	total: 6.4s	remaining: 2.46s
# 722:	learn: 1852.2118256	total: 6.41s	remaining: 2.46s
# 723:	learn: 1851.7137858	total: 6.42s	remaining: 2.45s
# 724:	learn: 1851.3984608	total: 6.43s	remaining: 2.44s
# 725:	learn: 1851.2173796	total: 6.44s	remaining: 2.43s
# 726:	learn: 1851.0791730	total: 6.45s	remaining: 2.42s
# 727:	learn: 1850.7611091	total: 6.46s	remaining: 2.41s
# 728:	learn: 1850.7048332	total: 6.47s	remaining: 2.4s
# 729:	learn: 1850.1370355	total: 6.48s	remaining: 2.4s
# 730:	learn: 1849.7255400	total: 6.49s	remaining: 2.39s
# 731:	learn: 1849.3750637	total: 6.5s	remaining: 2.38s
# 732:	learn: 1848.8648434	total: 6.5s	remaining: 2.37s
# 733:	learn: 1848.7274686	total: 6.51s	remaining: 2.36s
# 734:	learn: 1848.4253803	total: 6.52s	remaining: 2.35s
# 735:	learn: 1848.3003883	total: 6.53s	remaining: 2.34s
# 736:	learn: 1847.9740824	total: 6.54s	remaining: 2.33s
# 737:	learn: 1847.2832587	total: 6.55s	remaining: 2.32s
# 738:	learn: 1847.0813738	total: 6.56s	remaining: 2.32s
# 739:	learn: 1846.3541984	total: 6.57s	remaining: 2.31s
# 740:	learn: 1845.8478559	total: 6.58s	remaining: 2.3s
# 741:	learn: 1845.7660878	total: 6.58s	remaining: 2.29s
# 742:	learn: 1845.2763442	total: 6.59s	remaining: 2.28s
# 743:	learn: 1845.0191270	total: 6.6s	remaining: 2.27s
# 744:	learn: 1844.5157428	total: 6.61s	remaining: 2.26s
# 745:	learn: 1844.3450682	total: 6.62s	remaining: 2.25s
# 746:	learn: 1844.1496841	total: 6.63s	remaining: 2.24s
# 747:	learn: 1843.9073688	total: 6.64s	remaining: 2.23s
# 748:	learn: 1843.8515380	total: 6.64s	remaining: 2.23s
# 749:	learn: 1843.5907819	total: 6.67s	remaining: 2.22s
# 750:	learn: 1843.1860902	total: 6.7s	remaining: 2.22s
# 751:	learn: 1842.7562175	total: 6.71s	remaining: 2.21s
# 752:	learn: 1842.4693509	total: 6.72s	remaining: 2.2s
# 753:	learn: 1842.1130710	total: 6.73s	remaining: 2.2s
# 754:	learn: 1841.5934397	total: 6.74s	remaining: 2.19s
# 755:	learn: 1841.4452710	total: 6.75s	remaining: 2.18s
# 756:	learn: 1841.3656260	total: 6.76s	remaining: 2.17s
# 757:	learn: 1840.9771951	total: 6.77s	remaining: 2.16s
# 758:	learn: 1840.5418038	total: 6.78s	remaining: 2.15s
# 759:	learn: 1840.0603435	total: 6.79s	remaining: 2.14s
# 760:	learn: 1840.0056120	total: 6.8s	remaining: 2.13s
# 761:	learn: 1839.6773936	total: 6.81s	remaining: 2.13s
# 762:	learn: 1839.4945644	total: 6.82s	remaining: 2.12s
# 763:	learn: 1839.1009102	total: 6.83s	remaining: 2.11s
# 764:	learn: 1838.9304984	total: 6.83s	remaining: 2.1s
# 765:	learn: 1838.8182481	total: 6.84s	remaining: 2.09s
# 766:	learn: 1838.4406050	total: 6.85s	remaining: 2.08s
# 767:	learn: 1838.0539415	total: 6.86s	remaining: 2.07s
# 768:	learn: 1837.7428299	total: 6.87s	remaining: 2.06s
# 769:	learn: 1837.6886631	total: 6.88s	remaining: 2.06s
# 770:	learn: 1837.3122976	total: 6.89s	remaining: 2.05s
# 771:	learn: 1837.0262667	total: 6.9s	remaining: 2.04s
# 772:	learn: 1836.5563849	total: 6.91s	remaining: 2.03s
# 773:	learn: 1836.3968234	total: 6.92s	remaining: 2.02s
# 774:	learn: 1836.0574226	total: 6.92s	remaining: 2.01s
# 775:	learn: 1835.8459090	total: 6.93s	remaining: 2s
# 776:	learn: 1835.7927813	total: 6.94s	remaining: 1.99s
# 777:	learn: 1835.3564895	total: 6.95s	remaining: 1.98s
# 778:	learn: 1835.1651390	total: 6.96s	remaining: 1.97s
# 779:	learn: 1834.9747446	total: 6.97s	remaining: 1.97s
# 780:	learn: 1834.8454717	total: 6.98s	remaining: 1.96s
# 781:	learn: 1834.7021837	total: 6.99s	remaining: 1.95s
# 782:	learn: 1834.5959324	total: 6.99s	remaining: 1.94s
# 783:	learn: 1834.4275678	total: 7s	remaining: 1.93s
# 784:	learn: 1834.0020330	total: 7.01s	remaining: 1.92s
# 785:	learn: 1833.6775619	total: 7.02s	remaining: 1.91s
# 786:	learn: 1833.5739179	total: 7.03s	remaining: 1.9s
# 787:	learn: 1833.3683433	total: 7.04s	remaining: 1.89s
# 788:	learn: 1833.2061283	total: 7.05s	remaining: 1.88s
# 789:	learn: 1832.6573371	total: 7.06s	remaining: 1.88s
# 790:	learn: 1832.6045540	total: 7.07s	remaining: 1.87s
# 791:	learn: 1832.1534297	total: 7.08s	remaining: 1.86s
# 792:	learn: 1831.8123711	total: 7.08s	remaining: 1.85s
# 793:	learn: 1831.4554877	total: 7.09s	remaining: 1.84s
# 794:	learn: 1831.1159633	total: 7.1s	remaining: 1.83s
# 795:	learn: 1831.0358693	total: 7.11s	remaining: 1.82s
# 796:	learn: 1830.7440092	total: 7.12s	remaining: 1.81s
# 797:	learn: 1830.5601762	total: 7.13s	remaining: 1.8s
# 798:	learn: 1830.3803510	total: 7.14s	remaining: 1.79s
# 799:	learn: 1830.0853235	total: 7.14s	remaining: 1.79s
# 800:	learn: 1829.5661216	total: 7.15s	remaining: 1.78s
# 801:	learn: 1829.2829066	total: 7.17s	remaining: 1.77s
# 802:	learn: 1829.0394887	total: 7.18s	remaining: 1.76s
# 803:	learn: 1828.9897497	total: 7.18s	remaining: 1.75s
# 804:	learn: 1828.8313921	total: 7.19s	remaining: 1.74s
# 805:	learn: 1828.1339618	total: 7.2s	remaining: 1.73s
# 806:	learn: 1828.0573257	total: 7.21s	remaining: 1.72s
# 807:	learn: 1828.0059076	total: 7.22s	remaining: 1.72s
# 808:	learn: 1827.5013862	total: 7.23s	remaining: 1.71s
# 809:	learn: 1827.4507662	total: 7.24s	remaining: 1.7s
# 810:	learn: 1827.2769407	total: 7.25s	remaining: 1.69s
# 811:	learn: 1827.0928179	total: 7.25s	remaining: 1.68s
# 812:	learn: 1826.4033144	total: 7.26s	remaining: 1.67s
# 813:	learn: 1826.3132354	total: 7.27s	remaining: 1.66s
# 814:	learn: 1825.8652607	total: 7.28s	remaining: 1.65s
# 815:	learn: 1825.5420673	total: 7.29s	remaining: 1.64s
# 816:	learn: 1825.4373942	total: 7.3s	remaining: 1.63s
# 817:	learn: 1825.2865334	total: 7.3s	remaining: 1.63s
# 818:	learn: 1824.9009622	total: 7.31s	remaining: 1.62s
# 819:	learn: 1824.5462188	total: 7.32s	remaining: 1.61s
# 820:	learn: 1824.2762023	total: 7.33s	remaining: 1.6s
# 821:	learn: 1823.9968790	total: 7.34s	remaining: 1.59s
# 822:	learn: 1823.5839221	total: 7.35s	remaining: 1.58s
# 823:	learn: 1823.3772075	total: 7.36s	remaining: 1.57s
# 824:	learn: 1822.9943536	total: 7.37s	remaining: 1.56s
# 825:	learn: 1822.9441192	total: 7.37s	remaining: 1.55s
# 826:	learn: 1822.6764461	total: 7.38s	remaining: 1.54s
# 827:	learn: 1822.3691761	total: 7.39s	remaining: 1.53s
# 828:	learn: 1822.0630358	total: 7.4s	remaining: 1.53s
# 829:	learn: 1821.8696745	total: 7.41s	remaining: 1.52s
# 830:	learn: 1821.6323306	total: 7.42s	remaining: 1.51s
# 831:	learn: 1821.5829478	total: 7.43s	remaining: 1.5s
# 832:	learn: 1821.3577788	total: 7.43s	remaining: 1.49s
# 833:	learn: 1821.2121971	total: 7.44s	remaining: 1.48s
# 834:	learn: 1821.0889511	total: 7.45s	remaining: 1.47s
# 835:	learn: 1820.9307153	total: 7.46s	remaining: 1.46s
# 836:	learn: 1820.6853259	total: 7.47s	remaining: 1.45s
# 837:	learn: 1820.5935953	total: 7.48s	remaining: 1.45s
# 838:	learn: 1820.4545571	total: 7.49s	remaining: 1.44s
# 839:	learn: 1820.4060667	total: 7.49s	remaining: 1.43s
# 840:	learn: 1820.0734295	total: 7.5s	remaining: 1.42s
# 841:	learn: 1819.5888465	total: 7.51s	remaining: 1.41s
# 842:	learn: 1819.4747618	total: 7.52s	remaining: 1.4s
# 843:	learn: 1819.1769896	total: 7.53s	remaining: 1.39s
# 844:	learn: 1818.9932662	total: 7.54s	remaining: 1.38s
# 845:	learn: 1818.9451299	total: 7.55s	remaining: 1.37s
# 846:	learn: 1818.6951523	total: 7.56s	remaining: 1.36s
# 847:	learn: 1818.4824751	total: 7.57s	remaining: 1.36s
# 848:	learn: 1818.0064032	total: 7.58s	remaining: 1.35s
# 849:	learn: 1817.8814583	total: 7.58s	remaining: 1.34s
# 850:	learn: 1817.6217858	total: 7.59s	remaining: 1.33s
# 851:	learn: 1817.1534300	total: 7.6s	remaining: 1.32s
# 852:	learn: 1816.7922102	total: 7.61s	remaining: 1.31s
# 853:	learn: 1816.5117433	total: 7.62s	remaining: 1.3s
# 854:	learn: 1816.3481219	total: 7.63s	remaining: 1.29s
# 855:	learn: 1815.9814111	total: 7.64s	remaining: 1.28s
# 856:	learn: 1815.8295456	total: 7.64s	remaining: 1.27s
# 857:	learn: 1815.7840615	total: 7.65s	remaining: 1.27s
# 858:	learn: 1815.7132505	total: 7.66s	remaining: 1.26s
# 859:	learn: 1815.5530361	total: 7.67s	remaining: 1.25s
# 860:	learn: 1815.1591935	total: 7.68s	remaining: 1.24s
# 861:	learn: 1814.7977047	total: 7.69s	remaining: 1.23s
# 862:	learn: 1814.5667943	total: 7.7s	remaining: 1.22s
# 863:	learn: 1814.0902840	total: 7.71s	remaining: 1.21s
# 864:	learn: 1813.8462333	total: 7.71s	remaining: 1.2s
# 865:	learn: 1813.3558699	total: 7.72s	remaining: 1.2s
# 866:	learn: 1813.1042556	total: 7.73s	remaining: 1.19s
# 867:	learn: 1812.7078537	total: 7.74s	remaining: 1.18s
# 868:	learn: 1812.4276739	total: 7.75s	remaining: 1.17s
# 869:	learn: 1812.0410971	total: 7.76s	remaining: 1.16s
# 870:	learn: 1811.7029346	total: 7.77s	remaining: 1.15s
# 871:	learn: 1811.2977702	total: 7.78s	remaining: 1.14s
# 872:	learn: 1811.1851071	total: 7.79s	remaining: 1.13s
# 873:	learn: 1810.8221708	total: 7.79s	remaining: 1.12s
# 874:	learn: 1810.5910615	total: 7.8s	remaining: 1.11s
# 875:	learn: 1810.3993368	total: 7.81s	remaining: 1.1s
# 876:	learn: 1810.0503029	total: 7.82s	remaining: 1.1s
# ...
# 710:	learn: 0.5656116	total: 22.1s	remaining: 8.97s
# 711:	learn: 0.5655967	total: 22.1s	remaining: 8.94s
# 712:	learn: 0.5655866	total: 22.1s	remaining: 8.91s
# 713:	learn: 0.5655797	total: 22.2s	remaining: 8.88s
# 714:	learn: 0.5655564	total: 22.2s	remaining: 8.85s
# 715:	learn: 0.5655414	total: 22.2s	remaining: 8.82s
# 716:	learn: 0.5655198	total: 22.3s	remaining: 8.79s
# 717:	learn: 0.5655030	total: 22.3s	remaining: 8.76s
# 718:	learn: 0.5654826	total: 22.3s	remaining: 8.73s
# 719:	learn: 0.5654682	total: 22.4s	remaining: 8.7s
# 720:	learn: 0.5654536	total: 22.4s	remaining: 8.67s
# 721:	learn: 0.5654419	total: 22.4s	remaining: 8.63s
# 722:	learn: 0.5654260	total: 22.5s	remaining: 8.6s
# 723:	learn: 0.5653966	total: 22.5s	remaining: 8.57s
# 724:	learn: 0.5653824	total: 22.5s	remaining: 8.54s
# 725:	learn: 0.5653553	total: 22.5s	remaining: 8.51s
# 726:	learn: 0.5653320	total: 22.6s	remaining: 8.48s
# 727:	learn: 0.5653168	total: 22.6s	remaining: 8.45s
# 728:	learn: 0.5653035	total: 22.6s	remaining: 8.42s
# 729:	learn: 0.5652783	total: 22.7s	remaining: 8.38s
# 730:	learn: 0.5652521	total: 22.7s	remaining: 8.36s
# 731:	learn: 0.5652363	total: 22.7s	remaining: 8.32s
# 732:	learn: 0.5652045	total: 22.8s	remaining: 8.29s
# 733:	learn: 0.5651943	total: 22.8s	remaining: 8.26s
# 734:	learn: 0.5651720	total: 22.8s	remaining: 8.23s
# 735:	learn: 0.5651468	total: 22.9s	remaining: 8.2s
# 736:	learn: 0.5651325	total: 22.9s	remaining: 8.17s
# 737:	learn: 0.5651038	total: 22.9s	remaining: 8.14s
# 738:	learn: 0.5650931	total: 23s	remaining: 8.11s
# 739:	learn: 0.5650673	total: 23s	remaining: 8.08s
# 740:	learn: 0.5650392	total: 23s	remaining: 8.05s
# 741:	learn: 0.5650090	total: 23.1s	remaining: 8.02s
# 742:	learn: 0.5649564	total: 23.1s	remaining: 7.99s
# 743:	learn: 0.5649384	total: 23.1s	remaining: 7.96s
# 744:	learn: 0.5649211	total: 23.2s	remaining: 7.92s
# 745:	learn: 0.5649044	total: 23.2s	remaining: 7.89s
# 746:	learn: 0.5648710	total: 23.2s	remaining: 7.86s
# 747:	learn: 0.5648411	total: 23.2s	remaining: 7.83s
# 748:	learn: 0.5648091	total: 23.3s	remaining: 7.8s
# 749:	learn: 0.5647959	total: 23.3s	remaining: 7.77s
# 750:	learn: 0.5647682	total: 23.3s	remaining: 7.74s
# 751:	learn: 0.5647400	total: 23.4s	remaining: 7.71s
# 752:	learn: 0.5647313	total: 23.4s	remaining: 7.67s
# 753:	learn: 0.5647139	total: 23.4s	remaining: 7.64s
# 754:	learn: 0.5647033	total: 23.5s	remaining: 7.61s
# 755:	learn: 0.5646831	total: 23.5s	remaining: 7.58s
# 756:	learn: 0.5646413	total: 23.5s	remaining: 7.55s
# 757:	learn: 0.5646170	total: 23.6s	remaining: 7.52s
# 758:	learn: 0.5645966	total: 23.6s	remaining: 7.49s
# 759:	learn: 0.5645904	total: 23.6s	remaining: 7.46s
# 760:	learn: 0.5645796	total: 23.7s	remaining: 7.43s
# 761:	learn: 0.5645694	total: 23.7s	remaining: 7.4s
# 762:	learn: 0.5645439	total: 23.7s	remaining: 7.37s
# 763:	learn: 0.5645256	total: 23.8s	remaining: 7.34s
# 764:	learn: 0.5645047	total: 23.8s	remaining: 7.3s
# 765:	learn: 0.5644834	total: 23.8s	remaining: 7.27s
# 766:	learn: 0.5644669	total: 23.8s	remaining: 7.24s
# 767:	learn: 0.5644570	total: 23.9s	remaining: 7.21s
# 768:	learn: 0.5644498	total: 23.9s	remaining: 7.18s
# 769:	learn: 0.5644362	total: 23.9s	remaining: 7.15s
# 770:	learn: 0.5644162	total: 24s	remaining: 7.12s
# 771:	learn: 0.5643644	total: 24s	remaining: 7.08s
# 772:	learn: 0.5643430	total: 24s	remaining: 7.05s
# 773:	learn: 0.5643189	total: 24s	remaining: 7.02s
# 774:	learn: 0.5643109	total: 24.1s	remaining: 6.99s
# 775:	learn: 0.5642913	total: 24.1s	remaining: 6.96s
# 776:	learn: 0.5642641	total: 24.1s	remaining: 6.93s
# 777:	learn: 0.5642532	total: 24.2s	remaining: 6.9s
# 778:	learn: 0.5642416	total: 24.2s	remaining: 6.87s
# 779:	learn: 0.5642250	total: 24.2s	remaining: 6.83s
# 780:	learn: 0.5642127	total: 24.3s	remaining: 6.8s
# 781:	learn: 0.5641911	total: 24.3s	remaining: 6.77s
# 782:	learn: 0.5641749	total: 24.3s	remaining: 6.74s
# 783:	learn: 0.5641611	total: 24.4s	remaining: 6.71s
# 784:	learn: 0.5641408	total: 24.4s	remaining: 6.68s
# 785:	learn: 0.5641203	total: 24.4s	remaining: 6.65s
# 786:	learn: 0.5641097	total: 24.5s	remaining: 6.62s
# 787:	learn: 0.5640918	total: 24.5s	remaining: 6.59s
# 788:	learn: 0.5640685	total: 24.5s	remaining: 6.56s
# 789:	learn: 0.5640498	total: 24.6s	remaining: 6.53s
# 790:	learn: 0.5640198	total: 24.6s	remaining: 6.5s
# 791:	learn: 0.5639966	total: 24.6s	remaining: 6.46s
# 792:	learn: 0.5639783	total: 24.6s	remaining: 6.43s
# 793:	learn: 0.5639619	total: 24.7s	remaining: 6.4s
# 794:	learn: 0.5639394	total: 24.7s	remaining: 6.37s
# 795:	learn: 0.5639233	total: 24.7s	remaining: 6.34s
# 796:	learn: 0.5639045	total: 24.8s	remaining: 6.31s
# 797:	learn: 0.5638803	total: 24.8s	remaining: 6.28s
# 798:	learn: 0.5638569	total: 24.8s	remaining: 6.25s
# 799:	learn: 0.5638465	total: 24.9s	remaining: 6.21s
# 800:	learn: 0.5638326	total: 24.9s	remaining: 6.18s
# 801:	learn: 0.5638158	total: 24.9s	remaining: 6.15s
# 802:	learn: 0.5637958	total: 25s	remaining: 6.12s
# 803:	learn: 0.5637693	total: 25s	remaining: 6.09s
# 804:	learn: 0.5637561	total: 25s	remaining: 6.06s
# 805:	learn: 0.5637312	total: 25s	remaining: 6.03s
# 806:	learn: 0.5637154	total: 25.1s	remaining: 6s
# 807:	learn: 0.5636944	total: 25.1s	remaining: 5.97s
# 808:	learn: 0.5636604	total: 25.1s	remaining: 5.94s
# 809:	learn: 0.5636396	total: 25.2s	remaining: 5.91s
# 810:	learn: 0.5636223	total: 25.2s	remaining: 5.87s
# 811:	learn: 0.5636127	total: 25.2s	remaining: 5.84s
# 812:	learn: 0.5635906	total: 25.3s	remaining: 5.81s
# 813:	learn: 0.5635745	total: 25.3s	remaining: 5.78s
# 814:	learn: 0.5635503	total: 25.3s	remaining: 5.75s
# 815:	learn: 0.5635412	total: 25.4s	remaining: 5.72s
# 816:	learn: 0.5635307	total: 25.4s	remaining: 5.69s
# 817:	learn: 0.5635183	total: 25.4s	remaining: 5.66s
# 818:	learn: 0.5635026	total: 25.5s	remaining: 5.63s
# 819:	learn: 0.5634664	total: 25.5s	remaining: 5.59s
# 820:	learn: 0.5634517	total: 25.5s	remaining: 5.56s
# 821:	learn: 0.5634320	total: 25.5s	remaining: 5.53s
# 822:	learn: 0.5634119	total: 25.6s	remaining: 5.5s
# 823:	learn: 0.5633964	total: 25.6s	remaining: 5.47s
# 824:	learn: 0.5633695	total: 25.6s	remaining: 5.44s
# 825:	learn: 0.5633450	total: 25.7s	remaining: 5.41s
# 826:	learn: 0.5633309	total: 25.7s	remaining: 5.38s
# 827:	learn: 0.5633266	total: 25.7s	remaining: 5.34s
# 828:	learn: 0.5633089	total: 25.8s	remaining: 5.31s
# 829:	learn: 0.5632889	total: 25.8s	remaining: 5.28s
# 830:	learn: 0.5632696	total: 25.8s	remaining: 5.25s
# 831:	learn: 0.5632480	total: 25.9s	remaining: 5.22s
# 832:	learn: 0.5632408	total: 25.9s	remaining: 5.19s
# 833:	learn: 0.5632306	total: 25.9s	remaining: 5.16s
# 834:	learn: 0.5632101	total: 26s	remaining: 5.13s
# 835:	learn: 0.5631912	total: 26s	remaining: 5.1s
# 836:	learn: 0.5631727	total: 26s	remaining: 5.07s
# 837:	learn: 0.5631532	total: 26s	remaining: 5.03s
# 838:	learn: 0.5631350	total: 26.1s	remaining: 5s
# 839:	learn: 0.5631150	total: 26.1s	remaining: 4.97s
# 840:	learn: 0.5630872	total: 26.1s	remaining: 4.94s
# 841:	learn: 0.5630630	total: 26.2s	remaining: 4.91s
# 842:	learn: 0.5630548	total: 26.2s	remaining: 4.88s
# 843:	learn: 0.5630381	total: 26.2s	remaining: 4.85s
# 844:	learn: 0.5630283	total: 26.3s	remaining: 4.82s
# 845:	learn: 0.5630134	total: 26.3s	remaining: 4.79s
# 846:	learn: 0.5629877	total: 26.3s	remaining: 4.75s
# 847:	learn: 0.5629737	total: 26.3s	remaining: 4.72s
# 848:	learn: 0.5629594	total: 26.4s	remaining: 4.69s
# 849:	learn: 0.5629376	total: 26.4s	remaining: 4.66s
# 850:	learn: 0.5629164	total: 26.4s	remaining: 4.63s
# 851:	learn: 0.5628926	total: 26.5s	remaining: 4.6s
# 852:	learn: 0.5628694	total: 26.5s	remaining: 4.57s
# 853:	learn: 0.5628261	total: 26.5s	remaining: 4.53s
# 854:	learn: 0.5628113	total: 26.6s	remaining: 4.5s
# 855:	learn: 0.5627940	total: 26.6s	remaining: 4.47s
# 856:	learn: 0.5627874	total: 26.6s	remaining: 4.44s
# 857:	learn: 0.5627765	total: 26.7s	remaining: 4.41s
# 858:	learn: 0.5627416	total: 26.7s	remaining: 4.38s
# 859:	learn: 0.5627336	total: 26.7s	remaining: 4.35s
# 860:	learn: 0.5627255	total: 26.7s	remaining: 4.32s
# 861:	learn: 0.5626951	total: 26.8s	remaining: 4.29s
# 862:	learn: 0.5626853	total: 26.8s	remaining: 4.26s
# 863:	learn: 0.5626665	total: 26.8s	remaining: 4.22s
# 864:	learn: 0.5626460	total: 26.9s	remaining: 4.19s
# 865:	learn: 0.5626261	total: 26.9s	remaining: 4.16s
# 866:	learn: 0.5626191	total: 26.9s	remaining: 4.13s
# 867:	learn: 0.5626073	total: 27s	remaining: 4.1s
# 868:	learn: 0.5625884	total: 27s	remaining: 4.07s
# 869:	learn: 0.5625787	total: 27s	remaining: 4.04s
# 870:	learn: 0.5625567	total: 27.1s	remaining: 4.01s
# 871:	learn: 0.5625430	total: 27.1s	remaining: 3.98s
# 872:	learn: 0.5625326	total: 27.1s	remaining: 3.94s
# 873:	learn: 0.5625027	total: 27.1s	remaining: 3.91s
# 874:	learn: 0.5624816	total: 27.2s	remaining: 3.88s
# 875:	learn: 0.5624651	total: 27.2s	remaining: 3.85s
# 876:	learn: 0.5624492	total: 27.2s	remaining: 3.82s
# 877:	learn: 0.5624410	total: 27.3s	remaining: 3.79s
# 878:	learn: 0.5624160	total: 27.3s	remaining: 3.76s
# 879:	learn: 0.5624007	total: 27.3s	remaining: 3.73s
# 880:	learn: 0.5623826	total: 27.4s	remaining: 3.69s
# 881:	learn: 0.5623550	total: 27.4s	remaining: 3.66s
# 882:	learn: 0.5623289	total: 27.4s	remaining: 3.63s
# 883:	learn: 0.5623203	total: 27.4s	remaining: 3.6s
# 884:	learn: 0.5622944	total: 27.5s	remaining: 3.57s
# 885:	learn: 0.5622844	total: 27.5s	remaining: 3.54s
# 886:	learn: 0.5622630	total: 27.5s	remaining: 3.51s
# 887:	learn: 0.5622363	total: 27.6s	remaining: 3.48s
# 888:	learn: 0.5622195	total: 27.6s	remaining: 3.44s
# 889:	learn: 0.5622078	total: 27.6s	remaining: 3.41s
# 890:	learn: 0.5621937	total: 27.6s	remaining: 3.38s
# 891:	learn: 0.5621877	total: 27.7s	remaining: 3.35s
# 892:	learn: 0.5621428	total: 27.7s	remaining: 3.32s
# 893:	learn: 0.5621262	total: 27.7s	remaining: 3.29s
# 894:	learn: 0.5621174	total: 27.8s	remaining: 3.26s
# 895:	learn: 0.5621059	total: 27.8s	remaining: 3.23s
# 896:	learn: 0.5620810	total: 27.8s	remaining: 3.19s
# 897:	learn: 0.5620755	total: 27.9s	remaining: 3.16s
# 898:	learn: 0.5620603	total: 27.9s	remaining: 3.13s
# 899:	learn: 0.5620465	total: 27.9s	remaining: 3.1s
# 900:	learn: 0.5620241	total: 28s	remaining: 3.07s
# 901:	learn: 0.5620084	total: 28s	remaining: 3.04s
# 902:	learn: 0.5619991	total: 28s	remaining: 3.01s
# 903:	learn: 0.5619790	total: 28.1s	remaining: 2.98s
# 904:	learn: 0.5619696	total: 28.1s	remaining: 2.95s
# 905:	learn: 0.5619537	total: 28.1s	remaining: 2.92s
# 906:	learn: 0.5619402	total: 28.2s	remaining: 2.89s
# 907:	learn: 0.5619248	total: 28.2s	remaining: 2.85s
# 908:	learn: 0.5619080	total: 28.2s	remaining: 2.82s
# 909:	learn: 0.5618938	total: 28.2s	remaining: 2.79s
# 910:	learn: 0.5618743	total: 28.3s	remaining: 2.76s
# 911:	learn: 0.5618548	total: 28.3s	remaining: 2.73s
# 912:	learn: 0.5618439	total: 28.3s	remaining: 2.7s
# 913:	learn: 0.5618138	total: 28.4s	remaining: 2.67s
# 914:	learn: 0.5617985	total: 28.4s	remaining: 2.64s
# 915:	learn: 0.5617776	total: 28.4s	remaining: 2.61s
# 916:	learn: 0.5617652	total: 28.5s	remaining: 2.58s
# 917:	learn: 0.5617461	total: 28.5s	remaining: 2.55s
# 918:	learn: 0.5617345	total: 28.5s	remaining: 2.52s
# 919:	learn: 0.5617196	total: 28.6s	remaining: 2.48s
# 920:	learn: 0.5617091	total: 28.6s	remaining: 2.45s
# 921:	learn: 0.5616902	total: 28.6s	remaining: 2.42s
# 922:	learn: 0.5616740	total: 28.7s	remaining: 2.39s
# 923:	learn: 0.5616581	total: 28.7s	remaining: 2.36s
# 924:	learn: 0.5616436	total: 28.7s	remaining: 2.33s
# 925:	learn: 0.5616343	total: 28.8s	remaining: 2.3s
# 926:	learn: 0.5616126	total: 28.8s	remaining: 2.27s
# 927:	learn: 0.5615985	total: 28.8s	remaining: 2.24s
# 928:	learn: 0.5615732	total: 28.8s	remaining: 2.2s
# 929:	learn: 0.5615438	total: 28.9s	remaining: 2.17s
# 930:	learn: 0.5615242	total: 28.9s	remaining: 2.14s
# 931:	learn: 0.5615168	total: 28.9s	remaining: 2.11s
# 932:	learn: 0.5614989	total: 29s	remaining: 2.08s
# 933:	learn: 0.5614790	total: 29s	remaining: 2.05s
# 934:	learn: 0.5614692	total: 29s	remaining: 2.02s
# 935:	learn: 0.5614326	total: 29.1s	remaining: 1.99s
# 936:	learn: 0.5614180	total: 29.1s	remaining: 1.96s
# 937:	learn: 0.5613990	total: 29.1s	remaining: 1.93s
# 938:	learn: 0.5613858	total: 29.2s	remaining: 1.89s
# 939:	learn: 0.5613520	total: 29.2s	remaining: 1.86s
# 940:	learn: 0.5613300	total: 29.2s	remaining: 1.83s
# 941:	learn: 0.5613165	total: 29.3s	remaining: 1.8s
# 942:	learn: 0.5613087	total: 29.3s	remaining: 1.77s
# 943:	learn: 0.5612919	total: 29.3s	remaining: 1.74s
# 944:	learn: 0.5612753	total: 29.4s	remaining: 1.71s
# 945:	learn: 0.5612551	total: 29.4s	remaining: 1.68s
# 946:	learn: 0.5612304	total: 29.4s	remaining: 1.65s
# 947:	learn: 0.5612231	total: 29.5s	remaining: 1.61s
# 948:	learn: 0.5612135	total: 29.5s	remaining: 1.58s
# 949:	learn: 0.5611890	total: 29.5s	remaining: 1.55s
# 950:	learn: 0.5611670	total: 29.5s	remaining: 1.52s
# 951:	learn: 0.5611522	total: 29.6s	remaining: 1.49s
# 952:	learn: 0.5611441	total: 29.6s	remaining: 1.46s
# 953:	learn: 0.5611417	total: 29.6s	remaining: 1.43s
# 954:	learn: 0.5611348	total: 29.7s	remaining: 1.4s
# 955:	learn: 0.5611168	total: 29.7s	remaining: 1.37s
# 956:	learn: 0.5611057	total: 29.7s	remaining: 1.33s
# 957:	learn: 0.5610971	total: 29.8s	remaining: 1.3s
# 958:	learn: 0.5610785	total: 29.8s	remaining: 1.27s
# 959:	learn: 0.5610632	total: 29.8s	remaining: 1.24s
# 960:	learn: 0.5610545	total: 29.8s	remaining: 1.21s
# 961:	learn: 0.5610393	total: 29.9s	remaining: 1.18s
# 962:	learn: 0.5610237	total: 29.9s	remaining: 1.15s
# 963:	learn: 0.5610097	total: 29.9s	remaining: 1.12s
# 964:	learn: 0.5609972	total: 30s	remaining: 1.09s
# 965:	learn: 0.5609747	total: 30s	remaining: 1.06s
# 966:	learn: 0.5609590	total: 30s	remaining: 1.02s
# 967:	learn: 0.5609246	total: 30.1s	remaining: 994ms
# 968:	learn: 0.5608999	total: 30.1s	remaining: 963ms
# 969:	learn: 0.5608797	total: 30.1s	remaining: 932ms
# 970:	learn: 0.5608600	total: 30.2s	remaining: 901ms
# 971:	learn: 0.5608543	total: 30.2s	remaining: 870ms
# 972:	learn: 0.5608299	total: 30.2s	remaining: 839ms
# 973:	learn: 0.5608206	total: 30.3s	remaining: 808ms
# 974:	learn: 0.5607945	total: 30.3s	remaining: 777ms
# 975:	learn: 0.5607829	total: 30.3s	remaining: 746ms
# 976:	learn: 0.5607699	total: 30.4s	remaining: 715ms
# 977:	learn: 0.5607558	total: 30.4s	remaining: 684ms
# 978:	learn: 0.5607436	total: 30.4s	remaining: 653ms
# 979:	learn: 0.5607257	total: 30.5s	remaining: 622ms
# 980:	learn: 0.5607014	total: 30.5s	remaining: 591ms
# 981:	learn: 0.5606858	total: 30.5s	remaining: 559ms
# 982:	learn: 0.5606762	total: 30.6s	remaining: 528ms
# 983:	learn: 0.5606525	total: 30.6s	remaining: 497ms
# 984:	learn: 0.5606347	total: 30.6s	remaining: 466ms
# 985:	learn: 0.5606190	total: 30.6s	remaining: 435ms
# 986:	learn: 0.5605927	total: 30.7s	remaining: 404ms
# 987:	learn: 0.5605810	total: 30.7s	remaining: 373ms
# 988:	learn: 0.5605598	total: 30.7s	remaining: 342ms
# 989:	learn: 0.5605460	total: 30.8s	remaining: 311ms
# 990:	learn: 0.5605148	total: 30.8s	remaining: 280ms
# 991:	learn: 0.5604980	total: 30.8s	remaining: 249ms
# 992:	learn: 0.5604759	total: 30.9s	remaining: 218ms
# 993:	learn: 0.5604505	total: 30.9s	remaining: 187ms
# 994:	learn: 0.5604379	total: 30.9s	remaining: 155ms
# 995:	learn: 0.5604201	total: 31s	remaining: 124ms
# 996:	learn: 0.5604066	total: 31s	remaining: 93.3ms
# 997:	learn: 0.5603951	total: 31s	remaining: 62.2ms
# 998:	learn: 0.5603785	total: 31.1s	remaining: 31.1ms
# 999:	learn: 0.5603629	total: 31.1s	remaining: 0us
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000340 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2016
# [LightGBM] [Info] Number of data points in the train set: 24050, number of used features: 769
# [LightGBM] [Info] Start training from score 7365.217006
# [LightGBM] [Info] Number of positive: 65884, number of negative: 129370
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002219 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1864
# [LightGBM] [Info] Number of data points in the train set: 195254, number of used features: 557
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.337427 -> initscore=-0.674781
# [LightGBM] [Info] Start training from score -0.674781
# LGBMClassifier()

# %%
# Прогнозы на тестовых данных
catboost_regressor_predictions = catboost_regressor.predict(X_test_regression)
catboost_classifier_predictions = catboost_classifier.predict(X_test_classifier)

xgboost_regressor_predictions = xgboost_regressor.predict(X_test_regression)
xgboost_classifier_predictions = xgboost_classifier.predict(X_test_classifier)

lightgbm_regressor_predictions = lightgbm_regressor.predict(X_test_regression)
lightgbm_classifier_predictions = lightgbm_classifier.predict(X_test_classifier)

# %%
# Оценка качества моделей
catboost_regressor_accuracy = mean_squared_error(y_test_regression, catboost_regressor_predictions)
catboost_classifier_accuracy = accuracy_score(y_test_classifier, catboost_classifier_predictions)

xgboost_regressor_accuracy = mean_squared_error(y_test_regression, xgboost_regressor_predictions)
xgboost_classifier_accuracy = accuracy_score(y_test_classifier, xgboost_classifier_predictions)

lightgbm_regressor_accuracy = mean_squared_error(y_test_regression, lightgbm_regressor_predictions)
lightgbm_classifier_accuracy = accuracy_score(y_test_classifier, lightgbm_classifier_predictions)

# Вывод результатов
print('CatBoost Regressor Accuracy:', catboost_regressor_accuracy)
print('CatBoost Classifier Accuracy:', catboost_classifier_accuracy)

print('XGBoost Regressor Accuracy:', xgboost_regressor_accuracy)
print('XGBoost Classifier Accuracy:', xgboost_classifier_accuracy)

print('LightGBM Regressor Accuracy:', lightgbm_regressor_accuracy)
print('LightGBM Classifier Accuracy:', lightgbm_classifier_accuracy)
# Out:
# CatBoost Regressor Accuracy: 3776914.636992218
# CatBoost Classifier Accuracy: 0.6951489326832466
# XGBoost Regressor Accuracy: 3802853.1203989093
# XGBoost Classifier Accuracy: 0.6938583193346172
# LightGBM Regressor Accuracy: 3851491.31698211
# LightGBM Classifier Accuracy: 0.6945958126766911
